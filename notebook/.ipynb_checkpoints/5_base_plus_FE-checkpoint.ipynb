# %% [markdown]
# based on https://www.kaggle.com/coolcoder22/nn-19-features

# %%
# IMPORTS 
import numpy as np
import pandas as pd
import sklearn.metrics as mtr
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from keras.layers import Dense
from keras.models import Sequential
from keras.callbacks import Callback, EarlyStopping
from keras.models import Model
from keras.layers import Input, Dense, Concatenate, Reshape, Dropout, merge, Add
from keras.layers.embeddings import Embedding
from sklearn.model_selection import KFold,GroupKFold
import warnings
import random as rn
import tensorflow as tf
from keras.models import load_model
import os
import gc
from scipy.spatial import Voronoi
warnings.filterwarnings("ignore")

pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', 500)

# %%
train = pd.read_csv('../input/train.csv', dtype={'WindSpeed': 'object'})

# %%
train
# Out:
#             GameId          PlayId  Team      X      Y     S     A   Dis  \
# 0       2017090700  20170907000118  away  73.91  34.84  1.69  1.13  0.40
# 1       2017090700  20170907000118  away  74.67  32.64  0.42  1.35  0.01
# 2       2017090700  20170907000118  away  74.00  33.20  1.22  0.59  0.31
# 3       2017090700  20170907000118  away  71.46  27.70  0.42  0.54  0.02
# 4       2017090700  20170907000118  away  69.32  35.42  1.82  2.43  0.16
# ...            ...             ...   ...    ...    ...   ...   ...   ...
# 509757  2018123015  20181230154157  home  86.77  24.20  2.14  2.12  0.22
# 509758  2018123015  20181230154157  home  86.76  27.18  1.16  0.66  0.11
# 509759  2018123015  20181230154157  home  87.26  27.05  2.59  1.18  0.26
# 509760  2018123015  20181230154157  home  84.57  24.37  4.36  1.79  0.47
# 509761  2018123015  20181230154157  home  80.80  26.35  4.87  4.10  0.45
#
#         Orientation     Dir    NflId      DisplayName  JerseyNumber  Season  \
# 0             81.99  177.18   496723       Eric Berry            29    2017
# 1             27.61  198.70  2495116     Allen Bailey            97    2017
# 2              3.01  202.73  2495493   Justin Houston            50    2017
# 3            359.77  105.64  2506353  Derrick Johnson            56    2017
# 4             12.63  164.31  2530794       Ron Parker            38    2017
# ...             ...     ...      ...              ...           ...     ...
# 509757        44.55   15.31  2555289     Nick Vannett            81    2018
# 509758        53.63   42.80  2555395    Germain Ifedi            65    2018
# 509759         3.96   21.12  2556524      George Fant            74    2018
# 509760       148.08  183.34  2557891      Ethan Pocic            77    2018
# 509761       135.44  118.24  2558865     Chris Carson            32    2018
#
#         YardLine  Quarter GameClock PossessionTeam  Down  Distance  \
# 0             35        1  14:14:00             NE     3         2
# 1             35        1  14:14:00             NE     3         2
# 2             35        1  14:14:00             NE     3         2
# 3             35        1  14:14:00             NE     3         2
# 4             35        1  14:14:00             NE     3         2
# ...          ...      ...       ...            ...   ...       ...
# 509757        23        4  00:16:00            SEA     2         8
# 509758        23        4  00:16:00            SEA     2         8
# 509759        23        4  00:16:00            SEA     2         8
# 509760        23        4  00:16:00            SEA     2         8
# 509761        23        4  00:16:00            SEA     2         8
#
#        FieldPosition  HomeScoreBeforePlay  VisitorScoreBeforePlay  \
# 0                 NE                    0                       0
# 1                 NE                    0                       0
# 2                 NE                    0                       0
# 3                 NE                    0                       0
# 4                 NE                    0                       0
# ...              ...                  ...                     ...
# 509757           ARZ                   24                      24
# 509758           ARZ                   24                      24
# 509759           ARZ                   24                      24
# 509760           ARZ                   24                      24
# 509761           ARZ                   24                      24
#
#         NflIdRusher OffenseFormation        OffensePersonnel  \
# 0           2543773          SHOTGUN        1 RB, 1 TE, 3 WR
# 1           2543773          SHOTGUN        1 RB, 1 TE, 3 WR
# 2           2543773          SHOTGUN        1 RB, 1 TE, 3 WR
# 3           2543773          SHOTGUN        1 RB, 1 TE, 3 WR
# 4           2543773          SHOTGUN        1 RB, 1 TE, 3 WR
# ...             ...              ...                     ...
# 509757      2558865       SINGLEBACK  6 OL, 1 RB, 2 TE, 1 WR
# 509758      2558865       SINGLEBACK  6 OL, 1 RB, 2 TE, 1 WR
# 509759      2558865       SINGLEBACK  6 OL, 1 RB, 2 TE, 1 WR
# 509760      2558865       SINGLEBACK  6 OL, 1 RB, 2 TE, 1 WR
# 509761      2558865       SINGLEBACK  6 OL, 1 RB, 2 TE, 1 WR
#
#         DefendersInTheBox  DefensePersonnel PlayDirection  \
# 0                     6.0  2 DL, 3 LB, 6 DB          left
# 1                     6.0  2 DL, 3 LB, 6 DB          left
# 2                     6.0  2 DL, 3 LB, 6 DB          left
# 3                     6.0  2 DL, 3 LB, 6 DB          left
# 4                     6.0  2 DL, 3 LB, 6 DB          left
# ...                   ...               ...           ...
# 509757                9.0  4 DL, 3 LB, 4 DB         right
# 509758                9.0  4 DL, 3 LB, 4 DB         right
# 509759                9.0  4 DL, 3 LB, 4 DB         right
# 509760                9.0  4 DL, 3 LB, 4 DB         right
# 509761                9.0  4 DL, 3 LB, 4 DB         right
#
#                      TimeHandoff                  TimeSnap  Yards  \
# 0       2017-09-08T00:44:06.000Z  2017-09-08T00:44:05.000Z      8
# 1       2017-09-08T00:44:06.000Z  2017-09-08T00:44:05.000Z      8
# 2       2017-09-08T00:44:06.000Z  2017-09-08T00:44:05.000Z      8
# 3       2017-09-08T00:44:06.000Z  2017-09-08T00:44:05.000Z      8
# 4       2017-09-08T00:44:06.000Z  2017-09-08T00:44:05.000Z      8
# ...                          ...                       ...    ...
# 509757  2018-12-31T00:24:51.000Z  2018-12-31T00:24:49.000Z     11
# 509758  2018-12-31T00:24:51.000Z  2018-12-31T00:24:49.000Z     11
# 509759  2018-12-31T00:24:51.000Z  2018-12-31T00:24:49.000Z     11
# 509760  2018-12-31T00:24:51.000Z  2018-12-31T00:24:49.000Z     11
# 509761  2018-12-31T00:24:51.000Z  2018-12-31T00:24:49.000Z     11
#
#        PlayerHeight  PlayerWeight PlayerBirthDate PlayerCollegeName Position  \
# 0               6-0           212      12/29/1988         Tennessee       SS
# 1               6-3           288      03/25/1989             Miami       DE
# 2               6-3           270      01/21/1989           Georgia       DE
# 3               6-3           245      11/22/1982             Texas      ILB
# 4               6-0           206      08/17/1987          Newberry       FS
# ...             ...           ...             ...               ...      ...
# 509757          6-6           261      03/06/1993        Ohio State       TE
# 509758          6-5           325      06/02/1994         Texas A&M        G
# 509759          6-5           322      07/19/1992  Western Kentucky       OT
# 509760          6-6           320      08/05/1995   Louisiana State        C
# 509761         5-11           222      09/16/1994    Oklahoma State       RB
#
#        HomeTeamAbbr VisitorTeamAbbr  Week            Stadium        Location  \
# 0                NE              KC     1   Gillette Stadium  Foxborough, MA
# 1                NE              KC     1   Gillette Stadium  Foxborough, MA
# 2                NE              KC     1   Gillette Stadium  Foxborough, MA
# 3                NE              KC     1   Gillette Stadium  Foxborough, MA
# 4                NE              KC     1   Gillette Stadium  Foxborough, MA
# ...             ...             ...   ...                ...             ...
# 509757          SEA             ARI    17  CenturyLink Field     Seattle, WA
# 509758          SEA             ARI    17  CenturyLink Field     Seattle, WA
# 509759          SEA             ARI    17  CenturyLink Field     Seattle, WA
# 509760          SEA             ARI    17  CenturyLink Field     Seattle, WA
# 509761          SEA             ARI    17  CenturyLink Field     Seattle, WA
#
#        StadiumType        Turf     GameWeather  Temperature  Humidity  \
# 0          Outdoor  Field Turf  Clear and warm         63.0      77.0
# 1          Outdoor  Field Turf  Clear and warm         63.0      77.0
# 2          Outdoor  Field Turf  Clear and warm         63.0      77.0
# 3          Outdoor  Field Turf  Clear and warm         63.0      77.0
# 4          Outdoor  Field Turf  Clear and warm         63.0      77.0
# ...            ...         ...             ...          ...       ...
# 509757     Outdoor   FieldTurf          Cloudy         45.0      76.0
# 509758     Outdoor   FieldTurf          Cloudy         45.0      76.0
# 509759     Outdoor   FieldTurf          Cloudy         45.0      76.0
# 509760     Outdoor   FieldTurf          Cloudy         45.0      76.0
# 509761     Outdoor   FieldTurf          Cloudy         45.0      76.0
#
#        WindSpeed WindDirection
# 0              8            SW
# 1              8            SW
# 2              8            SW
# 3              8            SW
# 4              8            SW
# ...          ...           ...
# 509757         5            SE
# 509758         5            SE
# 509759         5            SE
# 509760         5            SE
# 509761         5            SE
#
# [509762 rows x 49 columns]

# %%
train['NflId'].nunique()
# Out:
# 2231

# %%
train[train.NflId==2552475]
# Out:
#             GameId          PlayId  Team       X      Y     S     A   Dis  \
# 8906    2017091009  20170910090051  home   90.58  22.45  3.52  2.82  0.45
# 9060    2017091009  20170910090590  home   90.84  28.46  3.78  2.98  0.38
# 9082    2017091009  20170910090611  home   87.11  30.02  4.19  3.02  0.44
# 9104    2017091009  20170910090656  home   79.55  29.95  2.10  2.36  0.05
# 9126    2017091009  20170910090682  home   67.50  31.22  3.38  0.82  0.43
# ...            ...             ...   ...     ...    ...   ...   ...   ...
# 477307  2018121611  20181216111322  home   53.44  31.96  5.71  2.52  0.56
# 477329  2018121611  20181216111344  home   74.67  31.96  4.68  0.83  0.46
# 477373  2018121611  20181216111455  home   78.51  33.87  5.98  2.13  0.59
# 477527  2018121611  20181216112290  home  110.80  27.12  4.39  2.25  0.43
# 477791  2018121611  20181216114162  home  104.94  28.86  5.72  2.01  0.56
#
#         Orientation     Dir    NflId  DisplayName  JerseyNumber  Season  \
# 8906         192.76  260.84  2552475  Todd Gurley            30    2017
# 9060         200.67  287.48  2552475  Todd Gurley            30    2017
# 9082         185.91  281.36  2552475  Todd Gurley            30    2017
# 9104         151.98  223.95  2552475  Todd Gurley            30    2017
# 9126         171.57  275.34  2552475  Todd Gurley            30    2017
# ...             ...     ...      ...          ...           ...     ...
# 477307        64.63   46.55  2552475  Todd Gurley            30    2018
# 477329        71.79   45.90  2552475  Todd Gurley            30    2018
# 477373        66.18   10.53  2552475  Todd Gurley            30    2018
# 477527       212.65  213.79  2552475  Todd Gurley            30    2018
# 477791        64.46   43.24  2552475  Todd Gurley            30    2018
#
#         YardLine  Quarter GameClock PossessionTeam  Down  Distance  \
# 8906          25        1  15:00:00             LA     1        10
# 9060          25        1  06:21:00             LA     1        10
# 9082          28        1  05:47:00             LA     2         7
# 9104          38        1  04:41:00             LA     1        10
# 9126          47        1  04:09:00             LA     2         1
# ...          ...      ...       ...            ...   ...       ...
# 477307        49        2  09:29:00             LA     1        10
# 477329        30        2  08:51:00             LA     1        10
# 477373        24        2  06:43:00             LA     1        20
# 477527         5        3  12:36:00             LA     1        10
# 477791         1        4  04:10:00             LA     2         1
#
#        FieldPosition  HomeScoreBeforePlay  VisitorScoreBeforePlay  \
# 8906              LA                    0                       0
# 9060              LA                   10                       3
# 9082              LA                   10                       3
# 9104              LA                   10                       3
# 9126              LA                   10                       3
# ...              ...                  ...                     ...
# 477307            LA                    7                       6
# 477329           PHI                    7                       6
# 477373           PHI                    7                       6
# 477527            LA                   13                      13
# 477791           PHI                   16                      30
#
#         NflIdRusher OffenseFormation  OffensePersonnel  DefendersInTheBox  \
# 8906        2552475       SINGLEBACK  1 RB, 2 TE, 2 WR                7.0
# 9060        2552475       SINGLEBACK  1 RB, 1 TE, 3 WR                6.0
# 9082        2552475       SINGLEBACK  1 RB, 1 TE, 3 WR                7.0
# 9104        2539336       SINGLEBACK  1 RB, 1 TE, 3 WR                6.0
# 9126        2552475       SINGLEBACK  1 RB, 2 TE, 2 WR                8.0
# ...             ...              ...               ...                ...
# 477307      2552475       SINGLEBACK  1 RB, 1 TE, 3 WR                7.0
# 477329      2552475       SINGLEBACK  1 RB, 1 TE, 3 WR                7.0
# 477373      2552475       SINGLEBACK  1 RB, 1 TE, 3 WR                6.0
# 477527      2552475       SINGLEBACK  1 RB, 1 TE, 3 WR                7.0
# 477791      2552475       SINGLEBACK  1 RB, 1 TE, 3 WR                8.0
#
#         DefensePersonnel PlayDirection               TimeHandoff  \
# 8906    3 DL, 4 LB, 4 DB          left  2017-09-10T20:06:12.000Z
# 9060    2 DL, 4 LB, 5 DB          left  2017-09-10T20:30:12.000Z
# 9082    2 DL, 4 LB, 5 DB          left  2017-09-10T20:30:47.000Z
# 9104    2 DL, 4 LB, 5 DB          left  2017-09-10T20:32:00.000Z
# 9126    3 DL, 4 LB, 4 DB          left  2017-09-10T20:32:44.000Z
# ...                  ...           ...                       ...
# 477307  4 DL, 2 LB, 5 DB         right  2018-12-17T02:12:47.000Z
# 477329  4 DL, 2 LB, 5 DB         right  2018-12-17T02:13:24.000Z
# 477373  4 DL, 2 LB, 5 DB         right  2018-12-17T02:16:22.000Z
# 477527  4 DL, 2 LB, 5 DB          left  2018-12-17T03:05:57.000Z
# 477791  4 DL, 2 LB, 5 DB         right  2018-12-17T04:17:29.000Z
#
#                         TimeSnap  Yards PlayerHeight  PlayerWeight  \
# 8906    2017-09-10T20:06:11.000Z      2          6-1           224
# 9060    2017-09-10T20:30:11.000Z      3          6-1           224
# 9082    2017-09-10T20:30:46.000Z      4          6-1           224
# 9104    2017-09-10T20:31:59.000Z      9          6-1           224
# 9126    2017-09-10T20:32:43.000Z      0          6-1           224
# ...                          ...    ...          ...           ...
# 477307  2018-12-17T02:12:45.000Z     21          6-1           224
# 477329  2018-12-17T02:13:23.000Z      9          6-1           224
# 477373  2018-12-17T02:16:21.000Z     -1          6-1           224
# 477527  2018-12-17T03:05:55.000Z     -2          6-1           224
# 477791  2018-12-17T04:17:27.000Z      1          6-1           224
#
#        PlayerBirthDate PlayerCollegeName Position HomeTeamAbbr  \
# 8906        08/03/1994           Georgia       RB           LA
# 9060        08/03/1994           Georgia       RB           LA
# 9082        08/03/1994           Georgia       RB           LA
# 9104        08/03/1994           Georgia       RB           LA
# 9126        08/03/1994           Georgia       RB           LA
# ...                ...               ...      ...          ...
# 477307      08/03/1994           Georgia       RB           LA
# 477329      08/03/1994           Georgia       RB           LA
# 477373      08/03/1994           Georgia       RB           LA
# 477527      08/03/1994           Georgia       RB           LA
# 477791      08/03/1994           Georgia       RB           LA
#
#        VisitorTeamAbbr  Week                        Stadium  \
# 8906               IND     1  Los Angeles Memorial Coliseum
# 9060               IND     1  Los Angeles Memorial Coliseum
# 9082               IND     1  Los Angeles Memorial Coliseum
# 9104               IND     1  Los Angeles Memorial Coliseum
# 9126               IND     1  Los Angeles Memorial Coliseum
# ...                ...   ...                            ...
# 477307             PHI    15  Los Angeles Memorial Coliseum
# 477329             PHI    15  Los Angeles Memorial Coliseum
# 477373             PHI    15  Los Angeles Memorial Coliseum
# 477527             PHI    15  Los Angeles Memorial Coliseum
# 477791             PHI    15  Los Angeles Memorial Coliseum
#
#                    Location StadiumType   Turf GameWeather  Temperature  \
# 8906    Los Angeles, Calif.     Outdoor  Grass       Sunny         90.0
# 9060    Los Angeles, Calif.     Outdoor  Grass       Sunny         90.0
# 9082    Los Angeles, Calif.     Outdoor  Grass       Sunny         90.0
# 9104    Los Angeles, Calif.     Outdoor  Grass       Sunny         90.0
# 9126    Los Angeles, Calif.     Outdoor  Grass       Sunny         90.0
# ...                     ...         ...    ...         ...          ...
# 477307      Los Angeles, CA     Outdoor  Grass      Cloudy         60.0
# 477329      Los Angeles, CA     Outdoor  Grass      Cloudy         60.0
# 477373      Los Angeles, CA     Outdoor  Grass      Cloudy         60.0
# 477527      Los Angeles, CA     Outdoor  Grass      Cloudy         60.0
# 477791      Los Angeles, CA     Outdoor  Grass      Cloudy         60.0
#
#         Humidity WindSpeed WindDirection
# 8906        38.0         2            SW
# 9060        38.0         2            SW
# 9082        38.0         2            SW
# 9104        38.0         2            SW
# 9126        38.0         2            SW
# ...          ...       ...           ...
# 477307      79.0         5             W
# 477329      79.0         5             W
# 477373      79.0         5             W
# 477527      79.0         5             W
# 477791      79.0         5             W
#
# [580 rows x 49 columns]

# %%
# Rusherの経験回数（これは未来の情報も含めてしまっている）
cnt_rusher = train[~train[['PlayId','NflIdRusher']].duplicated()]['NflIdRusher'].value_counts(dropna=False).reset_index()
cnt_rusher.columns = ['NflId', 'cnt_Rusher']
train = pd.merge(train, cnt_rusher, on='NflId', how='outer')
train['cnt_Rusher'].value_counts(dropna=False)
# Out:
# NaN      430971
# 1.0       20129
# 2.0        8946
# 3.0        5276
# 6.0        3881
# 5.0        2711
# 7.0        2669
# 4.0        2603
# 8.0        2007
# 15.0       1075
# 11.0        984
# 19.0        739
# 20.0        701
# 9.0         667
# 310.0       642
# 296.0       616
# 533.0       580
# 537.0       548
# 518.0       543
# 22.0        537
# 253.0       519
# 33.0        507
# 455.0       505
# 450.0       476
# 10.0        451
# 444.0       450
# 439.0       448
# 17.0        441
# 329.0       423
# 409.0       423
# 412.0       421
# 406.0       417
# 407.0       413
# 401.0       408
# 365.0       395
# 375.0       393
# 13.0        382
# 354.0       366
# 308.0       360
# 346.0       353
# 322.0       352
# 340.0       351
# 328.0       342
# 326.0       336
# 323.0       336
# 314.0       321
# 287.0       297
# 264.0       280
# 274.0       279
# 246.0       278
# 60.0        277
# 261.0       271
# 176.0       262
# 251.0       257
# 120.0       252
# 245.0       246
# 118.0       245
# 18.0        239
# 54.0        235
# 226.0       232
# 217.0       228
# 225.0       226
# 105.0       221
# 209.0       221
# 203.0       220
# 204.0       218
# 210.0       217
# 212.0       215
# 182.0       207
# 192.0       203
# 189.0       198
# 16.0        192
# 190.0       192
# 89.0        189
# 179.0       187
# 178.0       184
# 165.0       183
# 151.0       176
# 166.0       175
# 171.0       174
# 85.0        173
# 159.0       169
# 160.0       165
# 150.0       155
# 135.0       154
# 148.0       154
# 117.0       152
# 141.0       145
# 137.0       143
# 37.0        140
# 123.0       140
# 66.0        139
# 134.0       136
# 124.0       129
# 41.0        126
# 58.0        123
# 111.0       122
# 119.0       119
# 110.0       119
# 55.0        113
# 109.0       110
# 96.0        101
# 95.0        101
# 97.0        100
# 38.0         99
# 47.0         98
# 83.0         95
# 45.0         93
# 86.0         90
# 74.0         76
# 69.0         69
# 67.0         69
# 65.0         67
# 59.0         59
# 50.0         57
# 27.0         56
# 49.0         54
# 39.0         45
# 21.0         44
# 44.0         44
# 40.0         43
# 42.0         43
# 35.0         36
# 32.0         34
# 31.0         33
# 30.0         31
# 14.0         29
# 26.0         29
# 12.0         26
# 23.0         25
# Name: cnt_Rusher, dtype: int64

# %%
dict_cnt_rusher = dict(train[~train[['PlayId','NflIdRusher']].duplicated()]['NflIdRusher'].value_counts(dropna=False))
dict_cnt_rusher
# Out:
# {2555224: 537,
#  2552475: 533,
#  2555418: 518,
#  2552469: 455,
#  2557917: 450,
#  2533034: 444,
#  79607: 439,
#  2557976: 412,
#  2543743: 409,
#  2506404: 407,
#  2507164: 406,
#  2557973: 401,
#  2556075: 375,
#  2495466: 365,
#  2541161: 354,
#  2550189: 346,
#  2556466: 340,
#  2557997: 329,
#  2495469: 328,
#  497149: 326,
#  2552453: 323,
#  2555430: 322,
#  2540175: 314,
#  2532899: 310,
#  2540269: 310,
#  2558019: 308,
#  2558865: 296,
#  2495663: 296,
#  2558123: 287,
#  2558204: 274,
#  2553435: 264,
#  2560968: 261,
#  2552582: 253,
#  2558918: 253,
#  2495328: 251,
#  2555230: 246,
#  2557978: 245,
#  2507999: 226,
#  2533457: 225,
#  2543600: 217,
#  2558116: 212,
#  2543583: 210,
#  2560809: 209,
#  2557991: 204,
#  949: 203,
#  2552631: 192,
#  2561021: 190,
#  2559947: 189,
#  2495207: 182,
#  2558138: 179,
#  2553439: 178,
#  2558250: 176,
#  2550481: 171,
#  2552374: 166,
#  2557934: 165,
#  2557952: 160,
#  2540156: 159,
#  2559169: 151,
#  2552471: 150,
#  2543715: 148,
#  2559150: 141,
#  2561324: 137,
#  2543773: 135,
#  2555461: 134,
#  2560733: 124,
#  2540020: 123,
#  2539663: 120,
#  2539265: 120,
#  2560949: 119,
#  2539980: 118,
#  2560765: 118,
#  2552461: 117,
#  2556885: 111,
#  2552429: 110,
#  2555223: 109,
#  2552382: 105,
#  2540011: 105,
#  2495471: 97,
#  2550512: 96,
#  2553743: 95,
#  2559924: 89,
#  234: 89,
#  2555464: 86,
#  2557994: 85,
#  2560835: 85,
#  2560742: 83,
#  925: 74,
#  2553631: 69,
#  2540168: 67,
#  2560938: 66,
#  2550597: 3,
#  2552033: 3,
#  2550246: 3,
#  2556603: 3,
#  2552600: 3,
#  2550235: 3,
#  2543488: 3,
#  2558821: 2,
#  79860: 2,
#  2555261: 2,
#  2558194: 2,
#  2556190: 2,
#  2561036: 2,
#  2560801: 2,
#  2552464: 2,
#  2495441: 2,
#  2555260: 2,
#  2543466: 2,
#  2543646: 2,
#  2555466: 2,
#  2556695: 2,
#  2555259: 2,
#  2561029: 2,
#  2558273: 2,
#  2543638: 2,
#  497320: 2,
#  2555413: 2,
#  2557034: 2,
#  80427: 2,
#  2558877: 2,
#  2555334: 2,
#  2560907: 2,
#  2557920: 2,
#  2495211: 2,
#  2495966: 2,
#  2553895: 2,
#  2557977: 2,
#  2552431: 2,
#  2539322: 2,
#  2533040: 2,
#  2558052: 2,
#  2532978: 2,
#  2558127: 2,
#  497204: 2,
#  2553913: 2,
#  2557983: 2,
#  2552651: 2,
#  2495159: 2,
#  2495443: 1,
#  2532870: 1,
#  2561261: 1,
#  2506121: 1,
#  2560988: 1,
#  2555343: 1,
#  2561468: 1,
#  2560883: 1,
#  2553502: 1,
#  2532842: 1,
#  2541944: 1,
#  2534436: 1,
#  2534571: 1,
#  2558979: 1,
#  2495459: 1,
#  2539205: 1,
#  2507763: 1,
#  2506581: 1,
#  2560888: 1,
#  2532888: 1,
#  1032: 1,
#  2532956: 1,
#  2558008: 1,
#  2561358: 1,
#  2560747: 1,
#  2556697: 1,
#  2558856: 1,
#  2560955: 1,
#  81294: 1,
#  2495262: 1,
#  2554357: 1,
#  2535964: 1,
#  2555317: 1,
#  2649: 1,
#  2555333: 1,
#  497224: 1,
#  2543475: 1,
#  2543491: 1,
#  2557866: 1,
#  284: 1,
#  2533433: 1,
#  2506931: 1,
#  2558266: 1,
#  2535869: 1,
#  2556411: 1,
#  2505996: 1,
#  2495234: 1,
#  2558905: 1,
#  2557863: 1,
#  2543499: 1,
#  2540173: 1,
#  2557922: 1,
#  2557986: 1,
#  2543801: 1,
#  2541834: 1,
#  2505076: 1,
#  81284: 1,
#  2532903: 1,
#  2552576: 1,
#  2556404: 1,
#  2543828: 1,
#  2506147: 1,
#  2555419: 1,
#  2558063: 1,
#  2539235: 1,
#  2543477: 1,
#  2556661: 1,
#  2555346: 1,
#  2553499: 1,
#  2552408: 1,
#  2560836: 1,
#  2558956: 1,
#  2553896: 1,
#  2560847: 1,
#  2540165: 1,
#  2550400: 1,
#  2556855: 1,
#  2550256: 1,
#  2543509: 1,
#  2504775: 1}

# %%
np.median(list(dict_cnt_rusher.values()))
# Out:
# 7.0

# %%
train['cnt_Rusher'] = train['NflId'].map(dict_cnt_rusher)

# %%
# Yardsを用いた、target_encoding
# 今までrusherやったことがない場合は、欠損になるので、平均値補完
# これは、クロスバリデーションごとに使用する
df_rusher = train[['PlayId','NflIdRusher','Yards']]
df_rusher = df_rusher[~df_rusher['PlayId'].duplicated()].groupby('NflIdRusher').agg({'Yards':['max','mean']})
df_rusher.columns = ['Yards_max','Yards_mean']
# 2560854              9    4.500000
# 2560862             25    4.636364
# 2560883              5    5.000000
# 2560888             -1   -1.000000
# 2560898             23    3.750000
# 2560907             21   14.500000
# 2560915             10    2.428571
# 2560933             53    5.600000
# 2560935              8    3.384615
# 2560938             18    4.030303
# 2560949             29    4.294118
# 2560955              0    0.000000
# 2560967             75    6.230769
# 2560968             78    5.007663
# 2560988             -8   -8.000000
# 2561021             92    5.184211
# 2561029              2   -1.500000
# 2561036              0    0.000000
# 2561099             20    4.272727
# 2561137             21    2.973684
# 2561152             15    4.500000
# 2561261              4    4.000000
# 2561291              9    4.833333
# 2561324             43    5.240876
# 2561358              0    0.000000
# 2561382             16    4.454545
# 2561468              4    4.000000
# 3.9384154032515557

# %%
dict_yards_max = dict(df_rusher['Yards_max'])
dict_yards_mean = dict(df_rusher['Yards_mean'])

# %%
np.median(list(dict_yards_max.values()))
np.median(list(dict_yards_mean.values()))
# Out:
# 4.0

# %%
import seaborn as sns
import matplotlib.pyplot as plt

players = train[~train[['PlayId','NflIdRusher']].duplicated()]['NflIdRusher'].value_counts(dropna=False)

for i in players.index:
    print(i)
    print(train[train.NflIdRusher==i]['Yards'].describe())
    val_cnt = train[train.NflIdRusher==i]['Yards'].value_counts()
    sns.barplot(val_cnt.index, val_cnt.values)
    plt.show()
# Out:
# 2555224
# count    11814.000000
# mean         4.405959
# std          5.548651
# min         -8.000000
# 25%          1.000000
# 50%          3.000000
# 75%          6.000000
# max         41.000000
# Name: Yards, dtype: float64
# 2552475
# count    11726.000000
# mean         4.718574
# std          6.232751
# min         -7.000000
# 25%          1.000000
# 50%          3.000000
# 75%          6.000000
# max         57.000000
# Name: Yards, dtype: float64
# 2555418
# count    11396.000000
# mean         3.895753
# std          6.112218
# min         -7.000000
# 25%          1.000000
# 50%          3.000000
# 75%          5.000000
# max         53.000000
# Name: Yards, dtype: float64
# 2552469
# count    10010.000000
# mean         4.338462
# std          6.752769
# min         -4.000000
# 25%          1.000000
# 50%          3.000000
# 75%          6.000000
# max         87.000000
# Name: Yards, dtype: float64
# 2557917
# count    9900.000000
# mean        4.728889
# std         7.469562
# min        -6.000000
# 25%         1.000000
# 50%         3.000000
# 75%         6.000000
# max        69.000000
# Name: Yards, dtype: float64
# 2533034
# count    9768.000000
# mean        4.157658
# std         7.038699
# min        -7.000000
# 25%         1.000000
# 50%         3.000000
# 75%         5.000000
# max        97.000000
# Name: Yards, dtype: float64
# 79607
# count    9658.000000
# mean        3.751708
# std         6.245857
# min        -7.000000
# 25%         0.000000
# 50%         3.000000
# 75%         5.000000
# max        48.000000
# Name: Yards, dtype: float64
# 2557976
# count    9064.000000
# mean        4.288835
# std         6.630436
# min        -6.000000
# 25%         1.000000
# 50%         3.000000
# 75%         6.000000
# max        51.000000
# Name: Yards, dtype: float64
# 2543743
# count    8998.000000
# mean        3.672372
# std         5.591541
# min        -7.000000
# 25%         0.000000
# 50%         2.000000
# 75%         5.000000
# max        61.000000
# Name: Yards, dtype: float64
# 2506404
# count    8954.000000
# mean        4.078624
# std         4.773113
# min        -5.000000
# 25%         1.000000
# 50%         3.000000
# 75%         5.000000
# max        39.000000
# Name: Yards, dtype: float64
# 2507164
# count    8932.000000
# mean        3.869458
# std         7.235391
# min        -7.000000
# 25%         1.000000
# 50%         3.000000
# 75%         5.000000
# max        90.000000
# Name: Yards, dtype: float64
# 2557973
# count    8822.000000
# mean        3.688279
# std         7.016239
# min        -8.000000
# 25%         1.000000
# 50%         3.000000
# 75%         5.000000
# max        90.000000
# Name: Yards, dtype: float64
# 2556075
# count    8250.000000
# mean        4.357333
# std         8.188637
# min       -12.000000
# 25%         1.000000
# 50%         3.000000
# 75%         6.000000
# max        99.000000
# Name: Yards, dtype: float64
# 2495466
# count    8030.000000
# mean        4.810959
# std         7.470580
# min        -5.000000
# 25%         1.000000
# 50%         3.000000
# 75%         5.000000
# max        72.000000
# Name: Yards, dtype: float64
# 2541161
# count    7788.000000
# mean        4.002825
# std         6.288002
# min        -6.000000
# 25%         1.000000
# 50%         2.500000
# 75%         5.000000
# max        46.000000
# Name: Yards, dtype: float64
# 2550189
# count    7612.000000
# mean        4.427746
# std         8.375557
# min        -9.000000
# 25%         1.000000
# 50%         3.000000
# 75%         5.000000
# max        77.000000
# Name: Yards, dtype: float64
# 2556466
# count    7480.00000
# mean        3.80000
# std         4.99751
# min        -8.00000
# 25%         1.00000
# 50%         3.00000
# 75%         5.25000
# max        34.00000
# Name: Yards, dtype: float64
# 2557997
# count    7238.000000
# mean        4.553191
# std         6.840219
# min        -7.000000
# 25%         1.000000
# 50%         3.000000
# 75%         5.000000
# max        59.000000
# Name: Yards, dtype: float64
# 2495469
# count    7216.00000
# mean        4.20122
# std         5.91616
# min        -5.00000
# 25%         1.00000
# 50%         3.00000
# 75%         6.00000
# max        44.00000
# Name: Yards, dtype: float64
# 497149
# count    7172.000000
# mean        3.634969
# std         6.504714
# min        -7.000000
# 25%         1.000000
# 50%         2.000000
# 75%         5.000000
# max        68.000000
# Name: Yards, dtype: float64
# 2552453
# count    7106.000000
# mean        4.421053
# std         7.918233
# min        -8.000000
# 25%         0.000000
# 50%         3.000000
# 75%         6.000000
# max        65.000000
# Name: Yards, dtype: float64
# 2555430
# count    7084.000000
# mean        4.267081
# std         6.028577
# min       -11.000000
# 25%         1.000000
# 50%         3.000000
# 75%         6.000000
# max        50.000000
# Name: Yards, dtype: float64
# 2540175
# count    6908.000000
# mean        3.964968
# std         4.387115
# min        -7.000000
# 25%         1.000000
# 50%         3.000000
# 75%         5.000000
# max        27.000000
# Name: Yards, dtype: float64
# 2532899
# count    6820.000000
# mean        3.641935
# std         4.631669
# min        -6.000000
# 25%         1.000000
# 50%         3.000000
# 75%         6.000000
# max        29.000000
# Name: Yards, dtype: float64
# 2540269
# count    6820.000000
# mean        4.525806
# std         5.809566
# min        -6.000000
# 25%         1.000000
# 50%         3.000000
# 75%         6.000000
# max        46.000000
# Name: Yards, dtype: float64
# 2558019
# count    6776.000000
# mean        5.068182
# std         6.893845
# min        -7.000000
# 25%         2.000000
# 50%         3.000000
# 75%         7.000000
# max        74.000000
# Name: Yards, dtype: float64
# 2558865
# count    6512.000000
# mean        4.591216
# std         6.068642
# min        -4.000000
# 25%         1.000000
# 50%         3.000000
# 75%         6.000000
# max        61.000000
# Name: Yards, dtype: float64
# 2495663
# count    6512.000000
# mean        4.216216
# std         5.997690
# min        -5.000000
# 25%         1.000000
# 50%         3.000000
# 75%         6.000000
# max        52.000000
# Name: Yards, dtype: float64
# 2558123
# count    6314.000000
# mean        4.418118
# std         6.275225
# min       -10.000000
# 25%         1.000000
# 50%         3.000000
# 75%         6.000000
# max        49.000000
# Name: Yards, dtype: float64
# 2558204
# count    6028.000000
# mean        3.722628
# std         3.812954
# min        -4.000000
# 25%         1.000000
# 50%         3.000000
# 75%         5.000000
# max        25.000000
# Name: Yards, dtype: float64
# 2553435
# count    5808.000000
# mean        3.602273
# std         4.664594
# min        -2.000000
# 25%         1.000000
# 50%         3.000000
# 75%         5.000000
# max        53.000000
# Name: Yards, dtype: float64
# 2560968
# count    5742.000000
# mean        5.007663
# std        10.779800
# min       -10.000000
# 25%         1.000000
# 50%         2.000000
# 75%         5.000000
# max        78.000000
# Name: Yards, dtype: float64
# 2558918
# count    5566.000000
# mean        4.984190
# std         7.255999
# min        -6.000000
# 25%         1.000000
# 50%         3.000000
# 75%         7.000000
# max        66.000000
# Name: Yards, dtype: float64
# 2552582
# count    5566.000000
# mean        4.177866
# std         7.147049
# min        -7.000000
# 25%         1.000000
# 50%         3.000000
# 75%         6.000000
# max        71.000000
# Name: Yards, dtype: float64
# 2495328
# count    5522.000000
# mean        4.163347
# std         8.208286
# min        -5.000000
# 25%         0.000000
# 50%         2.000000
# 75%         5.000000
# max        75.000000
# Name: Yards, dtype: float64
# 2555230
# count    5412.000000
# mean        4.540650
# std         8.352563
# min        -7.000000
# 25%         1.000000
# 50%         3.000000
# 75%         6.000000
# max        66.000000
# Name: Yards, dtype: float64
# 2557978
# count    5390.000000
# mean        4.542857
# std         5.821964
# min        -4.000000
# 25%         1.000000
# 50%         3.000000
# 75%         6.000000
# max        30.000000
# Name: Yards, dtype: float64
# 2507999
# count    4972.000000
# mean        3.376106
# std         4.501697
# min        -6.000000
# 25%         1.000000
# 50%         2.000000
# 75%         5.000000
# max        34.000000
# Name: Yards, dtype: float64
# 2533457
# count    4950.000000
# mean        4.324444
# std         7.216550
# min        -5.000000
# 25%         1.000000
# 50%         3.000000
# 75%         6.000000
# max        70.000000
# Name: Yards, dtype: float64
# 2543600
# count    4774.000000
# mean        3.410138
# std         4.770074
# min        -7.000000
# 25%         1.000000
# 50%         3.000000
# 75%         5.000000
# max        48.000000
# Name: Yards, dtype: float64
# 2558116
# count    4664.000000
# mean        5.533019
# std         7.666221
# min        -5.000000
# 25%         1.750000
# 50%         4.000000
# 75%         7.000000
# max        67.000000
# Name: Yards, dtype: float64
# 2543583
# count    4620.000000
# mean        4.442857
# std         5.864087
# min        -7.000000
# 25%         1.000000
# 50%         3.000000
# 75%         6.000000
# max        44.000000
# Name: Yards, dtype: float64
# 2560809
# count    4598.000000
# mean        4.454545
# std         5.489960
# min        -4.000000
# 25%         1.000000
# 50%         3.000000
# 75%         6.000000
# max        34.000000
# Name: Yards, dtype: float64
# 2557991
# count    4488.000000
# mean        4.681373
# std         7.557260
# min        -4.000000
# 25%         1.000000
# 50%         3.000000
# 75%         6.000000
# max        70.000000
# Name: Yards, dtype: float64
# 949
# count    4466.000000
# mean        3.403941
# std         5.539945
# min        -6.000000
# 25%         1.000000
# 50%         3.000000
# 75%         5.000000
# max        60.000000
# Name: Yards, dtype: float64
# 2552631
# count    4224.000000
# mean        3.614583
# std         4.762325
# min        -7.000000
# 25%         1.000000
# 50%         2.000000
# 75%         6.000000
# max        37.000000
# Name: Yards, dtype: float64
# 2561021
# count    4180.000000
# mean        5.184211
# std        10.079466
# min        -5.000000
# 25%         1.000000
# 50%         3.000000
# 75%         6.000000
# max        92.000000
# Name: Yards, dtype: float64
# 2559947
# count    4158.000000
# mean        5.465608
# std         8.352739
# min        -7.000000
# 25%         1.000000
# 50%         3.000000
# 75%         7.000000
# max        65.000000
# Name: Yards, dtype: float64
# 2495207
# count    4004.000000
# mean        3.609890
# std         6.630474
# min        -9.000000
# 25%         1.000000
# 50%         3.000000
# 75%         5.000000
# max        75.000000
# Name: Yards, dtype: float64
# 2558138
# count    3938.000000
# mean        3.452514
# std         4.183729
# min        -5.000000
# 25%         1.000000
# 50%         3.000000
# 75%         5.000000
# max        30.000000
# Name: Yards, dtype: float64
# 2553439
# count    3916.000000
# mean        4.157303
# std         5.591434
# min        -5.000000
# 25%         1.000000
# 50%         3.000000
# 75%         6.000000
# max        37.000000
# Name: Yards, dtype: float64
# 2558250
# count    3872.000000
# mean        4.085227
# std         7.295757
# min       -12.000000
# 25%         0.000000
# 50%         3.000000
# 75%         5.000000
# max        46.000000
# Name: Yards, dtype: float64
# 2550481
# count    3762.000000
# mean        4.391813
# std         7.836614
# min        -4.000000
# 25%         1.000000
# 50%         3.000000
# 75%         5.000000
# max        75.000000
# Name: Yards, dtype: float64
# 2552374
# count    3652.000000
# mean        3.331325
# std         5.837316
# min        -6.000000
# 25%         0.000000
# 50%         2.000000
# 75%         5.000000
# max        34.000000
# Name: Yards, dtype: float64
# 2557934
# count    3630.000000
# mean        3.260606
# std         7.003905
# min        -8.000000
# 25%         0.000000
# 50%         2.000000
# 75%         5.000000
# max        69.000000
# Name: Yards, dtype: float64
# 2557952
# count    3520.000000
# mean        3.987500
# std         4.164405
# min        -6.000000
# 25%         1.000000
# 50%         3.000000
# 75%         6.000000
# max        24.000000
# Name: Yards, dtype: float64
# 2540156
# count    3498.00000
# mean        4.18239
# std         5.41547
# min        -7.00000
# 25%         1.00000
# 50%         3.00000
# 75%         6.00000
# max        25.00000
# Name: Yards, dtype: float64
# 2559169
# count    3322.000000
# mean        5.245033
# std         7.058975
# min        -5.000000
# 25%         1.000000
# 50%         3.000000
# 75%         7.000000
# max        41.000000
# Name: Yards, dtype: float64
# 2552471
# count    3300.000000
# mean        4.386667
# std         6.053781
# min        -5.000000
# 25%         1.000000
# 50%         3.000000
# 75%         6.000000
# max        58.000000
# Name: Yards, dtype: float64
# 2543715
# count    3256.000000
# mean        3.831081
# std         6.353660
# min        -6.000000
# 25%         0.000000
# 50%         3.000000
# 75%         6.000000
# max        58.000000
# Name: Yards, dtype: float64
# 2559150
# count    3102.000000
# mean        4.099291
# std         5.763741
# min        -5.000000
# 25%         1.000000
# 50%         3.000000
# 75%         6.000000
# max        32.000000
# Name: Yards, dtype: float64
# 2561324
# count    3014.000000
# mean        5.240876
# std         5.668785
# min        -1.000000
# 25%         2.000000
# 50%         4.000000
# 75%         6.000000
# max        43.000000
# Name: Yards, dtype: float64
# 2543773
# count    2970.000000
# mean        4.385185
# std         5.171995
# min        -6.000000
# 25%         1.000000
# 50%         3.000000
# 75%         6.000000
# max        27.000000
# Name: Yards, dtype: float64
# 2555461
# count    2948.000000
# mean        4.014925
# std         4.573546
# min        -5.000000
# 25%         1.000000
# 50%         3.000000
# 75%         6.000000
# max        26.000000
# Name: Yards, dtype: float64
# 2560733
# count    2728.000000
# mean        3.927419
# std         4.717297
# min        -5.000000
# 25%         1.000000
# 50%         3.000000
# 75%         6.000000
# max        24.000000
# Name: Yards, dtype: float64
# 2540020
# count    2706.000000
# mean        3.715447
# std         4.622332
# min        -4.000000
# 25%         0.000000
# 50%         3.000000
# 75%         7.000000
# max        21.000000
# Name: Yards, dtype: float64
# 2539663
# count    2640.00000
# mean        3.55000
# std         3.52877
# min        -4.00000
# 25%         1.00000
# 50%         3.00000
# 75%         5.00000
# max        16.00000
# Name: Yards, dtype: float64
# 2539265
# count    2640.000000
# mean        3.741667
# std         4.490646
# min        -4.000000
# 25%         1.000000
# 50%         3.000000
# 75%         5.000000
# max        31.000000
# Name: Yards, dtype: float64
# 2560949
# count    2618.000000
# mean        4.294118
# std         5.931192
# min        -4.000000
# 25%         1.000000
# 50%         3.000000
# 75%         6.000000
# max        29.000000
# Name: Yards, dtype: float64
# 2560765
# count    2596.000000
# mean        5.432203
# std         8.417183
# min        -5.000000
# 25%         1.000000
# 50%         4.000000
# 75%         6.000000
# max        71.000000
# Name: Yards, dtype: float64
# 2539980
# count    2596.000000
# mean        3.584746
# std         4.289808
# min        -4.000000
# 25%         1.000000
# 50%         3.000000
# 75%         5.000000
# max        25.000000
# Name: Yards, dtype: float64
# 2552461
# count    2574.000000
# mean        4.444444
# std         5.344689
# min        -6.000000
# 25%         1.000000
# 50%         3.000000
# 75%         7.000000
# max        23.000000
# Name: Yards, dtype: float64
# 2556885
# count    2442.000000
# mean        4.810811
# std         7.565705
# min        -7.000000
# 25%         1.000000
# 50%         3.000000
# 75%         6.000000
# max        52.000000
# Name: Yards, dtype: float64
# 2552429
# count    2420.000000
# mean        4.100000
# std         4.843896
# min        -6.000000
# 25%         1.000000
# 50%         3.000000
# 75%         6.000000
# max        37.000000
# Name: Yards, dtype: float64
# 2555223
# count    2398.000000
# mean        4.376147
# std         4.507386
# min        -3.000000
# 25%         2.000000
# 50%         3.000000
# 75%         6.000000
# max        26.000000
# Name: Yards, dtype: float64
# 2540011
# count    2310.000000
# mean        4.457143
# std         7.554659
# min        -9.000000
# 25%         1.000000
# 50%         3.000000
# 75%         7.000000
# max        61.000000
# Name: Yards, dtype: float64
# 2552382
# count    2310.000000
# mean        4.171429
# std         4.091426
# min        -4.000000
# 25%         1.000000
# 50%         4.000000
# 75%         6.000000
# max        19.000000
# Name: Yards, dtype: float64
# 2495471
# count    2134.000000
# mean        3.608247
# std         5.141618
# min        -2.000000
# 25%         1.000000
# 50%         2.000000
# 75%         5.000000
# max        36.000000
# Name: Yards, dtype: float64
# 2550512
# count    2112.000000
# mean        4.552083
# std         8.504305
# min        -7.000000
# 25%         1.000000
# 50%         3.000000
# 75%         6.000000
# max        69.000000
# Name: Yards, dtype: float64
# 2553743
# count    2090.000000
# mean        3.642105
# std         5.797785
# min        -6.000000
# 25%         0.000000
# 50%         3.000000
# 75%         5.000000
# max        45.000000
# Name: Yards, dtype: float64
# 2559924
# count    1958.000000
# mean        3.595506
# std         4.645185
# min        -6.000000
# 25%         1.000000
# 50%         3.000000
# 75%         5.000000
# max        18.000000
# Name: Yards, dtype: float64
# 234
# count    1958.000000
# mean        3.516854
# std         3.620821
# min        -4.000000
# 25%         1.000000
# 50%         3.000000
# 75%         5.000000
# max        16.000000
# Name: Yards, dtype: float64
# 2555464
# count    1892.000000
# mean        3.011628
# std         3.814980
# min        -6.000000
# 25%         0.000000
# 50%         2.000000
# 75%         5.000000
# max        13.000000
# Name: Yards, dtype: float64
# 2560835
# count    1870.000000
# mean        4.929412
# std         7.059280
# min        -3.000000
# 25%         1.000000
# 50%         3.000000
# 75%         6.000000
# max        38.000000
# Name: Yards, dtype: float64
# 2557994
# count    1870.000000
# mean        3.835294
# std         6.396280
# min        -4.000000
# 25%         1.000000
# 50%         3.000000
# 75%         5.000000
# max        39.000000
# Name: Yards, dtype: float64
# 2560742
# count    1826.000000
# mean        3.578313
# std         3.803769
# min        -2.000000
# 25%         1.000000
# 50%         3.000000
# 75%         5.000000
# max        15.000000
# Name: Yards, dtype: float64
# 925
# count    1628.000000
# mean        4.081081
# std         4.647719
# min        -4.000000
# 25%         1.000000
# 50%         3.000000
# 75%         5.000000
# max        19.000000
# Name: Yards, dtype: float64
# 2553631
# count    1518.000000
# mean        4.217391
# std         5.100329
# min        -4.000000
# 25%         1.000000
# 50%         3.000000
# 75%         6.000000
# max        29.000000
# Name: Yards, dtype: float64
# 2540168
# count    1474.000000
# mean        2.582090
# std         3.787155
# min        -6.000000
# 25%         0.000000
# 50%         2.000000
# 75%         3.000000
# max        19.000000
# Name: Yards, dtype: float64
# 2556414
# count    1452.000000
# mean        3.060606
# std         4.370399
# min        -5.000000
# 25%         1.000000
# 50%         3.000000
# 75%         5.000000
# max        21.000000
# Name: Yards, dtype: float64
# 2560938
# count    1452.000000
# mean        4.030303
# std         4.105993
# min        -3.000000
# 25%         2.000000
# 50%         3.000000
# 75%         5.000000
# max        18.000000
# Name: Yards, dtype: float64
# 2507428
# count    1430.000000
# mean        3.707692
# std         5.066653
# min        -6.000000
# 25%         1.000000
# 50%         2.000000
# 75%         5.000000
# max        25.000000
# Name: Yards, dtype: float64
# 2555229
# count    1320.000000
# mean        5.550000
# std         6.696876
# min        -4.000000
# 25%         2.000000
# 50%         3.500000
# 75%         7.000000
# max        37.000000
# Name: Yards, dtype: float64
# 2539336
# count    1320.000000
# mean        4.683333
# std         6.399016
# min        -6.000000
# 25%         1.000000
# 50%         3.500000
# 75%         7.000000
# max        27.000000
# Name: Yards, dtype: float64
# 2560933
# count    1320.000000
# mean        5.600000
# std         7.856214
# min        -3.000000
# 25%         2.000000
# 50%         4.000000
# 75%         6.000000
# max        53.000000
# Name: Yards, dtype: float64
# 2560711
# count    1298.000000
# mean        3.186441
# std         4.839831
# min        -4.000000
# 25%         0.000000
# 50%         3.000000
# 75%         5.000000
# max        29.000000
# Name: Yards, dtype: float64
# 2553733
# count    1276.000000
# mean        2.706897
# std         4.458469
# min        -5.000000
# 25%         0.000000
# 50%         2.000000
# 75%         5.000000
# max        23.000000
# Name: Yards, dtype: float64
# 2552647
# count    1276.000000
# mean        4.948276
# std         5.702878
# min        -4.000000
# 25%         2.000000
# 50%         4.000000
# 75%         6.000000
# max        30.000000
# Name: Yards, dtype: float64
# 2495470
# count    1210.000000
# mean        3.418182
# std         4.698908
# min        -4.000000
# 25%         0.000000
# 50%         2.000000
# 75%         4.000000
# max        21.000000
# Name: Yards, dtype: float64
# 2560862
# count    1210.000000
# mean        4.636364
# std         5.187310
# min        -2.000000
# 25%         1.000000
# 50%         4.000000
# 75%         6.000000
# max        25.000000
# Name: Yards, dtype: float64
# 2540145
# count    1188.000000
# mean        6.425926
# std         9.612303
# min        -4.000000
# 25%         1.000000
# 50%         4.000000
# 75%         8.000000
# max        47.000000
# Name: Yards, dtype: float64
# 2560756
# count    1100.000000
# mean        4.120000
# std         5.266005
# min        -3.000000
# 25%         1.000000
# 50%         3.000000
# 75%         5.000000
# max        20.000000
# Name: Yards, dtype: float64
# 2540204
# count    1078.000000
# mean        4.979592
# std         6.711286
# min        -3.000000
# 25%         1.000000
# 50%         3.000000
# 75%         5.000000
# max        34.000000
# Name: Yards, dtype: float64
# 2556118
# count    1034.000000
# mean        4.212766
# std         6.700132
# min        -6.000000
# 25%         0.000000
# 50%         3.000000
# 75%         5.000000
# max        28.000000
# Name: Yards, dtype: float64
# 2556440
# count    1034.000000
# mean        3.978723
# std         5.706396
# min        -4.000000
# 25%         0.000000
# 50%         3.000000
# 75%         6.000000
# max        30.000000
# Name: Yards, dtype: float64
# 2495473
# count    990.000000
# mean       3.644444
# std        4.256066
# min       -9.000000
# 25%        2.000000
# 50%        4.000000
# 75%        5.000000
# max       17.000000
# Name: Yards, dtype: float64
# 262
# count    990.000000
# mean       2.533333
# std        3.189087
# min       -4.000000
# 25%        1.000000
# 50%        2.000000
# 75%        5.000000
# max       11.000000
# Name: Yards, dtype: float64
# 2506467
# count    968.000000
# mean       4.113636
# std        4.804072
# min       -3.000000
# 25%        0.000000
# 50%        3.000000
# 75%        5.250000
# max       17.000000
# Name: Yards, dtype: float64
# 2550542
# count    924.000000
# mean       4.333333
# std        4.424561
# min       -1.000000
# 25%        1.000000
# 50%        3.000000
# 75%        6.000000
# max       16.000000
# Name: Yards, dtype: float64
# 2543603
# count    902.000000
# mean       3.439024
# std        3.717873
# min       -4.000000
# 25%        1.000000
# 50%        3.000000
# 75%        5.000000
# max       13.000000
# Name: Yards, dtype: float64
# 2555460
# count    902.000000
# mean       2.195122
# std        3.079714
# min       -7.000000
# 25%        1.000000
# 50%        2.000000
# 75%        3.000000
# max       14.000000
# Name: Yards, dtype: float64
# 2559180
# count    902.000000
# mean       4.024390
# std        5.575181
# min       -2.000000
# 25%        1.000000
# 50%        3.000000
# 75%        6.000000
# max       33.000000
# Name: Yards, dtype: float64
# 2553728
# count    880.000000
# mean       7.275000
# std        9.560504
# min       -2.000000
# 25%        1.000000
# 50%        4.000000
# 75%       10.250000
# max       52.000000
# Name: Yards, dtype: float64
# 2553650
# count    858.000000
# mean       4.384615
# std        4.793894
# min       -6.000000
# 25%        1.000000
# 50%        3.000000
# 75%        7.000000
# max       20.000000
# Name: Yards, dtype: float64
# 2561137
# count    836.000000
# mean       2.973684
# std        4.412478
# min       -4.000000
# 25%        0.000000
# 50%        2.000000
# 75%        4.000000
# max       21.000000
# Name: Yards, dtype: float64
# 2543664
# count    836.000000
# mean       3.631579
# std        4.160050
# min       -6.000000
# 25%        1.000000
# 50%        3.500000
# 75%        7.000000
# max       13.000000
# Name: Yards, dtype: float64
# 2552375
# count    814.000000
# mean       4.432432
# std        7.979662
# min       -6.000000
# 25%        0.000000
# 50%        3.000000
# 75%        5.000000
# max       43.000000
# Name: Yards, dtype: float64
# 2556762
# count    814.000000
# mean       3.918919
# std        3.268367
# min       -4.000000
# 25%        2.000000
# 50%        3.000000
# 75%        5.000000
# max       14.000000
# Name: Yards, dtype: float64
# 2539289
# count    770.000000
# mean       3.657143
# std        4.913489
# min       -6.000000
# 25%        2.000000
# 50%        4.000000
# 75%        6.000000
# max       18.000000
# Name: Yards, dtype: float64
# 2550658
# count    726.000000
# mean       2.454545
# std        5.324245
# min       -5.000000
# 25%        0.000000
# 50%        2.000000
# 75%        3.000000
# max       26.000000
# Name: Yards, dtype: float64
# 2556214
# count    726.000000
# mean       6.060606
# std        8.159220
# min       -5.000000
# 25%        0.000000
# 50%        4.000000
# 75%        9.000000
# max       33.000000
# Name: Yards, dtype: float64
# 2535890
# count    704.000000
# mean       2.968750
# std        3.452855
# min       -3.000000
# 25%        0.000000
# 50%        3.000000
# 75%        5.000000
# max       12.000000
# Name: Yards, dtype: float64
# 2558112
# count    682.000000
# mean       6.258065
# std       11.435485
# min       -3.000000
# 25%        1.000000
# 50%        3.000000
# 75%        6.000000
# max       60.000000
# Name: Yards, dtype: float64
# 2553762
# count    660.0000
# mean       4.3000
# std        5.4762
# min       -3.0000
# 25%        0.0000
# 50%        2.0000
# 75%        9.0000
# max       17.0000
# Name: Yards, dtype: float64
# 2533460
# count    594.000000
# mean       2.333333
# std        2.654977
# min       -3.000000
# 25%        1.000000
# 50%        2.000000
# 75%        5.000000
# max        7.000000
# Name: Yards, dtype: float64
# 2560777
# count    594.000000
# mean       2.740741
# std        3.206779
# min       -4.000000
# 25%        1.000000
# 50%        3.000000
# 75%        5.000000
# max        7.000000
# Name: Yards, dtype: float64
# 2560967
# count    572.000000
# mean       6.230769
# std       14.528765
# min       -3.000000
# 25%        1.000000
# 50%        2.500000
# 75%        6.000000
# max       75.000000
# Name: Yards, dtype: float64
# 2560770
# count    506.000000
# mean       1.913043
# std        3.299017
# min       -4.000000
# 25%        0.000000
# 50%        3.000000
# 75%        4.000000
# max        9.000000
# Name: Yards, dtype: float64
# 2552430
# count    484.000000
# mean       5.181818
# std        5.995858
# min       -4.000000
# 25%        2.000000
# 50%        4.000000
# 75%        7.000000
# max       22.000000
# Name: Yards, dtype: float64
# 2559880
# count    462.000000
# mean       3.761905
# std        2.778836
# min        0.000000
# 25%        2.000000
# 50%        3.000000
# 75%        5.000000
# max       11.000000
# Name: Yards, dtype: float64
# 2543770
# count    462.000000
# mean       4.523810
# std        5.175287
# min       -1.000000
# 25%        2.000000
# 50%        3.000000
# 75%        5.000000
# max       21.000000
# Name: Yards, dtype: float64
# 2550268
# count    440.00000
# mean       3.55000
# std        5.28308
# min       -2.00000
# 25%        1.00000
# 50%        2.00000
# 75%        3.50000
# max       21.00000
# Name: Yards, dtype: float64
# 2540169
# count    440.000000
# mean       8.250000
# std       12.354529
# min       -6.000000
# 25%        2.000000
# 50%        6.000000
# 75%        9.500000
# max       56.000000
# Name: Yards, dtype: float64
# 2532797
# count    440.000000
# mean       7.750000
# std       11.916805
# min       -5.000000
# 25%        2.000000
# 50%        4.500000
# 75%        9.250000
# max       54.000000
# Name: Yards, dtype: float64
# 2539217
# count    440.000000
# mean       2.750000
# std        4.052756
# min       -4.000000
# 25%       -0.250000
# 50%        3.000000
# 75%        5.000000
# max       14.000000
# Name: Yards, dtype: float64
# 2541544
# count    418.000000
# mean       2.631579
# std        3.379038
# min       -1.000000
# 25%        0.000000
# 50%        2.000000
# 75%        4.000000
# max       12.000000
# Name: Yards, dtype: float64
# 2543498
# count    418.000000
# mean       5.684211
# std        5.710505
# min       -7.000000
# 25%        2.000000
# 50%        6.000000
# 75%       10.000000
# max       17.000000
# Name: Yards, dtype: float64
# 2532790
# count    396.000000
# mean       5.888889
# std        5.808573
# min       -4.000000
# 25%        1.000000
# 50%        6.500000
# 75%        8.000000
# max       19.000000
# Name: Yards, dtype: float64
# 2550617
# count    374.000000
# mean       6.470588
# std        6.019000
# min       -5.000000
# 25%        3.000000
# 50%        7.000000
# 75%        9.000000
# max       20.000000
# Name: Yards, dtype: float64
# 2539303
# count    352.000000
# mean       4.312500
# std        2.826223
# min       -1.000000
# 25%        2.000000
# 50%        4.000000
# 75%        5.250000
# max        9.000000
# Name: Yards, dtype: float64
# 2495340
# count    330.000000
# mean       2.800000
# std        2.692328
# min       -1.000000
# 25%        1.000000
# 50%        2.000000
# 75%        4.000000
# max        9.000000
# Name: Yards, dtype: float64
# 2540230
# count    330.000000
# mean       4.066667
# std        4.589049
# min       -5.000000
# 25%        0.000000
# 50%        3.000000
# 75%        8.000000
# max       12.000000
# Name: Yards, dtype: float64
# 2552608
# count    330.000000
# mean       5.266667
# std        6.505675
# min       -6.000000
# 25%        1.000000
# 50%        5.000000
# 75%        9.000000
# max       20.000000
# Name: Yards, dtype: float64
# 2560915
# count    308.000000
# mean       2.428571
# std        2.774611
# min       -2.000000
# 25%        2.000000
# 50%        2.500000
# 75%        3.000000
# max       10.000000
# Name: Yards, dtype: float64
# 4327
# count    308.00000
# mean       4.00000
# std        2.78198
# min        0.00000
# 25%        2.00000
# 50%        3.50000
# 75%        5.00000
# max       10.00000
# Name: Yards, dtype: float64
# 2507166
# count    286.000000
# mean       5.000000
# std        8.147758
# min      -12.000000
# 25%        1.000000
# 50%        5.000000
# 75%        9.000000
# max       20.000000
# Name: Yards, dtype: float64
# 2560935
# count    286.000000
# mean       3.384615
# std        2.532381
# min       -1.000000
# 25%        1.000000
# 50%        4.000000
# 75%        5.000000
# max        8.000000
# Name: Yards, dtype: float64
# 2556803
# count    286.000000
# mean       1.615385
# std        1.445735
# min        0.000000
# 25%        1.000000
# 50%        1.000000
# 75%        3.000000
# max        5.000000
# Name: Yards, dtype: float64
# 2555417
# count    264.000000
# mean       1.666667
# std        3.014961
# min       -3.000000
# 25%       -0.250000
# 50%        1.000000
# 75%        3.250000
# max        8.000000
# Name: Yards, dtype: float64
# 2556841
# count    264.000000
# mean       3.416667
# std        3.481710
# min       -3.000000
# 25%        1.750000
# 50%        2.500000
# 75%        4.500000
# max       11.000000
# Name: Yards, dtype: float64
# 2561099
# count    242.000000
# mean       4.272727
# std        6.890971
# min       -6.000000
# 25%        0.000000
# 50%        2.000000
# 75%        9.000000
# max       20.000000
# Name: Yards, dtype: float64
# 2552415
# count    242.000000
# mean       5.818182
# std        7.236377
# min       -5.000000
# 25%        3.000000
# 50%        5.000000
# 75%        6.000000
# max       25.000000
# Name: Yards, dtype: float64
# 2561382
# count    242.000000
# mean       4.454545
# std        4.878609
# min        0.000000
# 25%        0.000000
# 50%        3.000000
# 75%        6.000000
# max       16.000000
# Name: Yards, dtype: float64
# 2540154
# count    242.000000
# mean       7.636364
# std        9.036579
# min        0.000000
# 25%        0.000000
# 50%        5.000000
# 75%       16.000000
# max       28.000000
# Name: Yards, dtype: float64
# 2558129
# count    242.000000
# mean       6.363636
# std        4.895590
# min        2.000000
# 25%        2.000000
# 50%        4.000000
# 75%       12.000000
# max       15.000000
# Name: Yards, dtype: float64
# 2557960
# count    220.000000
# mean       2.600000
# std        3.207298
# min       -4.000000
# 25%        1.000000
# 50%        3.000000
# 75%        4.000000
# max        8.000000
# Name: Yards, dtype: float64
# 2555220
# count    220.000000
# mean       3.500000
# std        5.036397
# min        0.000000
# 25%        0.000000
# 50%        2.000000
# 75%        3.000000
# max       17.000000
# Name: Yards, dtype: float64
# 2558066
# count    220.000000
# mean      13.300000
# std       11.927138
# min       -5.000000
# 25%        6.000000
# 50%        9.500000
# 75%       25.000000
# max       33.000000
# Name: Yards, dtype: float64
# 2543565
# count    198.000000
# mean       2.777778
# std        2.578929
# min       -2.000000
# 25%        2.000000
# 50%        3.000000
# 75%        5.000000
# max        7.000000
# Name: Yards, dtype: float64
# 2552379
# count    198.000000
# mean       2.777778
# std        2.205464
# min        0.000000
# 25%        1.000000
# 50%        2.000000
# 75%        4.000000
# max        7.000000
# Name: Yards, dtype: float64
# 1581
# count    198.000000
# mean       7.444444
# std        7.414107
# min       -6.000000
# 25%        4.000000
# 50%        7.000000
# 75%        8.000000
# max       23.000000
# Name: Yards, dtype: float64
# 2558975
# count    198.000000
# mean       1.777778
# std        2.255532
# min       -1.000000
# 25%        1.000000
# 50%        1.000000
# 75%        2.000000
# max        7.000000
# Name: Yards, dtype: float64
# 2550272
# count    198.000000
# mean       3.444444
# std        2.066028
# min       -1.000000
# 25%        2.000000
# 50%        4.000000
# 75%        5.000000
# max        6.000000
# Name: Yards, dtype: float64
# 2559325
# count    198.000000
# mean       5.333333
# std       12.882129
# min       -3.000000
# 25%       -1.000000
# 50%        1.000000
# 75%        3.000000
# max       41.000000
# Name: Yards, dtype: float64
# 2536044
# count    198.000000
# mean       4.777778
# std        4.167936
# min        0.000000
# 25%        2.000000
# 50%        2.000000
# 75%        9.000000
# max       11.000000
# Name: Yards, dtype: float64
# 2558833
# count    198.000000
# mean       1.666667
# std        1.494491
# min        0.000000
# 25%        1.000000
# 50%        1.000000
# 75%        3.000000
# max        4.000000
# Name: Yards, dtype: float64
# 2561152
# count    176.000000
# mean       4.500000
# std        5.162502
# min       -1.000000
# 25%        1.750000
# 50%        2.500000
# 75%        5.000000
# max       15.000000
# Name: Yards, dtype: float64
# 2550633
# count    176.000000
# mean       3.750000
# std        4.065886
# min       -2.000000
# 25%        1.250000
# 50%        4.500000
# 75%        5.000000
# max       12.000000
# Name: Yards, dtype: float64
# 2543572
# count    176.000000
# mean       5.500000
# std        7.386474
# min       -9.000000
# 25%        2.000000
# 50%        5.500000
# 75%        9.250000
# max       17.000000
# Name: Yards, dtype: float64
# 2557850
# count    176.000000
# mean       3.875000
# std        4.383899
# min       -3.000000
# 25%        2.250000
# 50%        3.500000
# 75%        5.250000
# max       13.000000
# Name: Yards, dtype: float64
# 2539964
# count    176.000000
# mean       6.625000
# std        5.693731
# min       -2.000000
# 25%        3.500000
# 50%        5.500000
# 75%       10.000000
# max       18.000000
# Name: Yards, dtype: float64
# 2557870
# count    176.000000
# mean       5.375000
# std        5.328763
# min       -1.000000
# 25%        2.750000
# 50%        5.000000
# 75%        6.500000
# max       17.000000
# Name: Yards, dtype: float64
# 238498
# count    176.000000
# mean      12.625000
# std        5.233546
# min        6.000000
# 25%        7.000000
# 50%       13.000000
# 75%       17.250000
# max       20.000000
# Name: Yards, dtype: float64
# 2553867
# count    176.000000
# mean       3.625000
# std        4.282356
# min       -1.000000
# 25%        0.500000
# 50%        2.000000
# 75%        6.750000
# max       11.000000
# Name: Yards, dtype: float64
# 2560898
# count    176.000000
# mean       3.750000
# std        8.158781
# min       -4.000000
# 25%       -2.000000
# 50%        1.500000
# 75%        6.000000
# max       23.000000
# Name: Yards, dtype: float64
# 2553660
# count    176.000000
# mean       2.875000
# std        5.792236
# min      -10.000000
# 25%        1.750000
# 50%        3.000000
# 75%        5.750000
# max       11.000000
# Name: Yards, dtype: float64
# 2535708
# count    176.000000
# mean       5.750000
# std        4.421377
# min       -1.000000
# 25%        2.500000
# 50%        6.000000
# 75%        8.750000
# max       12.000000
# Name: Yards, dtype: float64
# 2560813
# count    176.000000
# mean      17.250000
# std        9.886499
# min        0.000000
# 25%       11.500000
# 50%       18.000000
# 75%       23.500000
# max       32.000000
# Name: Yards, dtype: float64
# 497326
# count    176.000000
# mean       6.250000
# std       10.370563
# min       -8.000000
# 25%        1.750000
# 50%        3.000000
# 75%        9.250000
# max       30.000000
# Name: Yards, dtype: float64
# 2555432
# count    176.000000
# mean       2.125000
# std        1.456512
# min       -1.000000
# 25%        1.750000
# 50%        2.500000
# 75%        3.000000
# max        4.000000
# Name: Yards, dtype: float64
# 2550289
# count    176.000000
# mean       4.625000
# std        4.426705
# min       -2.000000
# 25%        2.750000
# 50%        3.500000
# 75%        5.500000
# max       13.000000
# Name: Yards, dtype: float64
# 2552466
# count    154.000000
# mean       4.714286
# std        6.670307
# min        0.000000
# 25%        0.000000
# 50%        2.000000
# 75%        6.000000
# max       20.000000
# Name: Yards, dtype: float64
# 2560757
# count    154.000000
# mean       1.000000
# std        3.391647
# min       -5.000000
# 25%        0.000000
# 50%        0.000000
# 75%        3.000000
# max        7.000000
# Name: Yards, dtype: float64
# 2552656
# count    154.000000
# mean       5.285714
# std        8.839686
# min      -10.000000
# 25%       -5.000000
# 50%        7.000000
# 75%       14.000000
# max       16.000000
# Name: Yards, dtype: float64
# 2532975
# count    154.000000
# mean       2.714286
# std        3.742905
# min        0.000000
# 25%        0.000000
# 50%        0.000000
# 75%        8.000000
# max        9.000000
# Name: Yards, dtype: float64
# 2540037
# count    154.000000
# mean       2.571429
# std        3.342844
# min       -3.000000
# 25%        0.000000
# 50%        3.000000
# 75%        5.000000
# max        8.000000
# Name: Yards, dtype: float64
# 2557895
# count    154.000000
# mean      15.000000
# std       12.724327
# min        0.000000
# 25%        9.000000
# 50%       11.000000
# 75%       20.000000
# max       43.000000
# Name: Yards, dtype: float64
# 2555209
# count    154.000000
# mean       1.142857
# std        5.558281
# min       -5.000000
# 25%       -5.000000
# 50%        2.000000
# 75%        8.000000
# max        9.000000
# Name: Yards, dtype: float64
# 2556519
# count    154.000000
# mean       6.285714
# std        5.793522
# min       -1.000000
# 25%        0.000000
# 50%        7.000000
# 75%       14.000000
# max       14.000000
# Name: Yards, dtype: float64
# 2508101
# count    132.000000
# mean       1.333333
# std        0.473200
# min        1.000000
# 25%        1.000000
# 50%        1.000000
# 75%        2.000000
# max        2.000000
# Name: Yards, dtype: float64
# 2541785
# count    132.000000
# mean       6.833333
# std        5.261362
# min       -1.000000
# 25%        3.000000
# 50%        6.500000
# 75%       11.000000
# max       15.000000
# Name: Yards, dtype: float64
# 2555295
# count    132.000000
# mean       6.666667
# std       11.801583
# min       -9.000000
# 25%       -5.000000
# 50%        7.500000
# 75%       12.000000
# max       27.000000
# Name: Yards, dtype: float64
# 2495455
# count    132.000000
# mean       5.500000
# std       10.650951
# min        0.000000
# 25%        0.000000
# 50%        0.000000
# 75%        4.000000
# max       29.000000
# Name: Yards, dtype: float64
# 2560854
# count    132.000000
# mean       4.500000
# std        2.575575
# min        1.000000
# 25%        3.000000
# 50%        4.000000
# 75%        6.000000
# max        9.000000
# Name: Yards, dtype: float64
# 2561291
# count    132.000000
# mean       4.833333
# std        2.275548
# min        2.000000
# 25%        3.000000
# 50%        4.500000
# 75%        6.000000
# max        9.000000
# Name: Yards, dtype: float64
# 2532820
# count    132.0
# mean       0.0
# std        0.0
# min        0.0
# 25%        0.0
# 50%        0.0
# 75%        0.0
# max        0.0
# Name: Yards, dtype: float64
# 2540225
# count    132.000000
# mean       0.833333
# std        1.071253
# min        0.000000
# 25%        0.000000
# 50%        0.500000
# 75%        1.000000
# max        3.000000
# Name: Yards, dtype: float64
# 2556273
# count    132.000000
# mean       2.666667
# std        1.251970
# min        1.000000
# 25%        1.000000
# 50%        3.000000
# 75%        4.000000
# max        4.000000
# Name: Yards, dtype: float64
# 2556528
# count    132.000000
# mean       3.166667
# std        1.348829
# min        1.000000
# 25%        2.000000
# 50%        3.500000
# 75%        4.000000
# max        5.000000
# Name: Yards, dtype: float64
# 2543496
# count    132.000000
# mean       4.500000
# std        5.271991
# min       -1.000000
# 25%       -1.000000
# 50%        4.000000
# 75%       10.000000
# max       11.000000
# Name: Yards, dtype: float64
# 2556454
# count    132.000000
# mean       2.500000
# std        1.613398
# min        0.000000
# 25%        2.000000
# 50%        2.000000
# 75%        4.000000
# max        5.000000
# Name: Yards, dtype: float64
# 2550738
# count    132.000000
# mean       4.166667
# std        2.042176
# min        1.000000
# 25%        3.000000
# 50%        4.000000
# 75%        6.000000
# max        7.000000
# Name: Yards, dtype: float64
# 2558846
# count    132.000000
# mean       6.500000
# std        6.368458
# min        0.000000
# 25%        3.000000
# 50%        3.500000
# 75%       10.000000
# max       19.000000
# Name: Yards, dtype: float64
# 2557848
# count    110.000000
# mean       3.200000
# std        4.728985
# min       -1.000000
# 25%        0.000000
# 50%        1.000000
# 75%        4.000000
# max       12.000000
# Name: Yards, dtype: float64
# 2552468
# count    110.000000
# mean       2.800000
# std        2.493294
# min        0.000000
# 25%        1.000000
# 50%        2.000000
# 75%        4.000000
# max        7.000000
# Name: Yards, dtype: float64
# 2550163
# count    110.000000
# mean       8.400000
# std        5.809199
# min        2.000000
# 25%        5.000000
# 50%        7.000000
# 75%        9.000000
# max       19.000000
# Name: Yards, dtype: float64
# 2552477
# count    110.000000
# mean       2.600000
# std        1.205492
# min        1.000000
# 25%        2.000000
# 50%        2.000000
# 75%        4.000000
# max        4.000000
# Name: Yards, dtype: float64
# 2552424
# count    110.000000
# mean       7.200000
# std        6.971502
# min       -4.000000
# 25%        5.000000
# 50%        7.000000
# 75%       11.000000
# max       17.000000
# Name: Yards, dtype: float64
# 2558150
# count    110.000000
# mean       4.800000
# std        3.885518
# min       -1.000000
# 25%        4.000000
# 50%        4.000000
# 75%        6.000000
# max       11.000000
# Name: Yards, dtype: float64
# 2552635
# count    110.000000
# mean       2.800000
# std        1.332722
# min        1.000000
# 25%        2.000000
# 50%        3.000000
# 75%        3.000000
# max        5.000000
# Name: Yards, dtype: float64
# 2558010
# count    110.000000
# mean       4.200000
# std        5.058919
# min       -3.000000
# 25%        2.000000
# 50%        3.000000
# 75%        7.000000
# max       12.000000
# Name: Yards, dtype: float64
# 2540259
# count    110.000000
# mean       2.800000
# std        1.171528
# min        2.000000
# 25%        2.000000
# 50%        2.000000
# 75%        3.000000
# max        5.000000
# Name: Yards, dtype: float64
# 2543457
# count    110.000000
# mean      10.400000
# std       11.251259
# min       -1.000000
# 25%        2.000000
# 50%        9.000000
# 75%       11.000000
# max       31.000000
# Name: Yards, dtype: float64
# 2557987
# count    110.000000
# mean       2.600000
# std        1.024471
# min        1.000000
# 25%        2.000000
# 50%        3.000000
# 75%        3.000000
# max        4.000000
# Name: Yards, dtype: float64
# 2553617
# count    110.000000
# mean       1.600000
# std        1.205492
# min        0.000000
# 25%        1.000000
# 50%        1.000000
# 75%        3.000000
# max        3.000000
# Name: Yards, dtype: float64
# 2558065
# count    110.000000
# mean      11.000000
# std        8.962716
# min       -3.000000
# 25%        5.000000
# 50%       13.000000
# 75%       20.000000
# max       20.000000
# Name: Yards, dtype: float64
# 2556752
# count    88.000000
# mean      6.000000
# std       1.422318
# min       4.000000
# 25%       5.500000
# 50%       6.000000
# 75%       6.500000
# max       8.000000
# Name: Yards, dtype: float64
# 2495448
# count    88.000000
# mean      3.750000
# std       3.919448
# min       0.000000
# 25%       0.750000
# 50%       2.500000
# 75%       5.500000
# max      10.000000
# Name: Yards, dtype: float64
# 2555234
# count    88.000000
# mean      3.000000
# std       3.017192
# min      -2.000000
# 25%       2.500000
# 50%       4.000000
# 75%       4.500000
# max       6.000000
# Name: Yards, dtype: float64
# 2534871
# count    88.000000
# mean      2.750000
# std       1.487496
# min       1.000000
# 25%       1.750000
# 50%       2.500000
# 75%       3.500000
# max       5.000000
# Name: Yards, dtype: float64
# 2560810
# count    88.00000
# mean      2.50000
# std       3.79655
# min      -1.00000
# 25%      -1.00000
# 50%       1.50000
# 75%       5.00000
# max       8.00000
# Name: Yards, dtype: float64
# 2557858
# count    88.000000
# mean     12.500000
# std       1.667816
# min      10.000000
# 25%      11.500000
# 50%      13.000000
# 75%      14.000000
# max      14.000000
# Name: Yards, dtype: float64
# 2557898
# count    88.000000
# mean      6.250000
# std       6.295866
# min      -3.000000
# 25%       2.250000
# 50%       8.000000
# 75%      12.000000
# max      12.000000
# Name: Yards, dtype: float64
# 2543847
# count    88.000000
# mean      3.500000
# std       3.927504
# min       0.000000
# 25%       0.750000
# 50%       2.000000
# 75%       4.750000
# max      10.000000
# Name: Yards, dtype: float64
# 2552636
# count    88.000000
# mean      2.250000
# std       2.877779
# min       0.000000
# 25%       0.000000
# 50%       1.000000
# 75%       3.250000
# max       7.000000
# Name: Yards, dtype: float64
# 2552597
# count    88.000000
# mean      0.500000
# std       7.475631
# min     -12.000000
# 25%      -1.500000
# 50%       3.500000
# 75%       5.500000
# max       7.000000
# Name: Yards, dtype: float64
# 2556396
# count    88.000000
# mean      1.000000
# std       4.325811
# min      -4.000000
# 25%      -2.500000
# 50%       0.500000
# 75%       4.000000
# max       7.000000
# Name: Yards, dtype: float64
# 2558954
# count    88.000000
# mean      4.250000
# std       3.919448
# min       2.000000
# 25%       2.000000
# 50%       2.000000
# 75%       4.250000
# max      11.000000
# Name: Yards, dtype: float64
# 2552487
# count    66.000000
# mean      8.000000
# std       2.966479
# min       4.000000
# 25%       4.000000
# 50%       9.000000
# 75%      11.000000
# max      11.000000
# Name: Yards, dtype: float64
# 2550246
# count    66.000000
# mean      5.666667
# std       3.114894
# min       3.000000
# 25%       3.000000
# 50%       4.000000
# 75%      10.000000
# max      10.000000
# Name: Yards, dtype: float64
# 2557889
# count    66.000000
# mean      9.666667
# std       4.058546
# min       4.000000
# 25%       4.000000
# 50%      12.000000
# 75%      13.000000
# max      13.000000
# Name: Yards, dtype: float64
# 2556603
# count    66.000000
# mean      1.000000
# std       0.822753
# min       0.000000
# 25%       0.000000
# 50%       1.000000
# 75%       2.000000
# max       2.000000
# Name: Yards, dtype: float64
# 2555227
# count    66.000000
# mean      0.000000
# std       0.822753
# min      -1.000000
# 25%      -1.000000
# 50%       0.000000
# 75%       1.000000
# max       1.000000
# Name: Yards, dtype: float64
# 2550235
# count    66.000000
# mean      0.000000
# std       0.822753
# min      -1.000000
# 25%      -1.000000
# 50%       0.000000
# 75%       1.000000
# max       1.000000
# Name: Yards, dtype: float64
# 2543488
# count    66.000000
# mean     15.666667
# std      25.509777
# min      -7.000000
# 25%      -7.000000
# 50%       3.000000
# 75%      51.000000
# max      51.000000
# Name: Yards, dtype: float64
# 2552033
# count    66.0
# mean      0.0
# std       0.0
# min       0.0
# 25%       0.0
# 50%       0.0
# 75%       0.0
# max       0.0
# Name: Yards, dtype: float64
# 2558208
# count    66.000000
# mean     14.000000
# std      14.035121
# min       0.000000
# 25%       0.000000
# 50%       9.000000
# 75%      33.000000
# max      33.000000
# Name: Yards, dtype: float64
# 2558837
# count    66.000000
# mean     -0.333333
# std       2.644782
# min      -4.000000
# 25%      -4.000000
# 50%       1.000000
# 75%       2.000000
# max       2.000000
# Name: Yards, dtype: float64
# 2550597
# count    66.000000
# mean      1.666667
# std       6.700938
# min      -4.000000
# 25%      -4.000000
# 50%      -2.000000
# 75%      11.000000
# max      11.000000
# Name: Yards, dtype: float64
# 2530515
# count    66.000000
# mean      5.666667
# std       5.478162
# min       0.000000
# 25%       0.000000
# 50%       4.000000
# 75%      13.000000
# max      13.000000
# Name: Yards, dtype: float64
# 2495454
# count    66.000000
# mean      9.000000
# std       5.932959
# min       1.000000
# 25%       1.000000
# 50%      11.000000
# 75%      15.000000
# max      15.000000
# Name: Yards, dtype: float64
# 2559020
# count    66.000000
# mean      4.666667
# std       2.513553
# min       2.000000
# 25%       2.000000
# 50%       4.000000
# 75%       8.000000
# max       8.000000
# Name: Yards, dtype: float64
# 2560781
# count    66.000000
# mean     11.666667
# std       8.117092
# ...
# min       6.000000
# 25%       6.000000
# 50%       6.500000
# 75%       7.000000
# max       7.000000
# Name: Yards, dtype: float64
# 2558877
# count    44.000000
# mean      5.000000
# std       3.034683
# min       2.000000
# 25%       2.000000
# 50%       5.000000
# 75%       8.000000
# max       8.000000
# Name: Yards, dtype: float64
# 2557920
# count    44.000000
# mean      6.000000
# std       1.011561
# min       5.000000
# 25%       5.000000
# 50%       6.000000
# 75%       7.000000
# max       7.000000
# Name: Yards, dtype: float64
# 80427
# count    44.000000
# mean     -2.000000
# std       5.057805
# min      -7.000000
# 25%      -7.000000
# 50%      -2.000000
# 75%       3.000000
# max       3.000000
# Name: Yards, dtype: float64
# 2560907
# count    44.000000
# mean     14.500000
# std       6.575147
# min       8.000000
# 25%       8.000000
# 50%      14.500000
# 75%      21.000000
# max      21.000000
# Name: Yards, dtype: float64
# 2556695
# count    44.000000
# mean      0.500000
# std       0.505781
# min       0.000000
# 25%       0.000000
# 50%       0.500000
# 75%       1.000000
# max       1.000000
# Name: Yards, dtype: float64
# 2555334
# count    44.000000
# mean      1.000000
# std       1.011561
# min       0.000000
# 25%       0.000000
# 50%       1.000000
# 75%       2.000000
# max       2.000000
# Name: Yards, dtype: float64
# 2543638
# count    44.000000
# mean      5.000000
# std       1.011561
# min       4.000000
# 25%       4.000000
# 50%       5.000000
# 75%       6.000000
# max       6.000000
# Name: Yards, dtype: float64
# 2557034
# count    44.000000
# mean      0.000000
# std       3.034683
# min      -3.000000
# 25%      -3.000000
# 50%       0.000000
# 75%       3.000000
# max       3.000000
# Name: Yards, dtype: float64
# 2555413
# count    44.000000
# mean      6.500000
# std       2.528903
# min       4.000000
# 25%       4.000000
# 50%       6.500000
# 75%       9.000000
# max       9.000000
# Name: Yards, dtype: float64
# 497320
# count    44.000000
# mean     10.000000
# std       8.092489
# min       2.000000
# 25%       2.000000
# 50%      10.000000
# 75%      18.000000
# max      18.000000
# Name: Yards, dtype: float64
# 2558273
# count    44.000000
# mean      1.000000
# std       4.046244
# min      -3.000000
# 25%      -3.000000
# 50%       1.000000
# 75%       5.000000
# max       5.000000
# Name: Yards, dtype: float64
# 2552431
# count    44.000000
# mean      1.000000
# std       1.011561
# min       0.000000
# 25%       0.000000
# 50%       1.000000
# 75%       2.000000
# max       2.000000
# Name: Yards, dtype: float64
# 2561029
# count    44.000000
# mean     -1.500000
# std       3.540464
# min      -5.000000
# 25%      -5.000000
# 50%      -1.500000
# 75%       2.000000
# max       2.000000
# Name: Yards, dtype: float64
# 2533040
# count    44.0
# mean      3.0
# std       0.0
# min       3.0
# 25%       3.0
# 50%       3.0
# 75%       3.0
# max       3.0
# Name: Yards, dtype: float64
# 497204
# count    44.000000
# mean      0.000000
# std       1.011561
# min      -1.000000
# 25%      -1.000000
# 50%       0.000000
# 75%       1.000000
# max       1.000000
# Name: Yards, dtype: float64
# 2558052
# count    44.000000
# mean      8.500000
# std       0.505781
# min       8.000000
# 25%       8.000000
# 50%       8.500000
# 75%       9.000000
# max       9.000000
# Name: Yards, dtype: float64
# 2557983
# count    44.0
# mean      0.0
# std       0.0
# min       0.0
# 25%       0.0
# 50%       0.0
# 75%       0.0
# max       0.0
# Name: Yards, dtype: float64
# 2553913
# count    44.000000
# mean      7.500000
# std       6.575147
# min       1.000000
# 25%       1.000000
# 50%       7.500000
# 75%      14.000000
# max      14.000000
# Name: Yards, dtype: float64
# 2555466
# count    44.000000
# mean      1.500000
# std       3.540464
# min      -2.000000
# 25%      -2.000000
# 50%       1.500000
# 75%       5.000000
# max       5.000000
# Name: Yards, dtype: float64
# 2532978
# count    44.000000
# mean     19.500000
# std      14.667636
# min       5.000000
# 25%       5.000000
# 50%      19.500000
# 75%      34.000000
# max      34.000000
# Name: Yards, dtype: float64
# 2495159
# count    44.000000
# mean      6.000000
# std       7.080928
# min      -1.000000
# 25%      -1.000000
# 50%       6.000000
# 75%      13.000000
# max      13.000000
# Name: Yards, dtype: float64
# 2539322
# count    44.000000
# mean      4.500000
# std       3.540464
# min       1.000000
# 25%       1.000000
# 50%       4.500000
# 75%       8.000000
# max       8.000000
# Name: Yards, dtype: float64
# 2560883
# count    22.0
# mean      5.0
# std       0.0
# min       5.0
# 25%       5.0
# 50%       5.0
# 75%       5.0
# max       5.0
# Name: Yards, dtype: float64
# 2560988
# count    22.0
# mean     -8.0
# std       0.0
# min      -8.0
# 25%      -8.0
# 50%      -8.0
# 75%      -8.0
# max      -8.0
# Name: Yards, dtype: float64
# 2532870
# count    22.0
# mean      0.0
# std       0.0
# min       0.0
# 25%       0.0
# 50%       0.0
# 75%       0.0
# max       0.0
# Name: Yards, dtype: float64
# 2561261
# count    22.0
# mean      4.0
# std       0.0
# min       4.0
# 25%       4.0
# 50%       4.0
# 75%       4.0
# max       4.0
# Name: Yards, dtype: float64
# 2506121
# count    22.0
# mean     -2.0
# std       0.0
# min      -2.0
# 25%      -2.0
# 50%      -2.0
# 75%      -2.0
# max      -2.0
# Name: Yards, dtype: float64
# 2561468
# count    22.0
# mean      4.0
# std       0.0
# min       4.0
# 25%       4.0
# 50%       4.0
# 75%       4.0
# max       4.0
# Name: Yards, dtype: float64
# 2553502
# count    22.0
# mean      7.0
# std       0.0
# min       7.0
# 25%       7.0
# 50%       7.0
# 75%       7.0
# max       7.0
# Name: Yards, dtype: float64
# 2555343
# count    22.0
# mean    -14.0
# std       0.0
# min     -14.0
# 25%     -14.0
# 50%     -14.0
# 75%     -14.0
# max     -14.0
# Name: Yards, dtype: float64
# 2532842
# count    22.0
# mean      0.0
# std       0.0
# min       0.0
# 25%       0.0
# 50%       0.0
# 75%       0.0
# max       0.0
# Name: Yards, dtype: float64
# 2534436
# count    22.0
# mean     -5.0
# std       0.0
# min      -5.0
# 25%      -5.0
# 50%      -5.0
# 75%      -5.0
# max      -5.0
# Name: Yards, dtype: float64
# 2495459
# count    22.0
# mean     -3.0
# std       0.0
# min      -3.0
# 25%      -3.0
# 50%      -3.0
# 75%      -3.0
# max      -3.0
# Name: Yards, dtype: float64
# 2495443
# count    22.0
# mean      0.0
# std       0.0
# min       0.0
# 25%       0.0
# 50%       0.0
# 75%       0.0
# max       0.0
# Name: Yards, dtype: float64
# 2541944
# count    22.0
# mean      8.0
# std       0.0
# min       8.0
# 25%       8.0
# 50%       8.0
# 75%       8.0
# max       8.0
# Name: Yards, dtype: float64
# 2534571
# count    22.0
# mean      2.0
# std       0.0
# min       2.0
# 25%       2.0
# 50%       2.0
# 75%       2.0
# max       2.0
# Name: Yards, dtype: float64
# 2558979
# count    22.0
# mean      0.0
# std       0.0
# min       0.0
# 25%       0.0
# 50%       0.0
# 75%       0.0
# max       0.0
# Name: Yards, dtype: float64
# 2539205
# count    22.0
# mean      6.0
# std       0.0
# min       6.0
# 25%       6.0
# 50%       6.0
# 75%       6.0
# max       6.0
# Name: Yards, dtype: float64
# 2556411
# count    22.0
# mean      5.0
# std       0.0
# min       5.0
# 25%       5.0
# 50%       5.0
# 75%       5.0
# max       5.0
# Name: Yards, dtype: float64
# 2506581
# count    22.0
# mean      1.0
# std       0.0
# min       1.0
# 25%       1.0
# 50%       1.0
# 75%       1.0
# max       1.0
# Name: Yards, dtype: float64
# 2554357
# count    22.0
# mean     -2.0
# std       0.0
# min      -2.0
# 25%      -2.0
# 50%      -2.0
# 75%      -2.0
# max      -2.0
# Name: Yards, dtype: float64
# 2649
# count    22.0
# mean     -2.0
# std       0.0
# min      -2.0
# 25%      -2.0
# 50%      -2.0
# 75%      -2.0
# max      -2.0
# Name: Yards, dtype: float64
# 2561358
# count    22.0
# mean      0.0
# std       0.0
# min       0.0
# 25%       0.0
# 50%       0.0
# 75%       0.0
# max       0.0
# Name: Yards, dtype: float64
# 2558905
# count    22.0
# mean     15.0
# std       0.0
# min      15.0
# 25%      15.0
# 50%      15.0
# 75%      15.0
# max      15.0
# Name: Yards, dtype: float64
# 1032
# count    22.0
# mean     -2.0
# std       0.0
# min      -2.0
# 25%      -2.0
# 50%      -2.0
# 75%      -2.0
# max      -2.0
# Name: Yards, dtype: float64
# 2495262
# count    22.0
# mean      0.0
# std       0.0
# min       0.0
# 25%       0.0
# 50%       0.0
# 75%       0.0
# max       0.0
# Name: Yards, dtype: float64
# 2532956
# count    22.0
# mean      8.0
# std       0.0
# min       8.0
# 25%       8.0
# 50%       8.0
# 75%       8.0
# max       8.0
# Name: Yards, dtype: float64
# 2558008
# count    22.0
# mean     28.0
# std       0.0
# min      28.0
# 25%      28.0
# 50%      28.0
# 75%      28.0
# max      28.0
# Name: Yards, dtype: float64
# 2556697
# count    22.0
# mean      6.0
# std       0.0
# min       6.0
# 25%       6.0
# 50%       6.0
# 75%       6.0
# max       6.0
# Name: Yards, dtype: float64
# 284
# count    22.0
# mean     -2.0
# std       0.0
# min      -2.0
# 25%      -2.0
# 50%      -2.0
# 75%      -2.0
# max      -2.0
# Name: Yards, dtype: float64
# 2533433
# count    22.0
# mean      1.0
# std       0.0
# min       1.0
# 25%       1.0
# 50%       1.0
# 75%       1.0
# max       1.0
# Name: Yards, dtype: float64
# 2558856
# count    22.0
# mean      5.0
# std       0.0
# min       5.0
# 25%       5.0
# 50%       5.0
# 75%       5.0
# max       5.0
# Name: Yards, dtype: float64
# 2560955
# count    22.0
# mean      0.0
# std       0.0
# min       0.0
# 25%       0.0
# 50%       0.0
# 75%       0.0
# max       0.0
# Name: Yards, dtype: float64
# 81294
# count    22.0
# mean      0.0
# std       0.0
# min       0.0
# 25%       0.0
# 50%       0.0
# 75%       0.0
# max       0.0
# Name: Yards, dtype: float64
# 2535964
# count    22.0
# mean      6.0
# std       0.0
# min       6.0
# 25%       6.0
# 50%       6.0
# 75%       6.0
# max       6.0
# Name: Yards, dtype: float64
# 2532888
# count    22.0
# mean      0.0
# std       0.0
# min       0.0
# 25%       0.0
# 50%       0.0
# 75%       0.0
# max       0.0
# Name: Yards, dtype: float64
# 2560888
# count    22.0
# mean     -1.0
# std       0.0
# min      -1.0
# 25%      -1.0
# 50%      -1.0
# 75%      -1.0
# max      -1.0
# Name: Yards, dtype: float64
# 2505996
# count    22.0
# mean      0.0
# std       0.0
# min       0.0
# 25%       0.0
# 50%       0.0
# 75%       0.0
# max       0.0
# Name: Yards, dtype: float64
# 2555317
# count    22.0
# mean     16.0
# std       0.0
# min      16.0
# 25%      16.0
# 50%      16.0
# 75%      16.0
# max      16.0
# Name: Yards, dtype: float64
# 2555333
# count    22.0
# mean      5.0
# std       0.0
# min       5.0
# 25%       5.0
# 50%       5.0
# 75%       5.0
# max       5.0
# Name: Yards, dtype: float64
# 2507763
# count    22.0
# mean      4.0
# std       0.0
# min       4.0
# 25%       4.0
# 50%       4.0
# 75%       4.0
# max       4.0
# Name: Yards, dtype: float64
# 497224
# count    22.0
# mean      9.0
# std       0.0
# min       9.0
# 25%       9.0
# 50%       9.0
# 75%       9.0
# max       9.0
# Name: Yards, dtype: float64
# 2543475
# count    22.0
# mean     17.0
# std       0.0
# min      17.0
# 25%      17.0
# 50%      17.0
# 75%      17.0
# max      17.0
# Name: Yards, dtype: float64
# 2543491
# count    22.0
# mean      7.0
# std       0.0
# min       7.0
# 25%       7.0
# 50%       7.0
# 75%       7.0
# max       7.0
# Name: Yards, dtype: float64
# 2557866
# count    22.0
# mean     -4.0
# std       0.0
# min      -4.0
# 25%      -4.0
# 50%      -4.0
# 75%      -4.0
# max      -4.0
# Name: Yards, dtype: float64
# 2495234
# count    22.0
# mean      0.0
# std       0.0
# min       0.0
# 25%       0.0
# 50%       0.0
# 75%       0.0
# max       0.0
# Name: Yards, dtype: float64
# 2506931
# count    22.0
# mean      1.0
# std       0.0
# min       1.0
# 25%       1.0
# 50%       1.0
# 75%       1.0
# max       1.0
# Name: Yards, dtype: float64
# 2558266
# count    22.0
# mean     10.0
# std       0.0
# min      10.0
# 25%      10.0
# 50%      10.0
# 75%      10.0
# max      10.0
# Name: Yards, dtype: float64
# 2535869
# count    22.0
# mean    -11.0
# std       0.0
# min     -11.0
# 25%     -11.0
# 50%     -11.0
# 75%     -11.0
# max     -11.0
# Name: Yards, dtype: float64
# 2557863
# count    22.0
# mean      0.0
# std       0.0
# min       0.0
# 25%       0.0
# 50%       0.0
# 75%       0.0
# max       0.0
# Name: Yards, dtype: float64
# 2543477
# count    22.0
# mean      4.0
# std       0.0
# min       4.0
# 25%       4.0
# 50%       4.0
# 75%       4.0
# max       4.0
# Name: Yards, dtype: float64
# 2543499
# count    22.0
# mean      0.0
# std       0.0
# min       0.0
# 25%       0.0
# 50%       0.0
# 75%       0.0
# max       0.0
# Name: Yards, dtype: float64
# 2560747
# count    22.0
# mean      0.0
# std       0.0
# min       0.0
# 25%       0.0
# 50%       0.0
# 75%       0.0
# max       0.0
# Name: Yards, dtype: float64
# 2557922
# count    22.0
# mean      0.0
# std       0.0
# min       0.0
# 25%       0.0
# 50%       0.0
# 75%       0.0
# max       0.0
# Name: Yards, dtype: float64
# 2557986
# count    22.0
# mean      1.0
# std       0.0
# min       1.0
# 25%       1.0
# 50%       1.0
# 75%       1.0
# max       1.0
# Name: Yards, dtype: float64
# 2543801
# count    22.0
# mean      0.0
# std       0.0
# min       0.0
# 25%       0.0
# 50%       0.0
# 75%       0.0
# max       0.0
# Name: Yards, dtype: float64
# 2541834
# count    22.0
# mean     -8.0
# std       0.0
# min      -8.0
# 25%      -8.0
# 50%      -8.0
# 75%      -8.0
# max      -8.0
# Name: Yards, dtype: float64
# 2505076
# count    22.0
# mean      0.0
# std       0.0
# min       0.0
# 25%       0.0
# 50%       0.0
# 75%       0.0
# max       0.0
# Name: Yards, dtype: float64
# 81284
# count    22.0
# mean      0.0
# std       0.0
# min       0.0
# 25%       0.0
# 50%       0.0
# 75%       0.0
# max       0.0
# Name: Yards, dtype: float64
# 2532903
# count    22.0
# mean     -3.0
# std       0.0
# min      -3.0
# 25%      -3.0
# 50%      -3.0
# 75%      -3.0
# max      -3.0
# Name: Yards, dtype: float64
# 2552576
# count    22.0
# mean      0.0
# std       0.0
# min       0.0
# 25%       0.0
# 50%       0.0
# 75%       0.0
# max       0.0
# Name: Yards, dtype: float64
# 2556404
# count    22.0
# mean      4.0
# std       0.0
# min       4.0
# 25%       4.0
# 50%       4.0
# 75%       4.0
# max       4.0
# Name: Yards, dtype: float64
# 2543828
# count    22.0
# mean      0.0
# std       0.0
# min       0.0
# 25%       0.0
# 50%       0.0
# 75%       0.0
# max       0.0
# Name: Yards, dtype: float64
# 2506147
# count    22.0
# mean      2.0
# std       0.0
# min       2.0
# 25%       2.0
# 50%       2.0
# 75%       2.0
# max       2.0
# Name: Yards, dtype: float64
# 2555419
# count    22.0
# mean      6.0
# std       0.0
# min       6.0
# 25%       6.0
# 50%       6.0
# 75%       6.0
# max       6.0
# Name: Yards, dtype: float64
# 2558063
# count    22.0
# mean      0.0
# std       0.0
# min       0.0
# 25%       0.0
# 50%       0.0
# 75%       0.0
# max       0.0
# Name: Yards, dtype: float64
# 2540173
# count    22.0
# mean      0.0
# std       0.0
# min       0.0
# 25%       0.0
# 50%       0.0
# 75%       0.0
# max       0.0
# Name: Yards, dtype: float64
# 2556855
# count    22.0
# mean     -2.0
# std       0.0
# min      -2.0
# 25%      -2.0
# 50%      -2.0
# 75%      -2.0
# max      -2.0
# Name: Yards, dtype: float64
# 2539235
# count    22.0
# mean     11.0
# std       0.0
# min      11.0
# 25%      11.0
# 50%      11.0
# 75%      11.0
# max      11.0
# Name: Yards, dtype: float64
# 2555346
# count    22.0
# mean      5.0
# std       0.0
# min       5.0
# 25%       5.0
# 50%       5.0
# 75%       5.0
# max       5.0
# Name: Yards, dtype: float64
# 2556661
# count    22.0
# mean     -1.0
# std       0.0
# min      -1.0
# 25%      -1.0
# 50%      -1.0
# 75%      -1.0
# max      -1.0
# Name: Yards, dtype: float64
# 2553499
# count    22.0
# mean     12.0
# std       0.0
# min      12.0
# 25%      12.0
# 50%      12.0
# 75%      12.0
# max      12.0
# Name: Yards, dtype: float64
# 2558956
# count    22.0
# mean      5.0
# std       0.0
# min       5.0
# 25%       5.0
# 50%       5.0
# 75%       5.0
# max       5.0
# Name: Yards, dtype: float64
# 2560847
# count    22.0
# mean      0.0
# std       0.0
# min       0.0
# 25%       0.0
# 50%       0.0
# 75%       0.0
# max       0.0
# Name: Yards, dtype: float64
# 2552408
# count    22.0
# mean     21.0
# std       0.0
# min      21.0
# 25%      21.0
# 50%      21.0
# 75%      21.0
# max      21.0
# Name: Yards, dtype: float64
# 2540165
# count    22.0
# mean     -7.0
# std       0.0
# min      -7.0
# 25%      -7.0
# 50%      -7.0
# 75%      -7.0
# max      -7.0
# Name: Yards, dtype: float64
# 2560836
# count    22.0
# mean     -2.0
# std       0.0
# min      -2.0
# 25%      -2.0
# 50%      -2.0
# 75%      -2.0
# max      -2.0
# Name: Yards, dtype: float64
# 2550400
# count    22.0
# mean      0.0
# std       0.0
# min       0.0
# 25%       0.0
# 50%       0.0
# 75%       0.0
# max       0.0
# Name: Yards, dtype: float64
# 2553896
# count    22.0
# mean      2.0
# std       0.0
# min       2.0
# 25%       2.0
# 50%       2.0
# 75%       2.0
# max       2.0
# Name: Yards, dtype: float64
# 2550256
# count    22.0
# mean     13.0
# std       0.0
# min      13.0
# 25%      13.0
# 50%      13.0
# 75%      13.0
# max      13.0
# Name: Yards, dtype: float64
# 2543509
# count    22.0
# mean      9.0
# std       0.0
# min       9.0
# 25%       9.0
# 50%       9.0
# 75%       9.0
# max       9.0
# Name: Yards, dtype: float64
# 2504775
# count    22.0
# mean      0.0
# std       0.0
# min       0.0
# 25%       0.0
# 50%       0.0
# 75%       0.0
# max       0.0
# Name: Yards, dtype: float64

# %%
今までにmax距離、最頻距離、平均、は使えるかも、平均や標準偏差は同じっポイ
新しく出現した場合は、平均で補完とか？

あとは、そもそものrusher回数、これは経験数という特徴になりそう

# %%
# playerの属性情報をクラスタリング（これも未来の情報を含めてしまっている）
from sklearn.cluster import KMeans
def height2cm(h):
    return int(h[0]) * 30.48 + int(h[2]) * 2.58

cols_player = ['NflId','PlayerHeight', 'PlayerWeight', 'S', 'A']
df_player = train[cols_player]
df_player['PlayerHeight'] = df_player['PlayerHeight'].apply(height2cm)
df_player = df_player.groupby('NflId').agg({'PlayerHeight':['max'], 'PlayerWeight':['max'], 'S':['max','mean'], 'A':['max','mean']})
df_player.columns = ['PlayerHeight','PlayerWeight','S_max','S_mean','A_max','A_mean']

scaler_player = StandardScaler()
df_player.loc[:,:] = scaler_player.fit_transform(df_player)
kmeans = KMeans(n_clusters=5).fit(df_player)
df_player = pd.DataFrame({'NflId':df_player.index, 'class_player': kmeans.labels_}).set_index('NflId')
train = pd.merge(train, df_player, on='NflId', how='outer')
train
# Out:
#             GameId          PlayId  Team       X      Y     S     A   Dis  \
# 0       2017090700  20170907000118  away   46.09  34.84  1.69  1.13  0.40
efendersInTheBox  DefensePersonnel PlayDirection  \
# 0                     6.0  2 DL, 3 LB, 6 DB          left
# 1                     6.0  2 DL, 3 LB, 6 DB          left
# 2                     7.0  2 DL, 3 LB, 6 DB          left
# 3                     9.0  4 DL, 4 LB, 3 DB          left
# 4                     5.0  2 DL, 3 LB, 6 DB          left
# ...                   ...               ...           ...
# 509757                8.0  4 DL, 3 LB, 4 DB         right
# 509758                8.0  4 DL, 3 LB, 4 DB         right
# 509759                7.0  4 DL, 2 LB, 5 DB         right
# 509760                7.0  4 DL, 2 LB, 5 DB          left
# 509761                7.0  4 DL, 2 LB, 5 DB          left
#
#                      TimeHandoff                  TimeSnap  Yards  \
# 0       2017-09-08T00:44:06.000Z  2017-09-08T00:44:05.000Z      8
# 1       2017-09-08T00:44:27.000Z  2017-09-08T00:44:26.000Z      3
# 2       2017-09-08T00:45:17.000Z  2017-09-08T00:45:15.000Z      5
# 3       2017-09-08T00:48:41.000Z  2017-09-08T00:48:39.000Z      2
# 4       2017-09-08T00:55:46.000Z  2017-09-08T00:55:45.000Z     10
# ...                          ...                       ...    ...
# 509757  2018-12-30T23:55:04.000Z  2018-12-30T23:55:03.000Z      0
# 509758  2018-12-31T00:03:48.000Z  2018-12-31T00:03:46.000Z     -2
# 509759  2018-12-30T21:47:13.000Z  2018-12-30T21:47:12.000Z      3
# 509760  2018-12-31T00:11:55.000Z  2018-12-31T00:11:54.000Z      5
# 509761  2018-12-31T00:12:36.000Z  2018-12-31T00:12:35.000Z      4
#
#        PlayerHeight  PlayerWeight PlayerBirthDate PlayerCollegeName Position  \
# 0               6-0           212      12/29/1988         Tennessee       SS
# 1               6-0           212      12/29/1988         Tennessee       SS
# 2               6-0           212      12/29/1988         Tennessee       SS
# 3               6-0           212      12/29/1988         Tennessee       SS
# 4               6-0           212      12/29/1988         Tennessee       SS
# ...             ...           ...             ...               ...      ...
# 509757          6-3           307      05/31/1993              Utah       DT
# 509758          6-3           307      05/31/1993              Utah       DT
# 509759          6-2           196      10/12/1995               LSU       WR
# 509760          6-2           196      10/12/1995               LSU       WR
# 509761          6-2           196      10/12/1995               LSU       WR
#
#        HomeTeamAbbr VisitorTeamAbbr  Week            Stadium        Location  \
# 0                NE              KC     1   Gillette Stadium  Foxborough, MA
# 1                NE              KC     1   Gillette Stadium  Foxborough, MA
# 2                NE              KC     1   Gillette Stadium  Foxborough, MA
# 3                NE              KC     1   Gillette Stadium  Foxborough, MA
# 4                NE              KC     1   Gillette Stadium  Foxborough, MA
# ...             ...             ...   ...                ...             ...
# 509757          SEA             ARI    17  CenturyLink Field     Seattle, WA
# 509758          SEA             ARI    17  CenturyLink Field     Seattle, WA
# 509759          SEA             ARI    17  CenturyLink Field     Seattle, WA
# 509760          SEA             ARI    17  CenturyLink Field     Seattle, WA
# 509761          SEA             ARI    17  CenturyLink Field     Seattle, WA
#
#        StadiumType        Turf     GameWeather  Temperature  Humidity  \
# 0          Outdoor  Field Turf  Clear and warm         63.0      77.0
# 1          Outdoor  Field Turf  Clear and warm         63.0      77.0
# 2          Outdoor  Field Turf  Clear and warm         63.0      77.0
# 3          Outdoor  Field Turf  Clear and warm         63.0      77.0
# 4          Outdoor  Field Turf  Clear and warm         63.0      77.0
# ...            ...         ...             ...          ...       ...
# 509757     Outdoor   FieldTurf          Cloudy         45.0      76.0
# 509758     Outdoor   FieldTurf          Cloudy         45.0      76.0
# 509759     Outdoor   FieldTurf          Cloudy         45.0      76.0
# 509760     Outdoor   FieldTurf          Cloudy         45.0      76.0
# 509761     Outdoor   FieldTurf          Cloudy         45.0      76.0
#
#        WindSpeed WindDirection  cnt_Rusher  class_player_x  class_player_y
# 0              8            SW         NaN               0               0
# 1              8            SW         NaN               0               0
# 2              8            SW         NaN               0               0
# 3              8            SW         NaN               0               0
# 4              8            SW         NaN               0               0
# ...          ...           ...         ...             ...             ...
# 509757         5            SE         NaN               4               1
# 509758         5            SE         NaN               4               1
# 509759         5            SE         NaN               3               3
# 509760         5            SE         NaN               3               3
# 509761         5            SE         NaN               3               3
#
# [509762 rows x 52 columns]

# %%
df_player
# Out:
#          class_player
# NflId
# 222                 4
# 234                 4
# 238                 1
# 252                 4
# 262                 2
# ...               ...
# 2561544             1
# 2561624             4
# 2561644             4
# 2561653             3
# 2561671             3
#
# [2231 rows x 1 columns]

# %%
dict_player_class = dict(df_player.iloc[:,0])
# Out:
# {222: 4,
#  234: 4,
#  238: 1,
#  252: 4,
#  262: 2,
#  264: 4,
#  276: 4,
#  284: 4,
#  306: 4,
#  310: 0,
#  382: 4,
#  744: 1,
#  758: 1,
#  786: 1,
#  808: 1,
#  925: 3,
#  949: 2,
#  1032: 0,
#  1062: 1,
#  1302: 0,
#  1330: 4,
#  1344: 1,
#  1581: 3,
#  1681: 4,
#  1974: 2,
#  2307: 2,
#  2346: 3,
#  2354: 0,
#  2649: 3,
#  4327: 4,
#  4365: 0,
#  4483: 4,
#  4485: 1,
#  4487: 4,
#  71193: 1,
#  71197: 4,
#  71211: 1,
#  71217: 4,
#  71249: 4,
#  71251: 2,
#  71265: 0,
#  71269: 0,
#  71363: 1,
#  71375: 1,
#  71423: 4,
#  71435: 4,
#  71441: 0,
#  71461: 1,
#  71465: 1,
#  71493: 1,
#  71523: 1,
#  79583: 1,
#  79607: 3,
#  79611: 1,
#  79844: 4,
#  79848: 0,
#  79852: 4,
#  79858: 4,
#  79860: 0,
#  79897: 2,
#  79899: 2,
#  79901: 2,
#  80421: 1,
#  80427: 3,
#  80429: 0,
#  80431: 0,
#  80668: 0,
#  80670: 4,
#  81284: 4,
#  81294: 4,
#  81306: 3,
#  81821: 1,
#  81871: 1,
#  81879: 2,
#  89746: 1,
#  89756: 2,
#  89758: 1,
#  238227: 4,
#  238457: 4,
#  238466: 2,
#  238498: 3,
#  494254: 4,
#  494257: 4,
#  494259: 4,
#  494261: 2,
#  494277: 4,
#  494287: 2,
#  494289: 2,
#  494307: 2,
#  494317: 2,
#  494323: 2,
#  496723: 0,
#  496727: 0,
#  496733: 2,
#  496735: 2,
#  496739: 4,
#  496760: 1,
#  496762: 1,
#  496780: 1,
#  496782: 4,
#  496788: 4,
#  496790: 4,
#  496794: 1,
#  496796: 4,
#  496802: 1,
#  496814: 4,
#  496816: 1,
#  496822: 1,
#  496825: 1,
#  496828: 4,
#  496841: 1,
#  496843: 4,
#  496861: 1,
#  496865: 1,
#  496881: 1,
#  496937: 4,
#  496961: 4,
#  496963: 4,
#  496980: 1,
#  496988: 1,
#  497012: 1,
#  497016: 1,
#  497018: 1,
#  497026: 1,
#  497028: 0,
#  497030: 1,
#  497032: 1,
#  497042: 1,
#  497048: 1,
#  497061: 1,
#  2550145: 4,
#  2550150: 1,
#  2550154: 1,
#  2550155: 1,
#  2550160: 1,
#  2550163: 3,
#  2550164: 0,
#  2550166: 1,
#  2550167: 4,
#  2550169: 1,
#  2550189: 3,
#  2550198: 0,
#  2550205: 1,
#  2550206: 0,
#  2550208: 1,
#  2550210: 1,
#  2550221: 1,
#  2550223: 4,
#  2550230: 1,
#  2550235: 2,
#  2550242: 1,
#  2550246: 3,
#  2550256: 3,
#  2550257: 4,
#  2550262: 4,
#  2550267: 1,
#  2550268: 2,
#  2550272: 3,
#  2550277: 1,
#  2550284: 0,
#  2550285: 4,
#  2550289: 3,
#  2550312: 1,
#  2550313: 4,
#  2550328: 4,
#  2550353: 3,
#  2550361: 1,
#  2550365: 4,
#  2550398: 1,
#  2550400: 0,
#  2550404: 1,
#  2550405: 4,
#  2550416: 1,
#  2550433: 1,
#  2550435: 1,
#  2550437: 1,
#  2550449: 1,
#  2550460: 1,
#  2550462: 1,
#  2550468: 4,
#  2550481: 2,
#  2550489: 1,
#  2550493: 1,
#  2550495: 1,
#  2550503: 1,
#  2550512: 3,
#  2550521: 4,
#  2550528: 1,
#  2550532: 1,
#  2550541: 0,
#  2550542: 3,
#  2550549: 1,
#  2550559: 1,
#  2550561: 1,
#  2550562: 1,
#  2550565: 0,
#  2550569: 1,
#  2550572: 0,
#  2550575: 1,
#  2550589: 1,
#  2550597: 0,
#  2550599: 4,
#  2550605: 2,
#  2550606: 1,
#  2550613: 2,
#  2550617: 3,
#  2550628: 4,
#  2550631: 4,
#  2550633: 3,
#  2550646: 1,
#  2550647: 4,
#  2550654: 0,
#  2550656: 0,
#  2550658: 3,
#  2550659: 2,
#  2550738: 3,
#  2550767: 4,
#  2550842: 2,
#  2550930: 0,
#  2551359: 4,
#  2552032: 1,
#  2552033: 4,
#  2552240: 1,
#  2552245: 1,
#  2552255: 0,
#  2552259: 4,
#  2552261: 0,
#  2552262: 0,
#  2552263: 2,
#  2552265: 0,
#  2552266: 4,
#  2552268: 1,
#  2552271: 1,
#  2552272: 1,
#  2552273: 4,
#  2552276: 4,
#  2552277: 1,
#  ...}

# %%
train[train.NflId==train.NflIdRusher][[,'Orientation']]
# Out:
# 5057      350.53
# 7791       80.67
# 7794       74.58
# 7796       93.08
# 8254      261.55
#            ...
# 509736    158.17
# 509737    222.95
# 509738    335.55
# 509739    236.67
# 509740    329.62
# Name: Orientation, Length: 23171, dtype: float64

# %%
 def new_X(x_coordinate, play_direction):
        if play_direction == 'left':
            return 120.0 - x_coordinate
        else:
            return x_coordinate

def new_line(rush_team, field_position, yardline):
    """そもそもYardLineはX座標ではないので、プレー方向からX座標に変換"""
    if rush_team == field_position:
        # offense starting at X = 0 plus the 10 yard endzone plus the line of scrimmage
        return 10.0 + yardline
    else:
        # half the field plus the yards between midfield and the line of scrimmage
        return 60.0 + (50 - yardline)

def new_orientation(angle, play_direction):
    if play_direction == 'left':
        new_angle = 360.0 - angle
        if new_angle == 360.0:
            new_angle = 0.0
        return new_angle
    else:
        return angle

def euclidean_distance(x1,y1,x2,y2):
    x_diff = (x1-x2)**2
    y_diff = (y1-y2)**2

    return np.sqrt(x_diff + y_diff)

def back_direction(orientation):
    """今、左に進むのを正としてとっているので"""
    if orientation > 180.0:
        return 1
    else:
        return 0

def update_yardline(df):
    new_yardline = df[df['NflId'] == df['NflIdRusher']]
    new_yardline['YardLine'] = new_yardline[['PossessionTeam','FieldPosition','YardLine']].apply(lambda x: new_line(x[0],x[1],x[2]), axis=1)
    new_yardline = new_yardline[['GameId','PlayId','YardLine']]

    return new_yardline

def update_orientation(df, yardline):
    df['X'] = df[['X','PlayDirection']].apply(lambda x: new_X(x[0],x[1]), axis=1)
    df['Orientation'] = df[['Orientation','PlayDirection']].apply(lambda x: new_orientation(x[0],x[1]), axis=1)
    df['Dir'] = df[['Dir','PlayDirection']].apply(lambda x: new_orientation(x[0],x[1]), axis=1)

    df = df.drop('YardLine', axis=1)
    df = pd.merge(df, yardline, on=['GameId','PlayId'], how='inner')

    return df

# %%
def defense_features(df):
    
    yardline = update_yardline(df)
    df = update_orientation(df, yardline)
    
    rusher = df[df['NflId'] == df['NflIdRusher']][['GameId','PlayId','Team','X','Y','Dir']]
    rusher.columns = ['GameId','PlayId','RusherTeam','RusherX','RusherY','Rusher_Dir']

    df = pd.merge(df,rusher,on=['GameId','PlayId'],how='inner')
    
    defense = df[df['Team'] != df['RusherTeam']][['GameId','PlayId','X','Y','RusherX','RusherY','S','A','Dis','Orientation','Dir']]  # 11人
    offense = df[(df['Team'] == df['RusherTeam']) & (df['NflId'] == df['NflIdRusher'])][['GameId','PlayId','X','Y','RusherX','RusherY','S','A','Dis','Orientation','Dir']]  # 10人
    
    defense['def_dist'] = defense[['X','Y','RusherX','RusherY']].apply(lambda x: euclidean_distance(x[0],x[1],x[2],x[3]), axis=1)
    defense['DirDiff_from_rusher'] = abs((360 - defense['Rusher_Dir']) - defense['Dir'])
    
    
    offense['off_dist'] = defense[['X','Y','RusherX','RusherY']].apply(lambda x: euclidean_distance(x[0],x[1],x[2],x[3]), axis=1)
    
    
    
    defense = defense.groupby(['GameId','PlayId'])\
                     .agg({'def_dist_to_back':['min','max','mean','std']})\
                     .reset_index()
    defense.columns = ['GameId','PlayId','def_min_dist','def_max_dist','def_mean_dist','def_std_dist']

    return defense

# %%
yardline = update_yardline(train)
df = update_orientation(train, yardline)

rusher = df[df['NflId'] == df['NflIdRusher']][['GameId','PlayId','Team','X','Y','Dir']]
rusher.columns = ['GameId','PlayId','RusherTeam','RusherX','RusherY','Rusher_Dir']

# %%
if rusher.Rusher_Dir 
rusher
# Out:
#             GameId          PlayId RusherTeam  RusherX  RusherY  Rusher_Dir
# 18      2017090700  20170907000118       home    41.25    30.53      114.26
# 40      2017090700  20170907000139       home    48.93    27.16       47.80
# 62      2017090700  20170907000189       home    71.34    19.11      138.04
# 87      2017090700  20170907000345       home   104.47    25.36       84.56
# 105     2017090700  20170907000473       home    77.12    22.73       40.33
# ...            ...             ...        ...      ...      ...         ...
# 509669  2017111911  20171119113256       home    60.54    30.94      115.79
# 509690  2017111911  20171119113634       home    72.05    23.53      153.48
# 509712  2017111911  20171119113676       home    71.75    29.19      105.18
# 509734  2017111911  20171119113882       home    43.80    29.03      128.32
# 509757  2017111911  20171119111058       home    28.31    27.90       64.11
#
# [23171 rows x 6 columns]

# %%
outcomes = train[['GameId','PlayId','Yards']].drop_duplicates()

# %%
# evaluation metric
def crps(y_true, y_pred):
    y_true = np.clip(np.cumsum(y_true, axis=1), 0, 1)
    y_pred = np.clip(np.cumsum(y_pred, axis=1), 0, 1)
    return ((y_true - y_pred) ** 2).sum(axis=1).sum(axis=0) / (199 * y_true.shape[0])

# %%
# author : nlgn
# Link : https://www.kaggle.com/kingychiu/keras-nn-starter-crps-early-stopping
class Metric(Callback):
    def __init__(self, model, callbacks, data):
        super().__init__()
        self.model = model
        self.callbacks = callbacks
        self.data = data

    def on_train_begin(self, logs=None):
        for callback in self.callbacks:
            callback.on_train_begin(logs)

    def on_train_end(self, logs=None):
        for callback in self.callbacks:
            callback.on_train_end(logs)

    def on_epoch_end(self, batch, logs=None):
        X_train, y_train = self.data[0][0], self.data[0][1]
        y_pred = self.model.predict(X_train)
        y_true = np.clip(np.cumsum(y_train, axis=1), 0, 1)
        y_pred = np.clip(np.cumsum(y_pred, axis=1), 0, 1)
        tr_s = ((y_true - y_pred) ** 2).sum(axis=1).sum(axis=0) / (199 * X_train[-1].shape[0])
        tr_s = np.round(tr_s, 6)
        logs['tr_CRPS'] = tr_s

        X_valid, y_valid = self.data[1][0], self.data[1][1]

        y_pred = self.model.predict(X_valid)
        y_true = np.clip(np.cumsum(y_valid, axis=1), 0, 1)
        y_pred = np.clip(np.cumsum(y_pred, axis=1), 0, 1)
        val_s = ((y_true - y_pred) ** 2).sum(axis=1).sum(axis=0) / (199 * X_valid[-1].shape[0])
        val_s = np.round(val_s, 6)
        logs['val_CRPS'] = val_s
        print('tr CRPS', tr_s, 'val CRPS', val_s)

        for callback in self.callbacks:
            callback.on_epoch_end(batch, logs)

# %%
# author : ryancaldwell
# Link : https://www.kaggle.com/ryancaldwell/location-eda
def create_features(df, deploy=False):
    def new_X(x_coordinate, play_direction):
        if play_direction == 'left':
            return 120.0 - x_coordinate
        else:
            return x_coordinate

    def new_line(rush_team, field_position, yardline):
        """そもそもYardLineはX座標ではないので、プレー方向からX座標に変換"""
        if rush_team == field_position:
            # offense starting at X = 0 plus the 10 yard endzone plus the line of scrimmage
            return 10.0 + yardline
        else:
            # half the field plus the yards between midfield and the line of scrimmage
            return 60.0 + (50 - yardline)

    def new_orientation(angle, play_direction):
        if play_direction == 'left':
            new_angle = 360.0 - angle
            if new_angle == 360.0:
                new_angle = 0.0
            return new_angle
        else:
            return angle

    def euclidean_distance(x1,y1,x2,y2):
        x_diff = (x1-x2)**2
        y_diff = (y1-y2)**2

        return np.sqrt(x_diff + y_diff)

    def back_direction(orientation):
        """今、左に進むのを正としてとっているので"""
        if orientation > 180.0:
            return 1
        else:
            return 0

    def update_yardline(df):
        new_yardline = df[df['NflId'] == df['NflIdRusher']]
        new_yardline['YardLine'] = new_yardline[['PossessionTeam','FieldPosition','YardLine']].apply(lambda x: new_line(x[0],x[1],x[2]), axis=1)
        new_yardline = new_yardline[['GameId','PlayId','YardLine']]

        return new_yardline

    def update_orientation(df, yardline):
        df['X'] = df[['X','PlayDirection']].apply(lambda x: new_X(x[0],x[1]), axis=1)
        df['Orientation'] = df[['Orientation','PlayDirection']].apply(lambda x: new_orientation(x[0],x[1]), axis=1)
        df['Dir'] = df[['Dir','PlayDirection']].apply(lambda x: new_orientation(x[0],x[1]), axis=1)

        df = df.drop('YardLine', axis=1)
        df = pd.merge(df, yardline, on=['GameId','PlayId'], how='inner')

        return df

    def back_features(df):
        carriers = df[df['NflId'] == df['NflIdRusher']][['GameId','PlayId','NflIdRusher','X','Y','Orientation','Dir','YardLine']]
        carriers['back_from_scrimmage'] = carriers['YardLine'] - carriers['X']
        carriers['back_oriented_down_field'] = carriers['Orientation'].apply(lambda x: back_direction(x))
        carriers['back_moving_down_field'] = carriers['Dir'].apply(lambda x: back_direction(x))
        carriers = carriers.rename(columns={'X':'back_X',
                                            'Y':'back_Y'})
        carriers = carriers[['GameId','PlayId','NflIdRusher','back_X','back_Y','back_from_scrimmage','back_oriented_down_field','back_moving_down_field']]

        return carriers

    def features_relative_to_back(df, carriers):
        """rusher(back_X, back_Y)からの全ての選手の距離の集計量"""
        player_distance = df[['GameId','PlayId','NflId','X','Y']]
        player_distance = pd.merge(player_distance, carriers, on=['GameId','PlayId'], how='inner')
        player_distance = player_distance[player_distance['NflId'] != player_distance['NflIdRusher']] # Rusher以外
        player_distance['dist_to_back'] = player_distance[['X','Y','back_X','back_Y']].apply(lambda x: euclidean_distance(x[0],x[1],x[2],x[3]), axis=1)

        player_distance = player_distance.groupby(['GameId','PlayId','back_from_scrimmage','back_oriented_down_field','back_moving_down_field'])\
                                         .agg({'dist_to_back':['min','max','mean','std']})\
                                         .reset_index()
        player_distance.columns = ['GameId','PlayId','back_from_scrimmage','back_oriented_down_field','back_moving_down_field',
                                   'min_dist','max_dist','mean_dist','std_dist']

        return player_distance

    
#     def defense_features(df):
#         rusher = df[df['NflId'] == df['NflIdRusher']][['GameId','PlayId','Team','X','Y']]
#         rusher.columns = ['GameId','PlayId','RusherTeam','RusherX','RusherY']

#         df = pd.merge(df,rusher,on=['GameId','PlayId'],how='inner')
#         defense = df[df['Team'] != df['RusherTeam']][['GameId','PlayId','X','Y','RusherX','RusherY','S','A','Dis','Orientation','Dir']]
#         defense['def_dist_to_back'] = defense[['X','Y','RusherX','RusherY']].apply(lambda x: euclidean_distance(x[0],x[1],x[2],x[3]), axis=1)

#         defense = defense.groupby(['GameId','PlayId'])\
#                          .agg({'def_dist_to_back':['min','max','mean','std']})\
#                          .reset_index()
#         defense.columns = ['GameId','PlayId','def_min_dist','def_max_dist','def_mean_dist','def_std_dist']
        
#         return defense
    
    
    def add_features(df):
        rusher = df[df['NflId'] == df['NflIdRusher']][['GameId','PlayId','Team','X','Y']]
        rusher.columns = ['GameId','PlayId','RusherTeam','RusherX','RusherY']

        df = pd.merge(df,rusher,on=['GameId','PlayId'],how='inner')
        df['dist_from_rusher'] = df[['X','Y','RusherX','RusherY']].apply(lambda x: euclidean_distance(x[0],x[1],x[2],x[3]), axis=1)
        df = df.sort_values(by=['GameId','PlayId','dist_from_rusher'])
        
        defense_summary = df[df['Team'] != df['RusherTeam']].groupby(['GameId','PlayId'])\
                         .agg({'dist_from_rusher':['min','max','mean','std']})\
                         .reset_index()
        defense_summary.columns = ['GameId','PlayId','def_min_dist','def_max_dist','def_mean_dist','def_std_dist']
        
#         defense_closest = df[df['Team'] != df['RusherTeam']][::11][['GameId','PlayId','X','Y','S','A','Dis','Orientation','Dir']]  # Rusherに最も近いDefense
#         defense_closest.columns = ['GameId','PlayId','X_def_closest','Y_def_closest','S_def_closest','A_def_closest','Dis_def_closest','Orientation_def_closest','Dir_def_closest']
        
#         offense_closest = df[df['Team'] == df['RusherTeam']][1::11][['GameId','PlayId','X','Y','S','A','Dis','Orientation','Dir']]  # Rusherに最も近いOffense
#         offense_closest.columns = ['GameId','PlayId','X_off_closest','Y_off_closest','S_off_closest','A_off_closest','Dis_off_closest','Orientation_off_closest','Dir_def_closest']
        
#         df_nn = pd.merge(defense_summary, defense_closest, on=['GameId','PlayId'], how='inner')
#         df_nn = pd.merge(df_nn, offense_closest, on=['GameId','PlayId'], how='inner')
        
#         # Rusherのボロノイ領域を計算して特徴量を作成
#         # RusherがPlayIdの中で最も上に並ぶようにソート
#         # ソートしてから、ボロノイ領域を計算
#         vor = df.groupby(['GameId','PlayId'])[['X','Y']].apply(Voronoi)

#         # Rusherのボロノイ領域の面積
#         def PolyArea(arr):
#             x = arr[:,0]
#             y = arr[:,1]
#             return 0.5*np.abs(np.dot(x,np.roll(y,1))-np.dot(y,np.roll(x,1)))

#         df_nn['X_maxInVoronoi'] = 0
#         df_nn['X_minInVoronoi'] = 0
#         df_nn['AreaInVoronoi'] = 0
#         for i, playid in enumerate(list(df_nn['PlayId'].unique())):
#             df_nn.loc[df_nn['PlayId']==playid, 'X_maxInVoronoi'] = vor.iloc[i].vertices[vor.iloc[i].regions[vor.iloc[i].point_region[0]]][:,0].max()  # Rusherのボロノイ領域の最大のx座標
#             df_nn.loc[df_nn['PlayId']==playid, 'X_minInVoronoi'] = vor.iloc[i].vertices[vor.iloc[i].regions[vor.iloc[i].point_region[0]]][:,0].min()  # Rusherのボロノイ領域の最小のx座標
#             df_nn.loc[df_nn['PlayId']==playid, 'AreaInVoronoi'] = PolyArea(vor.iloc[i].vertices[vor.iloc[i].regions[vor.iloc[i].point_region[0]]])  # Rusherのボロノイ領域の面積
    
        return defense_summary
    
        
    
    def static_features(df):
        # Rusherの属性情報
        static_features = df[df['NflId'] == df['NflIdRusher']][['GameId','PlayId','X','Y','S','A','Dis','Orientation','Dir',
                                                            'YardLine','Quarter','Down','Distance','DefendersInTheBox']].drop_duplicates()
        static_features['DefendersInTheBox'] = static_features['DefendersInTheBox'].fillna(np.mean(static_features['DefendersInTheBox']))

        return static_features
    
    def split_personnel(s):
        splits = s.split(',')
        for i in range(len(splits)):
            splits[i] = splits[i].strip()

        return splits

    def defense_formation(l):
        dl = 0
        lb = 0
        db = 0
        other = 0

        for position in l:
            sub_string = position.split(' ')
            if sub_string[1] == 'DL':
                dl += int(sub_string[0])
            elif sub_string[1] in ['LB','OL']:
                lb += int(sub_string[0])
            else:
                db += int(sub_string[0])

        counts = (dl,lb,db,other)

        return counts

    def offense_formation(l):
        qb = 0
        rb = 0
        wr = 0
        te = 0
        ol = 0

        sub_total = 0
        qb_listed = False
        for position in l:
            sub_string = position.split(' ')
            pos = sub_string[1]
            cnt = int(sub_string[0])

            if pos == 'QB':
                qb += cnt
                sub_total += cnt
                qb_listed = True
            # Assuming LB is a line backer lined up as full back
            elif pos in ['RB','LB']:
                rb += cnt
                sub_total += cnt
            # Assuming DB is a defensive back and lined up as WR
            elif pos in ['WR','DB']:
                wr += cnt
                sub_total += cnt
            elif pos == 'TE':
                te += cnt
                sub_total += cnt
            # Assuming DL is a defensive lineman lined up as an additional line man
            else:
                ol += cnt
                sub_total += cnt

        # If not all 11 players were noted at given positions we need to make some assumptions
        # I will assume if a QB is not listed then there was 1 QB on the play
        # If a QB is listed then I'm going to assume the rest of the positions are at OL
        # This might be flawed but it looks like RB, TE and WR are always listed in the personnel
        if sub_total < 11:
            diff = 11 - sub_total
            if not qb_listed:
                qb += 1
                diff -= 1
            ol += diff

        counts = (qb,rb,wr,te,ol)

        return counts
    
    def personnel_features(df):
        personnel = df[['GameId','PlayId','OffensePersonnel','DefensePersonnel']].drop_duplicates()
        personnel['DefensePersonnel'] = personnel['DefensePersonnel'].apply(lambda x: split_personnel(x))
        personnel['DefensePersonnel'] = personnel['DefensePersonnel'].apply(lambda x: defense_formation(x))
        personnel['num_DL'] = personnel['DefensePersonnel'].apply(lambda x: x[0])
        personnel['num_LB'] = personnel['DefensePersonnel'].apply(lambda x: x[1])
        personnel['num_DB'] = personnel['DefensePersonnel'].apply(lambda x: x[2])

        personnel['OffensePersonnel'] = personnel['OffensePersonnel'].apply(lambda x: split_personnel(x))
        personnel['OffensePersonnel'] = personnel['OffensePersonnel'].apply(lambda x: offense_formation(x))
        personnel['num_QB'] = personnel['OffensePersonnel'].apply(lambda x: x[0])
        personnel['num_RB'] = personnel['OffensePersonnel'].apply(lambda x: x[1])
        personnel['num_WR'] = personnel['OffensePersonnel'].apply(lambda x: x[2])
        personnel['num_TE'] = personnel['OffensePersonnel'].apply(lambda x: x[3])
        personnel['num_OL'] = personnel['OffensePersonnel'].apply(lambda x: x[4])

        # Let's create some features to specify if the OL is covered
        personnel['OL_diff'] = personnel['num_OL'] - personnel['num_DL']
        personnel['OL_TE_diff'] = (personnel['num_OL'] + personnel['num_TE']) - personnel['num_DL']
        # Let's create a feature to specify if the defense is preventing the run
        # Let's just assume 7 or more DL and LB is run prevention
        personnel['run_def'] = (personnel['num_DL'] + personnel['num_LB'] > 6).astype(int)

        personnel.drop(['OffensePersonnel','DefensePersonnel'], axis=1, inplace=True)
        
        return personnel

    def combine_features(relative_to_back, static, personnel, add_features, deploy=deploy):
        df = pd.merge(relative_to_back,static,on=['GameId','PlayId'],how='inner')
        df = pd.merge(df,personnel,on=['GameId','PlayId'],how='inner')
        df = pd.merge(df,add_features,on=['GameId','PlayId'],how='inner')

        if not deploy:
            df = pd.merge(df, outcomes, on=['GameId','PlayId'], how='inner')

        return df
    

    yardline = update_yardline(df)
    df = update_orientation(df, yardline)
    back_feats = back_features(df)
    rel_back = features_relative_to_back(df, back_feats)
    static_feats = static_features(df)
    personnel = personnel_features(df)
    
    add_features = add_features(df)
    
    basetable = combine_features(rel_back, static_feats, personnel, add_features, deploy=deploy)

#     display('rel_back', rel_back.head())
#     display('static_feats', static_feats.head())
#     display('personnel', personnel.head())
#     display('add_features', add_features.head())
    
    del rel_back, static_feats, personnel, add_features
    gc.collect()
    return basetable

# %%
train_basetable = create_features(train, False)

# %%
X = train_basetable.copy()
yards = X.Yards
X = X.drop(['Yards'], axis=1)

y = np.zeros((yards.shape[0], 199))
for idx, target in enumerate(list(yards)):
    y[idx][99 + target] = 1

# %%
def process_two(t_):
    t_['fe1'] = pd.Series(np.sqrt(np.absolute(np.square(t_.X.values) + np.square(t_.Y.values))))
    t_['fe5'] = np.square(t_['S'].values) + 2 * t_['A'].values * t_['Dis'].values  # N
    t_['fe7'] = np.arccos(np.clip(t_['X'].values / t_['Y'].values, -1, 1))  # N
    t_['fe8'] = t_['S'].values / np.clip(t_['fe1'].values, 0.6, None)
    radian_angle = (90 - t_['Dir']) * np.pi / 180.0
    t_['fe10'] = np.abs(t_['S'] * np.cos(radian_angle))
    t_['fe11'] = np.abs(t_['S'] * np.sin(radian_angle))
    return t_


X = process_two(X)

important = ['back_from_scrimmage', 'min_dist', 'max_dist', 'mean_dist', 'std_dist',
       'def_min_dist', 'def_max_dist', 'def_mean_dist', 'def_std_dist', 'X',
       'Y', 'S', 'A', 'Dis', 'Orientation', 'Dir', 'YardLine']

cat = ['back_oriented_down_field', 'back_moving_down_field']

num = ['back_from_scrimmage', 'min_dist', 'max_dist', 'mean_dist', 'std_dist', 'def_min_dist', 'def_max_dist', 'def_mean_dist', 'def_std_dist',
       'X', 'Y', 'S', 'A', 'Dis', 'Orientation', 'Dir', 'YardLine', 'Distance'] + ['fe1', 'fe5', 'fe7','fe8', 'fe10', 'fe11']

num = [col for col in X.columns if col not in cat]


print(len(cat))
print(len(num))
# Out:
# 2
# 40

# %%
scaler = StandardScaler()
X[num] = scaler.fit_transform(X[num])

# %%
X
# Out:
#          GameId    PlayId  back_from_scrimmage  back_oriented_down_field  \
# 0     -1.008048 -1.008048            -1.253018                         1
# 1     -1.008048 -1.008048            -0.911788                         0
# 2     -1.008048 -1.008048            -1.348989                         1
# 3     -1.008048 -1.008048            -1.487614                         0
# 4     -1.008048 -1.008048             0.090576                         0
# ...         ...       ...                  ...                       ...
# 23166  1.057783  1.057784            -0.378616                         0
# 23167  1.057783  1.057784            -0.986432                         0
# 23168  1.057783  1.057784            -0.911788                         0
# 23169  1.057783  1.057784            -1.189037                         0
# 23170  1.057783  1.057784             1.359525                         0
#
#        back_moving_down_field  min_dist  max_dist  mean_dist  std_dist  \
# 0                           0  0.153870  0.226343  -0.508223 -0.622002
# 1                           0 -0.689447  0.406484  -0.056590 -0.001102
# 2                           0  0.406039 -0.272615  -0.161567 -0.820498
# 23169  0.665020 -1.167206  0.647236 -0.072453 -0.467382  0.886008 -0.657778
# 23170  0.665020  0.038883 -0.816896 -0.072453 -0.467382 -1.637151  0.881754
#
#          num_OL   OL_diff  OL_TE_diff   run_def  def_min_dist  def_max_dist  \
# 0     -0.279712  1.749984    1.038440 -0.924028      0.043930      0.231670
# 1     -0.279712  1.749984    1.038440 -0.924028     -0.268025      0.412004
# 2     -0.279712  1.749984    1.038440 -0.924028     -0.335517     -0.267822
# 3      3.229332  0.495145    1.038440  1.082218     -0.022750     -3.500548
# 4     -0.279712  0.495145    2.111951 -0.924028     -0.267704     -0.123401
# ...         ...       ...         ...       ...           ...           ...
# 23166 -0.279712 -0.759695   -1.108583  1.082218     -1.641734     -0.677229
# 23167 -0.279712 -0.759695   -1.108583 -0.924028     -1.777933      1.143488
# 23168 -0.279712 -0.759695   -1.108583 -0.924028     -0.974333     -0.643798
# 23169 -0.279712 -0.759695   -1.108583 -0.924028     -0.469055     -0.744617
# 23170  3.229332  0.495145    1.038440  1.082218      0.794525     -0.802375
#
#        def_mean_dist  def_std_dist       fe1       fe5       fe7       fe8  \
# 0          -0.409466     -0.435471 -0.423973 -0.557856 -0.372904 -0.246612
# 1          -0.042434     -0.029163 -0.214948 -1.003626 -0.372904 -0.678778
# 2          -0.307555     -0.639468  0.590472  1.375561 -0.372904 -0.047633
# 3          -2.730224     -3.240833  2.105144  0.105402 -0.372904 -1.036407
# 4           0.469439      0.024478 -0.913961 -0.396045 -0.372904  0.445731
# ...              ...           ...       ...       ...       ...       ...
# 23166      -1.426717     -0.638044  0.753230 -0.290271 -0.372904 -0.764276
# 23167       0.956595      1.501639 -0.760925 -0.169784 -0.372904  0.416305
# 23168      -1.034124     -0.443226 -0.507313  0.329623 -0.372904  0.390583
# 23169      -0.874498     -0.241379  1.073800 -0.164770 -0.372904 -0.804620
# 23170      -0.824007     -0.815953  1.091607  0.545497 -0.372904 -0.608176
#
#            fe10      fe11
# 0      0.384871 -0.665124
# 1     -0.513070 -0.333621
# 2      0.857240  0.980201
# 3      1.349947 -1.293835
# 4     -1.202821  0.582461
# ...         ...       ...
# 23166  0.759034 -0.730831
# 23167 -0.718985  0.606695
# 23168  0.186528  0.521988
# 23169 -0.063816  0.327826
# 23170  1.229699 -0.187347
#
# [23171 rows x 42 columns]

# %%
def model_396_1():
    inputs = []
    embeddings = []
    for i in cat:
        input_ = Input(shape=(1,))
        embedding = Embedding(int(np.absolute(X[i]).max() + 1), 10, input_length=1)(input_)
        embedding = Reshape(target_shape=(10,))(embedding)
        inputs.append(input_)
        embeddings.append(embedding)
    input_numeric = Input(shape=(len(num),))
    embedding_numeric = Dense(512, activation='relu')(input_numeric) 
    inputs.append(input_numeric)
    embeddings.append(embedding_numeric)
    x = Concatenate()(embeddings)
    x = Dense(256, activation='relu')(x)
    x = Dense(128, activation='relu')(x)
    x = Dropout(0.5)(x)
    output = Dense(199, activation='softmax')(x)
    model = Model(inputs, output)
    return model


n_splits = 5
kf = GroupKFold(n_splits=n_splits)
score = []
for i_369, (tdx, vdx) in enumerate(kf.split(X, y, X['GameId'])):
    print(f'Fold : {i_369}')
    X_train, X_val, y_train, y_val = X.iloc[tdx], X.iloc[vdx], y[tdx], y[vdx]
    X_train = [np.absolute(X_train[i]) for i in cat] + [X_train[num]]
    X_val = [np.absolute(X_val[i]) for i in cat] + [X_val[num]]
    model = model_396_1()
    model.compile(optimizer='Adam', loss='categorical_crossentropy', metrics=[])
    es = EarlyStopping(monitor='val_CRPS', 
                   mode='min',
                   restore_best_weights=True, 
                   verbose=2, 
                   patience=5)
    es.set_model(model)
    metric = Metric(model, [es], [(X_train,y_train), (X_val,y_val)])
    for i in range(1):
        model.fit(X_train, y_train, verbose=False)
    for i in range(1):
        model.fit(X_train, y_train, batch_size=64, verbose=False)
    for i in range(1):
        model.fit(X_train, y_train, batch_size=128, verbose=False)
    for i in range(1):
        model.fit(X_train, y_train, batch_size=256, verbose=False)
    model.fit(X_train, y_train, callbacks=[metric], epochs=100, batch_size=1024, verbose=False)
    score_ = crps(y_val, model.predict(X_val))
    model.save(f'keras_369_{i_369}.h5')
    print(score_)
    score.append(score_)
    

print(np.mean(score))
# Out:
# Fold : 0
# tr CRPS 0.012522 val CRPS 0.012517
# tr CRPS 0.012492 val CRPS 0.012512
# tr CRPS 0.012471 val CRPS 0.012512
# tr CRPS 0.012458 val CRPS 0.012512
# tr CRPS 0.012422 val CRPS 0.012497
# tr CRPS 0.012401 val CRPS 0.012509
# tr CRPS 0.01238 val CRPS 0.012494
# tr CRPS 0.012388 val CRPS 0.01251
# tr CRPS 0.012355 val CRPS 0.012496
# tr CRPS 0.012314 val CRPS 0.012494
# tr CRPS 0.012283 val CRPS 0.012489
# tr CRPS 0.012273 val CRPS 0.012494
# tr CRPS 0.012246 val CRPS 0.012492
# tr CRPS 0.012219 val CRPS 0.012486
# tr CRPS 0.012172 val CRPS 0.012494
# tr CRPS 0.012175 val CRPS 0.012494
# tr CRPS 0.012113 val CRPS 0.012488
# tr CRPS 0.012132 val CRPS 0.012493
# tr CRPS 0.012078 val CRPS 0.012496
# Restoring model weights from the end of the best epoch
# Epoch 00019: early stopping
# 0.012486094398589505
# Fold : 1
# tr CRPS 0.012402 val CRPS 0.012841
# tr CRPS 0.012398 val CRPS 0.01284
# tr CRPS 0.012352 val CRPS 0.012809
# tr CRPS 0.012351 val CRPS 0.012834
# tr CRPS 0.012323 val CRPS 0.012823
# tr CRPS 0.012293 val CRPS 0.012801
# tr CRPS 0.012276 val CRPS 0.012805
# tr CRPS 0.012267 val CRPS 0.012804
# tr CRPS 0.012231 val CRPS 0.012792
# tr CRPS 0.012215 val CRPS 0.01279
# tr CRPS 0.01219 val CRPS 0.012795
# tr CRPS 0.012168 val CRPS 0.012791
# tr CRPS 0.012136 val CRPS 0.012788
# tr CRPS 0.012117 val CRPS 0.012789
# tr CRPS 0.012095 val CRPS 0.012796
# tr CRPS 0.012068 val CRPS 0.012797
# tr CRPS 0.01203 val CRPS 0.012799
# tr CRPS 0.011998 val CRPS 0.012787
# tr CRPS 0.011985 val CRPS 0.01278
# tr CRPS 0.011948 val CRPS 0.012806
# tr CRPS 0.01191 val CRPS 0.012824
# tr CRPS 0.01189 val CRPS 0.012824
# tr CRPS 0.011848 val CRPS 0.012826
# tr CRPS 0.011817 val CRPS 0.012849
# Restoring model weights from the end of the best epoch
# Epoch 00024: early stopping
# 0.012780349231208316
# Fold : 2
# tr CRPS 0.012333 val CRPS 0.013044
# tr CRPS 0.012311 val CRPS 0.013046
# tr CRPS 0.012286 val CRPS 0.013037
# tr CRPS 0.012267 val CRPS 0.013044
# tr CRPS 0.012247 val CRPS 0.013043
# tr CRPS 0.012238 val CRPS 0.013037
# tr CRPS 0.012211 val CRPS 0.013038
# tr CRPS 0.012194 val CRPS 0.013041
# Restoring model weights from the end of the best epoch
# Epoch 00008: early stopping
# 0.013036503457210483
# Fold : 3
# tr CRPS 0.012381 val CRPS 0.013094
# tr CRPS 0.012346 val CRPS 0.013087
# tr CRPS 0.012326 val CRPS 0.013083
# tr CRPS 0.012308 val CRPS 0.01307
# tr CRPS 0.01229 val CRPS 0.013078
# tr CRPS 0.012267 val CRPS 0.013077
# tr CRPS 0.012257 val CRPS 0.013075
# tr CRPS 0.012237 val CRPS 0.013067
# tr CRPS 0.012224 val CRPS 0.013067
# tr CRPS 0.012193 val CRPS 0.013067
# tr CRPS 0.012176 val CRPS 0.013056
# tr CRPS 0.012152 val CRPS 0.013071
# tr CRPS 0.012129 val CRPS 0.013068
# tr CRPS 0.012114 val CRPS 0.013057
# tr CRPS 0.012081 val CRPS 0.013057
# tr CRPS 0.012055 val CRPS 0.013069
# Restoring model weights from the end of the best epoch
# Epoch 00016: early stopping
# 0.013055920930206587
# Fold : 4
# tr CRPS 0.012563 val CRPS 0.012322
# tr CRPS 0.012539 val CRPS 0.012317
# tr CRPS 0.012527 val CRPS 0.01232
# tr CRPS 0.01251 val CRPS 0.012308
# tr CRPS 0.012482 val CRPS 0.012304
# tr CRPS 0.012454 val CRPS 0.012312
# tr CRPS 0.012457 val CRPS 0.012299
# tr CRPS 0.01243 val CRPS 0.012284
# tr CRPS 0.01241 val CRPS 0.012294
# tr CRPS 0.012404 val CRPS 0.012293
# tr CRPS 0.012363 val CRPS 0.012286
# tr CRPS 0.012339 val CRPS 0.012281
# tr CRPS 0.012308 val CRPS 0.012277
# tr CRPS 0.012281 val CRPS 0.012284
# tr CRPS 0.01226 val CRPS 0.012275
# tr CRPS 0.012244 val CRPS 0.012284
# tr CRPS 0.012201 val CRPS 0.012264
# tr CRPS 0.012183 val CRPS 0.012309
# tr CRPS 0.012153 val CRPS 0.012251
# tr CRPS 0.012111 val CRPS 0.012287
# tr CRPS 0.012144 val CRPS 0.012285
# tr CRPS 0.012086 val CRPS 0.012298
# tr CRPS 0.012029 val CRPS 0.012282
# tr CRPS 0.012006 val CRPS 0.012293
# Restoring model weights from the end of the best epoch
# Epoch 00024: early stopping
# 0.012251332000958036
# 0.012722040003634588

# %%
models = []
for i in range(n_splits):
    models.append(load_model(f'keras_369_{i}.h5'))
    
for (test_df, sample_prediction_df) in iter_test:
    basetable = create_features(test_df, deploy=True)
    basetable = process_two(basetable)
    basetable[num] = scaler.transform(basetable[num])
    test_ = [np.absolute(basetable[i]) for i in cat] + [basetable[num]]
    
    y_pred = np.mean([model.predict(test_) for model in models], axis=0)
    y_pred = np.clip(np.cumsum(y_pred, axis=1), 0, 1).tolist()[0]
    
    preds_df = pd.DataFrame(data=[y_pred], columns=sample_prediction_df.columns)
    env.predict(preds_df)
    
env.write_submission_file()

# %% [markdown]
# ### Graph features

# %%
train
# Out:
#             GameId          PlayId      X      Y     S     A   Dis  \
# 0       2017090700  20170907000118  73.91  34.84  1.69  1.13  0.40
# 1       2017090700  20170907000118  74.67  32.64  0.42  1.35  0.01
# 2       2017090700  20170907000118  74.00  33.20  1.22  0.59  0.31
# 3       2017090700  20170907000118  71.46  27.70  0.42  0.54  0.02
# 4       2017090700  20170907000118  69.32  35.42  1.82  2.43  0.16
# ...            ...             ...    ...    ...   ...   ...   ...
# 509757  2018123015  20181230154157  86.77  24.20  2.14  2.12  0.22
# 509758  2018123015  20181230154157  86.76  27.18  1.16  0.66  0.11
# 509759  2018123015  20181230154157  87.26  27.05  2.59  1.18  0.26
# 509760  2018123015  20181230154157  84.57  24.37  4.36  1.79  0.47
# 509761  2018123015  20181230154157  80.80  26.35  4.87  4.10  0.45
#
#         Orientation     Dir  dist_from_rusher  IsOffense
# 0             81.99  177.18          6.480872          0
# 1             27.61  198.70          4.593310          0
# 2              3.01  202.73          5.448982          0
# 3            359.77  105.64          7.820038          0
# 4             12.63  164.31         10.622476          0
# ...             ...     ...               ...        ...
# 509757        44.55   15.31          6.345345          1
# 509758        53.63   42.80          6.017516          1
# 509759         3.96   21.12          6.497815          1
# 509760       148.08  183.34          4.258321          1
# 509761       135.44  118.24          0.000000          1
#
# [509762 rows x 11 columns]

# %%
train = train.sort_values(by=['GameId','PlayId','dist_from_rusher'])
train.head(200)
# Out:
#             GameId          PlayId      X      Y     S     A   Dis  \
# 18      2017090700  20170907000118  78.75  30.53  3.63  3.35  0.38
# 15      2017090700  20170907000118  79.76  29.49  0.84  1.22  0.00
# 13      2017090700  20170907000118  75.43  32.41  1.50  1.36  0.32
# 19      2017090700  20170907000118  74.60  31.88  1.86  1.51  0.17
# 20      2017090700  20170907000118  74.58  29.12  1.00  0.69  0.22
# ...            ...             ...    ...    ...   ...   ...   ...
# 509750  2018123015  20181230154157  87.91  22.38  4.52  2.55  0.44
# 509749  2018123015  20181230154157  87.82  21.82  2.90  2.67  0.29
# 509754  2018123015  20181230154157  87.34  41.37  3.96  1.48  0.39
# 509745  2018123015  20181230154157  99.14  29.81  1.97  1.40  0.19
# 509741  2018123015  20181230154157  90.09  42.83  3.11  2.47  0.31
#
#         Orientation     Dir  dist_from_rusher  IsOffense
# 18           161.98  245.74          0.000000          1
# 15           192.18  110.86          1.449724          1
# 13           207.08  222.76          3.815337          1
# 19           218.49  267.32          4.364058          1
# 20           169.36  242.05          4.401931          1
# ...             ...     ...               ...        ...
# 509750       338.09  306.72          8.143279          0
# 509749       295.36   40.07          8.354717          0
# 509754       139.94  136.00         16.382063          1
# 509745       256.20  248.21         18.663526          0
# 509741       175.02  130.60         18.918100          0
#
# [509762 rows x 11 columns]

# %%
import networkx as nx
graphs = []

for i, playid in enumerate(train['PlayId'].unique()):
    tmp = train[train.PlayId==playid]
    g = nx.Graph()
    g.add_nodes_from(range(22))
    g.ndata['features'] = np.array(tmp[['X','Y','Dir','Orientation','S','A','IsOffense']])
    for n in range(21):
        g.add_edge(0, n+1, weight=tmp.iloc[n]['dist_from_rusher'].values)

    graphs.append(g)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-48-a8fab6e70356> in <module>
#       5     g = nx.Graph()
#       6     g.add_nodes_from(range(22))
# ----> 7     g.ndata['features'] = np.array(tmp[['X','Y','Dir','Orientation','S','A','IsOffense']])
#       8     for n in range(21):
#       9         g.add_edge(0, n+1, weight=tmp.iloc[n]['dist_from_rusher'].values)
#
# AttributeError: 'Graph' object has no attribute 'ndata'

# %%
g
# Out:
# DGLGraph(num_nodes=22, num_edges=21,
#          ndata_schemes={'features': Scheme(shape=(7,), dtype=torch.float64)}
#          edata_schemes={'distance': Scheme(shape=(), dtype=torch.float64)})

# %%
len(graphs)
# Out:
# 23171

# %% [markdown]
# ### kernelのkerasモデル

# %%
def model_396_1():
    inputs = []
    embeddings = []
    for i in cat:
        input_ = Input(shape=(1,))
        embedding = Embedding(int(np.absolute(X[i]).max() + 1), 10, input_length=1)(input_)
        embedding = Reshape(target_shape=(10,))(embedding)
        inputs.append(input_)
        embeddings.append(embedding)
    input_numeric = Input(shape=(len(num),))
    embedding_numeric = Dense(512, activation='relu')(input_numeric) 
    inputs.append(input_numeric)
    embeddings.append(embedding_numeric)
    x = Concatenate()(embeddings)
    x = Dense(256, activation='relu')(x)
    x = Dense(128, activation='relu')(x)
    x = Dropout(0.5)(x)
    output = Dense(199, activation='softmax')(x)
    model = Model(inputs, output)
    return model

# %%
n_splits = 5
kf = GroupKFold(n_splits=n_splits)
score = []
for i_369, (tdx, vdx) in enumerate(kf.split(X, y, X['GameId'])):
    print(f'Fold : {i_369}')
    X_train, X_val, y_train, y_val = X.iloc[tdx], X.iloc[vdx], y[tdx], y[vdx]
    X_train = [np.absolute(X_train[i]) for i in cat] + [X_train[num]]
    X_val = [np.absolute(X_val[i]) for i in cat] + [X_val[num]]
    model = model_396_1()
    model.compile(optimizer='Adam', loss='categorical_crossentropy', metrics=[])
    es = EarlyStopping(monitor='val_CRPS', 
                   mode='min',
                   restore_best_weights=True, 
                   verbose=2, 
                   patience=5)
    es.set_model(model)
    metric = Metric(model, [es], [(X_train,y_train), (X_val,y_val)])
    for i in range(1):
        model.fit(X_train, y_train, verbose=False)
    for i in range(1):
        model.fit(X_train, y_train, batch_size=64, verbose=False)
    for i in range(1):
        model.fit(X_train, y_train, batch_size=128, verbose=False)
    for i in range(1):
        model.fit(X_train, y_train, batch_size=256, verbose=False)
    model.fit(X_train, y_train, callbacks=[metric], epochs=100, batch_size=1024, verbose=False)
    score_ = crps(y_val, model.predict(X_val))
    model.save(f'keras_369_{i_369}.h5')
    print(score_)
    score.append(score_)
# Out:
# Fold : 0
# tr CRPS 0.012911 val CRPS 0.012699
# tr CRPS 0.012891 val CRPS 0.012692
# tr CRPS 0.01287 val CRPS 0.012686
# tr CRPS 0.012847 val CRPS 0.012665
# tr CRPS 0.012833 val CRPS 0.012651
# tr CRPS 0.012821 val CRPS 0.012646
# tr CRPS 0.012802 val CRPS 0.012645
# tr CRPS 0.012792 val CRPS 0.01265
# tr CRPS 0.012764 val CRPS 0.012613
# tr CRPS 0.012753 val CRPS 0.012619
# tr CRPS 0.012737 val CRPS 0.012626
# tr CRPS 0.01272 val CRPS 0.012607
# tr CRPS 0.012723 val CRPS 0.012615
# tr CRPS 0.012704 val CRPS 0.012603
# tr CRPS 0.012693 val CRPS 0.012586
# tr CRPS 0.012682 val CRPS 0.012584
# tr CRPS 0.012648 val CRPS 0.012556
# tr CRPS 0.012622 val CRPS 0.012564
# tr CRPS 0.012603 val CRPS 0.01256
# tr CRPS 0.012612 val CRPS 0.012576
# tr CRPS 0.012571 val CRPS 0.012547
# tr CRPS 0.012572 val CRPS 0.012549
# tr CRPS 0.012548 val CRPS 0.012556
# tr CRPS 0.012536 val CRPS 0.012554
# tr CRPS 0.012499 val CRPS 0.012548
# tr CRPS 0.012487 val CRPS 0.012549
# Restoring model weights from the end of the best epoch
# Epoch 00026: early stopping
# 0.012546901419028764
# Fold : 1
# tr CRPS 0.0128 val CRPS 0.013118
# tr CRPS 0.012777 val CRPS 0.013113
# tr CRPS 0.012762 val CRPS 0.013102
# tr CRPS 0.012747 val CRPS 0.013089
# tr CRPS 0.01273 val CRPS 0.013078
# tr CRPS 0.012712 val CRPS 0.013072
# tr CRPS 0.012697 val CRPS 0.013058
# tr CRPS 0.012681 val CRPS 0.013047
# tr CRPS 0.012666 val CRPS 0.013048
# tr CRPS 0.012655 val CRPS 0.013044
# tr CRPS 0.012627 val CRPS 0.013034
# tr CRPS 0.012604 val CRPS 0.013014
# tr CRPS 0.012599 val CRPS 0.013017
# tr CRPS 0.012576 val CRPS 0.013012
# tr CRPS 0.012569 val CRPS 0.013011
# tr CRPS 0.012547 val CRPS 0.012998
# tr CRPS 0.012526 val CRPS 0.012998
# tr CRPS 0.012506 val CRPS 0.012984
# tr CRPS 0.012491 val CRPS 0.012969
# tr CRPS 0.012462 val CRPS 0.012968
# tr CRPS 0.012461 val CRPS 0.012969
# tr CRPS 0.012427 val CRPS 0.012956
# tr CRPS 0.01242 val CRPS 0.012968
# tr CRPS 0.012377 val CRPS 0.012951
# tr CRPS 0.012405 val CRPS 0.012972
# tr CRPS 0.012384 val CRPS 0.01297
# tr CRPS 0.012332 val CRPS 0.012951
# tr CRPS 0.012307 val CRPS 0.012942
# tr CRPS 0.012312 val CRPS 0.012968
# tr CRPS 0.012302 val CRPS 0.012973
# tr CRPS 0.01226 val CRPS 0.012943
# tr CRPS 0.012267 val CRPS 0.012975
# tr CRPS 0.012223 val CRPS 0.012952
# Restoring model weights from the end of the best epoch
# Epoch 00033: early stopping
# 0.012942442010546937
# Fold : 2
# tr CRPS 0.012705 val CRPS 0.01327
# tr CRPS 0.012693 val CRPS 0.013261
# tr CRPS 0.012676 val CRPS 0.013257
# tr CRPS 0.012656 val CRPS 0.013243
# tr CRPS 0.01264 val CRPS 0.013234
# tr CRPS 0.012625 val CRPS 0.013233
# tr CRPS 0.012614 val CRPS 0.013218
# tr CRPS 0.012595 val CRPS 0.013209
# tr CRPS 0.012567 val CRPS 0.013196
# tr CRPS 0.012556 val CRPS 0.013192
# tr CRPS 0.012549 val CRPS 0.013194
# tr CRPS 0.012519 val CRPS 0.013176
# tr CRPS 0.012513 val CRPS 0.013177
# tr CRPS 0.012491 val CRPS 0.013167
# tr CRPS 0.012476 val CRPS 0.013156
# tr CRPS 0.012464 val CRPS 0.013157
# tr CRPS 0.012472 val CRPS 0.01316
# tr CRPS 0.012426 val CRPS 0.013146
# tr CRPS 0.012408 val CRPS 0.013143
# tr CRPS 0.012405 val CRPS 0.01315
# tr CRPS 0.012375 val CRPS 0.013142
# tr CRPS 0.012356 val CRPS 0.013146
# tr CRPS 0.012327 val CRPS 0.013131
# tr CRPS 0.01232 val CRPS 0.01314
# tr CRPS 0.012316 val CRPS 0.013117
# tr CRPS 0.012319 val CRPS 0.013148
# tr CRPS 0.01227 val CRPS 0.013111
# tr CRPS 0.012254 val CRPS 0.013138
# tr CRPS 0.012228 val CRPS 0.013112
# tr CRPS 0.012212 val CRPS 0.013109
# tr CRPS 0.012215 val CRPS 0.013122
# tr CRPS 0.01217 val CRPS 0.013119
# tr CRPS 0.012143 val CRPS 0.013131
# tr CRPS 0.012173 val CRPS 0.013149
# tr CRPS 0.012125 val CRPS 0.01312
# Restoring model weights from the end of the best epoch
# Epoch 00035: early stopping
# 0.013108843320405586
# Fold : 3
# tr CRPS 0.012722 val CRPS 0.013257
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-11-49a1d9c807c4> in <module>
#      24     for i in range(1):
#      25         model.fit(X_train, y_train, batch_size=256, verbose=False)
# ---> 26     model.fit(X_train, y_train, callbacks=[metric], epochs=100, batch_size=1024, verbose=False)
#      27     score_ = crps(y_val, model.predict(X_val))
#      28     model.save(f'keras_369_{i_369}.h5')
#
# c:\users\0000011306852\appdata\local\programs\python\python36\lib\site-packages\keras\engine\training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_freq, max_queue_size, workers, use_multiprocessing, **kwargs)
#    1237                                         steps_per_epoch=steps_per_epoch,
#    1238                                         validation_steps=validation_steps,
# -> 1239                                         validation_freq=validation_freq)
#    1240
#    1241     def evaluate(self,
#
# c:\users\0000011306852\appdata\local\programs\python\python36\lib\site-packages\keras\engine\training_arrays.py in fit_loop(model, fit_function, fit_inputs, out_labels, batch_size, epochs, verbose, callbacks, val_function, val_inputs, shuffle, initial_epoch, steps_per_epoch, validation_steps, validation_freq)
#     214                         epoch_logs['val_' + l] = o
#     215
# --> 216         callbacks.on_epoch_end(epoch, epoch_logs)
#     217         if callbacks.model.stop_training:
#     218             break
#
# c:\users\0000011306852\appdata\local\programs\python\python36\lib\site-packages\keras\callbacks\callbacks.py in on_epoch_end(self, epoch, logs)
#     150         logs = logs or {}
#     151         for callback in self.callbacks:
# --> 152             callback.on_epoch_end(epoch, logs)
#     153
#     154     def on_train_batch_begin(self, batch, logs=None):
#
# <ipython-input-4-c7721b91c485> in on_epoch_end(self, batch, logs)
#      21         y_true = np.clip(np.cumsum(y_train, axis=1), 0, 1)
#      22         y_pred = np.clip(np.cumsum(y_pred, axis=1), 0, 1)
# ---> 23         tr_s = ((y_true - y_pred) ** 2).sum(axis=1).sum(axis=0) / (199 * X_train[-1].shape[0])
#      24         tr_s = np.round(tr_s, 6)
#      25         logs['tr_CRPS'] = tr_s
#
# c:\users\0000011306852\appdata\local\programs\python\python36\lib\site-packages\numpy\core\_methods.py in _sum(a, axis, dtype, out, keepdims, initial, where)
#      36 def _sum(a, axis=None, dtype=None, out=None, keepdims=False,
#      37          initial=_NoValue, where=True):
# ---> 38     return umr_sum(a, axis, dtype, out, keepdims, initial, where)
#      39
#      40 def _prod(a, axis=None, dtype=None, out=None, keepdims=False,
#
# KeyboardInterrupt:

# %%
print(np.mean(score))

# %%
models = []
for i in range(n_splits):
    models.append(load_model(f'keras_369_{i}.h5'))
    
for (test_df, sample_prediction_df) in iter_test:
    basetable = create_features(test_df, deploy=True)
    basetable = process_two(basetable)
    basetable[num] = scaler.transform(basetable[num])
    test_ = [np.absolute(basetable[i]) for i in cat] + [basetable[num]]
    
    y_pred = np.mean([model.predict(test_) for model in models], axis=0)
    y_pred = np.clip(np.cumsum(y_pred, axis=1), 0, 1).tolist()[0]
    
    preds_df = pd.DataFrame(data=[y_pred], columns=sample_prediction_df.columns)
