# %% [markdown]
# https://www.kaggle.com/bestpredict/location-eda-8eb410

# %%
import os
# os.environ['CUDA_VISIBLE_DEVICES'] = "1"


import numpy as np
import pandas as pd
import sklearn.metrics as mtr
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split

from keras.layers import Dense,Input,Flatten,concatenate,Dropout,Lambda,BatchNormalization
from keras.models import Model
import keras.backend as K
from keras.callbacks import Callback
from  keras.callbacks import EarlyStopping,ModelCheckpoint
import datetime

TRAIN_OFFLINE = False


pd.set_option('display.max_columns', 50)
pd.set_option('display.max_rows', 150)
# Out:
# Using TensorFlow backend.

# %%
train = pd.read_csv('../input/train.csv', dtype={'WindSpeed': 'object'})

# %%
outcomes = train[['GameId','PlayId','Yards']].drop_duplicates()

# %%
def strtoseconds(txt):
    txt = txt.split(':')
    ans = int(txt[0])*60 + int(txt[1]) + int(txt[2])/60
    return ans

def strtofloat(x):
    try:
        return float(x)
    except:
        return -1

def map_weather(txt):
    ans = 1
    if pd.isna(txt):
        return 0
    if 'partly' in txt:
        ans*=0.5
    if 'climate controlled' in txt or 'indoor' in txt:
        return ans*3
    if 'sunny' in txt or 'sun' in txt:
        return ans*2
    if 'clear' in txt:
        return ans
    if 'cloudy' in txt:
        return -ans
    if 'rain' in txt or 'rainy' in txt:
        return -2*ans
    if 'snow' in txt:
        return -3*ans
    return 0

def OffensePersonnelSplit(x):
    dic = {'DB' : 0, 'DL' : 0, 'LB' : 0, 'OL' : 0, 'QB' : 0, 'RB' : 0, 'TE' : 0, 'WR' : 0}
    for xx in x.split(","):
        xxs = xx.split(" ")
        dic[xxs[-1]] = int(xxs[-2])
    return dic

def DefensePersonnelSplit(x):
    dic = {'DB' : 0, 'DL' : 0, 'LB' : 0, 'OL' : 0}
    for xx in x.split(","):
        xxs = xx.split(" ")
        dic[xxs[-1]] = int(xxs[-2])
    return dic

def orientation_to_cat(x):
    x = np.clip(x, 0, 360 - 1)
    try:
        return str(int(x/15))
    except:
        return "nan"
def preprocess(train):
    ## GameClock
    train['GameClock_sec'] = train['GameClock'].apply(strtoseconds)
    train["GameClock_minute"] = train["GameClock"].apply(lambda x : x.split(":")[0]).astype("object")

    ## Height
    train['PlayerHeight_dense'] = train['PlayerHeight'].apply(lambda x: 12*int(x.split('-')[0])+int(x.split('-')[1]))

    ## Time
    train['TimeHandoff'] = train['TimeHandoff'].apply(lambda x: datetime.datetime.strptime(x, "%Y-%m-%dT%H:%M:%S.%fZ"))
    train['TimeSnap'] = train['TimeSnap'].apply(lambda x: datetime.datetime.strptime(x, "%Y-%m-%dT%H:%M:%S.%fZ"))

    train['TimeDelta'] = train.apply(lambda row: (row['TimeHandoff'] - row['TimeSnap']).total_seconds(), axis=1)
    train['PlayerBirthDate'] = train['PlayerBirthDate'].apply(lambda x: datetime.datetime.strptime(x, "%m/%d/%Y"))

    ## Age
    seconds_in_year = 60*60*24*365.25
    train['PlayerAge'] = train.apply(lambda row: (row['TimeHandoff']-row['PlayerBirthDate']).total_seconds()/seconds_in_year, axis=1)
    train["PlayerAge_ob"] = train['PlayerAge'].astype(np.int).astype("object")

    ## WindSpeed
    train['WindSpeed_ob'] = train['WindSpeed'].apply(lambda x: x.lower().replace('mph', '').strip() if not pd.isna(x) else x)
    train['WindSpeed_ob'] = train['WindSpeed_ob'].apply(lambda x: (int(x.split('-')[0])+int(x.split('-')[1]))/2 if not pd.isna(x) and '-' in x else x)
    train['WindSpeed_ob'] = train['WindSpeed_ob'].apply(lambda x: (int(x.split()[0])+int(x.split()[-1]))/2 if not pd.isna(x) and type(x)!=float and 'gusts up to' in x else x)
    train['WindSpeed_dense'] = train['WindSpeed_ob'].apply(strtofloat)

    ## Weather
    train['GameWeather_process'] = train['GameWeather'].str.lower()
    train['GameWeather_process'] = train['GameWeather_process'].apply(lambda x: "indoor" if not pd.isna(x) and "indoor" in x else x)
    train['GameWeather_process'] = train['GameWeather_process'].apply(lambda x: x.replace('coudy', 'cloudy').replace('clouidy', 'cloudy').replace('party', 'partly') if not pd.isna(x) else x)
    train['GameWeather_process'] = train['GameWeather_process'].apply(lambda x: x.replace('clear and sunny', 'sunny and clear') if not pd.isna(x) else x)
    train['GameWeather_process'] = train['GameWeather_process'].apply(lambda x: x.replace('skies', '').replace("mostly", "").strip() if not pd.isna(x) else x)
    train['GameWeather_dense'] = train['GameWeather_process'].apply(map_weather)

    ## Rusher
    train['IsRusher'] = (train['NflId'] == train['NflIdRusher'])
    train['IsRusher_ob'] = (train['NflId'] == train['NflIdRusher']).astype("object")
    temp = train[train["IsRusher"]][["Team", "PlayId"]].rename(columns={"Team":"RusherTeam"})
    train = train.merge(temp, on = "PlayId")
    train["IsRusherTeam"] = train["Team"] == train["RusherTeam"]

    ## dense -> categorical
    train["Quarter_ob"] = train["Quarter"].astype("object")
    train["Down_ob"] = train["Down"].astype("object")
    train["JerseyNumber_ob"] = train["JerseyNumber"].astype("object")
    train["YardLine_ob"] = train["YardLine"].astype("object")
    # train["DefendersInTheBox_ob"] = train["DefendersInTheBox"].astype("object")
    # train["Week_ob"] = train["Week"].astype("object")
    # train["TimeDelta_ob"] = train["TimeDelta"].astype("object")


    ## Orientation and Dir
    train["Orientation_ob"] = train["Orientation"].apply(lambda x : orientation_to_cat(x)).astype("object")
    train["Dir_ob"] = train["Dir"].apply(lambda x : orientation_to_cat(x)).astype("object")

    train["Orientation_sin"] = train["Orientation"].apply(lambda x : np.sin(x/360 * 2 * np.pi))
    train["Orientation_cos"] = train["Orientation"].apply(lambda x : np.cos(x/360 * 2 * np.pi))
    train["Dir_sin"] = train["Dir"].apply(lambda x : np.sin(x/360 * 2 * np.pi))
    train["Dir_cos"] = train["Dir"].apply(lambda x : np.cos(x/360 * 2 * np.pi))

    ## diff Score
    train["diffScoreBeforePlay"] = train["HomeScoreBeforePlay"] - train["VisitorScoreBeforePlay"]
    train["diffScoreBeforePlay_binary_ob"] = (train["HomeScoreBeforePlay"] > train["VisitorScoreBeforePlay"]).astype("object")

    ## Turf
    Turf = {'Field Turf':'Artificial', 'A-Turf Titan':'Artificial', 'Grass':'Natural', 'UBU Sports Speed S5-M':'Artificial', 'Artificial':'Artificial', 'DD GrassMaster':'Artificial', 'Natural Grass':'Natural', 'UBU Speed Series-S5-M':'Artificial', 'FieldTurf':'Artificial', 'FieldTurf 360':'Artificial', 'Natural grass':'Natural', 'grass':'Natural', 'Natural':'Natural', 'Artifical':'Artificial', 'FieldTurf360':'Artificial', 'Naturall Grass':'Natural', 'Field turf':'Artificial', 'SISGrass':'Artificial', 'Twenty-Four/Seven Turf':'Artificial', 'natural grass':'Natural'} 
    train['Turf'] = train['Turf'].map(Turf)

    ## OffensePersonnel
    temp = train["OffensePersonnel"].iloc[np.arange(0, len(train), 22)].apply(lambda x : pd.Series(OffensePersonnelSplit(x)))
    temp.columns = ["Offense" + c for c in temp.columns]
    temp["PlayId"] = train["PlayId"].iloc[np.arange(0, len(train), 22)]
    train = train.merge(temp, on = "PlayId")

    ## DefensePersonnel
    temp = train["DefensePersonnel"].iloc[np.arange(0, len(train), 22)].apply(lambda x : pd.Series(DefensePersonnelSplit(x)))
    temp.columns = ["Defense" + c for c in temp.columns]
    temp["PlayId"] = train["PlayId"].iloc[np.arange(0, len(train), 22)]
    train = train.merge(temp, on = "PlayId")

    ## sort
#     train = train.sort_values(by = ['X']).sort_values(by = ['Dis']).sort_values(by=['PlayId', 'Team', 'IsRusher']).reset_index(drop = True)
    train = train.sort_values(by = ['X']).sort_values(by = ['Dis']).sort_values(by=['PlayId', 'IsRusherTeam', 'IsRusher']).reset_index(drop = True)
    return train

# %%
def create_features(df, deploy=False):
    def new_X(x_coordinate, play_direction):
        if play_direction == 'left':
            return 120.0 - x_coordinate
        else:
            return x_coordinate

    def new_line(rush_team, field_position, yardline):
        if rush_team == field_position:
            # offense starting at X = 0 plus the 10 yard endzone plus the line of scrimmage
            return 10.0 + yardline
        else:
            # half the field plus the yards between midfield and the line of scrimmage
            return 60.0 + (50 - yardline)

    def new_orientation(angle, play_direction):
        if play_direction == 'left':
            new_angle = 360.0 - angle
            if new_angle == 360.0:
                new_angle = 0.0
            return new_angle
        else:
            return angle

    def euclidean_distance(x1,y1,x2,y2):
        x_diff = (x1-x2)**2
        y_diff = (y1-y2)**2

        return np.sqrt(x_diff + y_diff)

    def back_direction(orientation):
        if orientation > 180.0:
            return 1
        else:
            return 0

    def update_yardline(df):
        new_yardline = df[df['NflId'] == df['NflIdRusher']]
        new_yardline['YardLine'] = new_yardline[['PossessionTeam','FieldPosition','YardLine']].apply(lambda x: new_line(x[0],x[1],x[2]), axis=1)
        new_yardline = new_yardline[['GameId','PlayId','YardLine']]

        return new_yardline

    def update_orientation(df, yardline):
        df['X'] = df[['X','PlayDirection']].apply(lambda x: new_X(x[0],x[1]), axis=1)
        df['Orientation'] = df[['Orientation','PlayDirection']].apply(lambda x: new_orientation(x[0],x[1]), axis=1)
        df['Dir'] = df[['Dir','PlayDirection']].apply(lambda x: new_orientation(x[0],x[1]), axis=1)

        df = df.drop('YardLine', axis=1)
        df = pd.merge(df, yardline, on=['GameId','PlayId'], how='inner')

        return df

    def back_features(df):
        carriers = df[df['NflId'] == df['NflIdRusher']][['GameId','PlayId','NflIdRusher','X','Y','Orientation','Dir','YardLine']]
        carriers['back_from_scrimmage'] = carriers['YardLine'] - carriers['X']
        carriers['back_oriented_down_field'] = carriers['Orientation'].apply(lambda x: back_direction(x))
        carriers['back_moving_down_field'] = carriers['Dir'].apply(lambda x: back_direction(x))
        carriers = carriers.rename(columns={'X':'back_X',
                                            'Y':'back_Y'})
        carriers = carriers[['GameId','PlayId','NflIdRusher','back_X','back_Y','back_from_scrimmage','back_oriented_down_field','back_moving_down_field']]

        return carriers

    def features_relative_to_back(df, carriers):
        player_distance = df[['GameId','PlayId','NflId','X','Y']]
        player_distance = pd.merge(player_distance, carriers, on=['GameId','PlayId'], how='inner')
        player_distance = player_distance[player_distance['NflId'] != player_distance['NflIdRusher']]
        player_distance['dist_to_back'] = player_distance[['X','Y','back_X','back_Y']].apply(lambda x: euclidean_distance(x[0],x[1],x[2],x[3]), axis=1)

        player_distance = player_distance.groupby(['GameId','PlayId','back_from_scrimmage','back_oriented_down_field','back_moving_down_field'])\
                                         .agg({'dist_to_back':['min','max','mean','std']})\
                                         .reset_index()
        player_distance.columns = ['GameId','PlayId','back_from_scrimmage','back_oriented_down_field','back_moving_down_field',
                                   'min_dist','max_dist','mean_dist','std_dist']

        return player_distance

    def defense_features(df):
        rusher = df[df['NflId'] == df['NflIdRusher']][['GameId','PlayId','Team','X','Y']]
        rusher.columns = ['GameId','PlayId','RusherTeam','RusherX','RusherY']

        defense = pd.merge(df,rusher,on=['GameId','PlayId'],how='inner')
        defense = defense[defense['Team'] != defense['RusherTeam']][['GameId','PlayId','X','Y','RusherX','RusherY']]
        defense['def_dist_to_back'] = defense[['X','Y','RusherX','RusherY']].apply(lambda x: euclidean_distance(x[0],x[1],x[2],x[3]), axis=1)

        defense = defense.groupby(['GameId','PlayId'])\
                         .agg({'def_dist_to_back':['min','max','mean','std']})\
                         .reset_index()
        defense.columns = ['GameId','PlayId','def_min_dist','def_max_dist','def_mean_dist','def_std_dist']

        return defense

    def static_features(df):
        
        
        add_new_feas = []

        ## Height
        df['PlayerHeight_dense'] = df['PlayerHeight'].apply(lambda x: 12*int(x.split('-')[0])+int(x.split('-')[1]))
        
        add_new_feas.append('PlayerHeight_dense')

        ## Time
        df['TimeHandoff'] = df['TimeHandoff'].apply(lambda x: datetime.datetime.strptime(x, "%Y-%m-%dT%H:%M:%S.%fZ"))
        df['TimeSnap'] = df['TimeSnap'].apply(lambda x: datetime.datetime.strptime(x, "%Y-%m-%dT%H:%M:%S.%fZ"))

        df['TimeDelta'] = df.apply(lambda row: (row['TimeHandoff'] - row['TimeSnap']).total_seconds(), axis=1)
        df['PlayerBirthDate'] =df['PlayerBirthDate'].apply(lambda x: datetime.datetime.strptime(x, "%m/%d/%Y"))

        ## Age
        seconds_in_year = 60*60*24*365.25
        df['PlayerAge'] = df.apply(lambda row: (row['TimeHandoff']-row['PlayerBirthDate']).total_seconds()/seconds_in_year, axis=1)
        add_new_feas.append('PlayerAge')

        ## WindSpeed
        df['WindSpeed_ob'] = df['WindSpeed'].apply(lambda x: x.lower().replace('mph', '').strip() if not pd.isna(x) else x)
        df['WindSpeed_ob'] = df['WindSpeed_ob'].apply(lambda x: (int(x.split('-')[0])+int(x.split('-')[1]))/2 if not pd.isna(x) and '-' in x else x)
        df['WindSpeed_ob'] = df['WindSpeed_ob'].apply(lambda x: (int(x.split()[0])+int(x.split()[-1]))/2 if not pd.isna(x) and type(x)!=float and 'gusts up to' in x else x)
        df['WindSpeed_dense'] = df['WindSpeed_ob'].apply(strtofloat)
        add_new_feas.append('WindSpeed_dense')

        ## Weather
        df['GameWeather_process'] = df['GameWeather'].str.lower()
        df['GameWeather_process'] = df['GameWeather_process'].apply(lambda x: "indoor" if not pd.isna(x) and "indoor" in x else x)
        df['GameWeather_process'] = df['GameWeather_process'].apply(lambda x: x.replace('coudy', 'cloudy').replace('clouidy', 'cloudy').replace('party', 'partly') if not pd.isna(x) else x)
        df['GameWeather_process'] = df['GameWeather_process'].apply(lambda x: x.replace('clear and sunny', 'sunny and clear') if not pd.isna(x) else x)
        df['GameWeather_process'] = df['GameWeather_process'].apply(lambda x: x.replace('skies', '').replace("mostly", "").strip() if not pd.isna(x) else x)
        df['GameWeather_dense'] = df['GameWeather_process'].apply(map_weather)
        add_new_feas.append('GameWeather_dense')
#         ## Rusher
#         train['IsRusher'] = (train['NflId'] == train['NflIdRusher'])
#         train['IsRusher_ob'] = (train['NflId'] == train['NflIdRusher']).astype("object")
#         temp = train[train["IsRusher"]][["Team", "PlayId"]].rename(columns={"Team":"RusherTeam"})
#         train = train.merge(temp, on = "PlayId")
#         train["IsRusherTeam"] = train["Team"] == train["RusherTeam"]

        ## dense -> categorical
#         train["Quarter_ob"] = train["Quarter"].astype("object")
#         train["Down_ob"] = train["Down"].astype("object")
#         train["JerseyNumber_ob"] = train["JerseyNumber"].astype("object")
#         train["YardLine_ob"] = train["YardLine"].astype("object")
        # train["DefendersInTheBox_ob"] = train["DefendersInTheBox"].astype("object")
        # train["Week_ob"] = train["Week"].astype("object")
        # train["TimeDelta_ob"] = train["TimeDelta"].astype("object")


        ## Orientation and Dir
        df["Orientation_ob"] = df["Orientation"].apply(lambda x : orientation_to_cat(x)).astype("object")
        df["Dir_ob"] = df["Dir"].apply(lambda x : orientation_to_cat(x)).astype("object")

        df["Orientation_sin"] = df["Orientation"].apply(lambda x : np.sin(x/360 * 2 * np.pi))
        df["Orientation_cos"] = df["Orientation"].apply(lambda x : np.cos(x/360 * 2 * np.pi))
        df["Dir_sin"] = df["Dir"].apply(lambda x : np.sin(x/360 * 2 * np.pi))
        df["Dir_cos"] = df["Dir"].apply(lambda x : np.cos(x/360 * 2 * np.pi))
        add_new_feas.append("Dir_sin")
        add_new_feas.append("Dir_cos")

        ## diff Score
        df["diffScoreBeforePlay"] = df["HomeScoreBeforePlay"] - df["VisitorScoreBeforePlay"]
        add_new_feas.append("diffScoreBeforePlay")
    
    
        static_features = df[df['NflId'] == df['NflIdRusher']][add_new_feas+['GameId','PlayId','X','Y','S','A','Dis','Orientation','Dir',
                                                            'YardLine','Quarter','Down','Distance','DefendersInTheBox']].drop_duplicates()
#         static_features['DefendersInTheBox'] = static_features['DefendersInTheBox'].fillna(np.mean(static_features['DefendersInTheBox']))
        static_features.fillna(-999,inplace=True)
#         for i in add_new_feas:
#             static_features[i] = static_features[i].fillna(np.mean(static_features[i]))
            

        return static_features


    def combine_features(relative_to_back, defense, static, deploy=deploy):
        df = pd.merge(relative_to_back,defense,on=['GameId','PlayId'],how='inner')
        df = pd.merge(df,static,on=['GameId','PlayId'],how='inner')

        if not deploy:
            df = pd.merge(df, outcomes, on=['GameId','PlayId'], how='inner')

        return df
    
    yardline = update_yardline(df)
    df = update_orientation(df, yardline)
    back_feats = back_features(df)
    rel_back = features_relative_to_back(df, back_feats)
    def_feats = defense_features(df)
    static_feats = static_features(df)
    basetable = combine_features(rel_back, def_feats, static_feats, deploy=deploy)
    
    return basetable

# %%
# %time train_basetable = create_features(train, False)
# Out:
# c:\users\0000011306852\appdata\local\programs\python\python36\lib\site-packages\ipykernel_launcher.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# Wall time: 2min 30s

# %%
train_basetable
# Out:
#            GameId          PlayId  back_from_scrimmage  \
# 0      2017090700  20170907000118                 3.75
# 1      2017090700  20170907000139                 4.07
# 2      2017090700  20170907000189                 3.66
# 3      2017090700  20170907000345                 3.53
# 4      2017090700  20170907000395                 5.01
# ...           ...             ...                  ...
# 23166  2018123015  20181230153910                 4.57
# 23167  2018123015  20181230154035                 4.00
# 23168  2018123015  20181230154082                 4.07
# 23169  2018123015  20181230154135                 3.81
# 23170  2018123015  20181230154157                 6.20
#
#        back_oriented_down_field  back_moving_down_field  min_dist   max_dist  \
# 0                             1                       0  1.449724  22.415872
# 1                             0                       0  0.792023  23.025872
# 2                             1                       0  1.646390  20.726285
# 3                             0                       0  0.918096   9.791231
# 4                             0                       0  0.502892  21.214806
# ...                         ...                     ...       ...        ...
# 23166                         0                       0  0.575847  19.341419
# 23167                         0                       0  1.151217  25.500196
# 23168                         0                       0  0.776209  19.454503
# 23169                         0                       0  0.584637  19.113474
# 23170                         0                       0  1.204159  18.918100
#
#        mean_dist  std_dist  def_min_dist  def_max_dist  def_mean_dist  \
# 0       8.046559  4.873845      4.593310     22.415872       9.752491
# 1       8.614623  5.598683      4.287773     23.025872      10.297028
# 2       8.482583  4.642121      4.221670     20.726285       9.903689
# 3       5.549379  1.983128      4.528002      9.791231       6.309354
# 4       9.168819  5.611232      4.288088     21.214806      11.056456
# ...          ...       ...           ...           ...            ...
# 23166   6.736412  4.514974      2.942329     19.341419       8.243270
# 23167   9.827962  7.474030      2.808932     25.500196      11.779213
# 23168   8.272970  5.548527      3.595998     19.454503       8.825731
# 23169   8.202171  5.833721      4.090880     19.113474       9.062557
# 23170   7.826834  4.535856      5.328461     18.918100       9.137466
#
#        def_std_dist  PlayerHeight_dense  PlayerAge  WindSpeed_dense  \
# 0          5.327299                  70  25.596251              8.0
# 1          5.833217                  70  25.596252              8.0
# 2          5.073290                  70  25.596253              8.0
# 3          1.834174                  71  26.852933              8.0
# 4          5.900009                  71  22.091819              8.0
# ...             ...                 ...        ...              ...
# 23166      5.075063                  73  27.041779              5.0
# 23167      7.739310                  69  25.861781              5.0
# 23168      5.317643                  69  25.861783              5.0
# 23169      5.568974                  71  24.290258              5.0
# 23170      4.853538                  71  24.290259              5.0
#
#        GameWeather_dense   Dir_sin   Dir_cos  diffScoreBeforePlay       X  \
# 0                    1.0  0.911690 -0.410878                    0   41.25
# 1                    1.0  0.740805  0.671721                    0   48.93
# 2                    1.0  0.668612 -0.743612                    0   71.34
# 3                    1.0  0.995496  0.094803                    0  104.47
# 4                    1.0  0.375901 -0.926660                    7   29.99
# ...                  ...       ...       ...                  ...     ...
# 23166               -1.0  0.938312  0.345790                    3   70.43
# 23167               -1.0  0.485115 -0.874450                    0   31.00
# 23168               -1.0  0.659346  0.751840                    0   39.93
# 23169               -1.0  0.659215  0.751955                    0   81.19
# 23170               -1.0  0.880973 -0.473166                    0   80.80
#
#            Y     S     A   Dis  Orientation     Dir  YardLine  Quarter  Down  \
# 0      30.53  3.63  3.35  0.38       198.02  114.26      45.0        1     3
# 1      27.16  3.06  2.41  0.34       149.30   47.80      53.0        1     1
# 2      19.11  5.77  2.42  0.60       219.18  138.04      75.0        1     1
# 3      25.36  4.45  3.20  0.46       173.78   84.56     108.0        1     2
# 4      27.12  3.90  2.53  0.44        34.27  157.92      35.0        1     1
# ...      ...   ...   ...   ...          ...     ...       ...      ...   ...
# 23166  32.27  3.99  3.38  0.39        72.56   69.77      75.0        4     1
# 23167  30.99  4.18  2.95  0.40       122.97  150.98      35.0        4     1
# 23168  29.20  4.67  3.68  0.45        63.11   41.25      44.0        4     3
# 23169  23.75  4.23  2.43  0.41        66.34   41.24      85.0        4     1
# 23170  26.35  4.87  4.10  0.45       135.44  118.24      87.0        4     2
#
#        Distance  DefendersInTheBox  Yards
# 0             2                6.0      8
# 1            10                6.0      3
# 2            10                7.0      5
# 3             2                9.0      2
# 4            10                7.0      7
# ...         ...                ...    ...
# 23166        10                8.0      1
# 23167        10                6.0      4
# 23168         1                7.0      4
# 23169        10                7.0      2
# 23170         8                9.0     11
#
# [23171 rows x 33 columns]

# %%
X = train_basetable.copy()
yards = X.Yards

y = np.zeros((yards.shape[0], 199))
for idx, target in enumerate(list(yards)):
    y[idx][99 + target] = 1

X.drop(['GameId','PlayId','Yards'], axis=1, inplace=True)

# %%
scaler = StandardScaler()
X = scaler.fit_transform(X)

# %%
from keras.layers import Dense,Input,Flatten,concatenate,Dropout,Lambda
from keras.models import Model
import keras.backend as K
import re
from keras.losses import binary_crossentropy
from  keras.callbacks import EarlyStopping,ModelCheckpoint
import codecs

from keras.utils import to_categorical
from keras.callbacks import EarlyStopping, ModelCheckpoint, Callback
from sklearn.metrics import f1_score




class CRPSCallback(Callback):
    
    def __init__(self,validation, predict_batch_size=20, include_on_batch=False):
        super(CRPSCallback, self).__init__()
        self.validation = validation
        self.predict_batch_size = predict_batch_size
        self.include_on_batch = include_on_batch
        
        print('validation shape',len(self.validation))

    def on_batch_begin(self, batch, logs={}):
        pass

    def on_train_begin(self, logs={}):
        if not ('CRPS_score_val' in self.params['metrics']):
            self.params['metrics'].append('CRPS_score_val')

    def on_batch_end(self, batch, logs={}):
        if (self.include_on_batch):
            logs['CRPS_score_val'] = float('-inf')

    def on_epoch_end(self, epoch, logs={}):
        logs['CRPS_score_val'] = float('-inf')
            
        if (self.validation):
            X_valid, y_valid = self.validation[0], self.validation[1]
            y_pred = self.model.predict(X_valid)
            y_true = np.clip(np.cumsum(y_valid, axis=1), 0, 1)
            y_pred = np.clip(np.cumsum(y_pred, axis=1), 0, 1)
            val_s = ((y_true - y_pred) ** 2).sum(axis=1).sum(axis=0) / (199 * X_valid.shape[0])
            val_s = np.round(val_s, 6)
            logs['CRPS_score_val'] = val_s

# %%
def get_model(x_tr,y_tr,x_val,y_val):
    inp = Input(shape = (x_tr.shape[1],))
    x = Dense(1024, input_dim=X.shape[1], activation='relu')(inp)
    x = Dropout(0.5)(x)
    x = BatchNormalization()(x)
    x = Dense(512, activation='relu')(x)
    x = Dropout(0.5)(x)
    x = BatchNormalization()(x)
    x = Dense(256, activation='relu')(x)
    x = Dropout(0.5)(x)
    x = BatchNormalization()(x)
    
    out = Dense(199, activation='softmax')(x)
    model = Model(inp,out)
    model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=[])
    #add lookahead
#     lookahead = Lookahead(k=5, alpha=0.5) # Initialize Lookahead
#     lookahead.inject(model) # add into model

    
    es = EarlyStopping(monitor='CRPS_score_val', 
                       mode='min',
                       restore_best_weights=True, 
                       verbose=1, 
                       patience=10)

    mc = ModelCheckpoint('best_model.h5',monitor='CRPS_score_val',mode='min',
                                   save_best_only=True, verbose=1, save_weights_only=True)
    
    bsz = 1024
    steps = x_tr.shape[0]/bsz
    


    model.fit(x_tr, y_tr,callbacks=[CRPSCallback(validation = (x_val,y_val)),es,mc], epochs=100, batch_size=bsz,verbose=1)
    model.load_weights("best_model.h5")
    
    y_pred = model.predict(x_val)
    y_valid = y_val
    y_true = np.clip(np.cumsum(y_valid, axis=1), 0, 1)
    y_pred = np.clip(np.cumsum(y_pred, axis=1), 0, 1)
    val_s = ((y_true - y_pred) ** 2).sum(axis=1).sum(axis=0) / (199 * x_val.shape[0])
    crps = np.round(val_s, 6)

    return model,crps

# %%
X
# Out:
# array([[-1.25301814,  1.67362393, -0.18639474, ...,  2.19167184,
#         -1.6676964 , -0.07074881],
#        [-0.91178801, -0.5975058 , -0.18639474, ..., -0.77134982,
#          0.44022727, -0.07074881],
#        [-1.34898912,  1.67362393, -0.18639474, ..., -0.77134982,
#          0.44022727,  0.01629631],
#        ...,
#        [-0.91178801, -0.5975058 , -0.18639474, ...,  2.19167184,
#         -1.93118686,  0.01629631],
#        [-1.18903749, -0.5975058 , -0.18639474, ..., -0.77134982,
#          0.44022727,  0.01629631],
#        [ 1.35952508, -0.5975058 , -0.18639474, ...,  0.71016101,
#         -0.08675365,  0.19038655]])

# %%
from sklearn.model_selection import train_test_split, KFold
import time

losses = []
models = []
crps_csv = []

s_time = time.time()


for k in range(2):
    kfold = KFold(10, random_state = 42 + k, shuffle = True)
    for k_fold, (tr_inds, val_inds) in enumerate(kfold.split(yards)):
        print("-----------")
        print("-----------")
        tr_x,tr_y = X[tr_inds],y[tr_inds]
        val_x,val_y = X[val_inds],y[val_inds]
        model,crps = get_model(tr_x,tr_y,val_x,val_y)
        models.append(model)
        print("the %d fold crps is %f"%((k_fold+1),crps))
        crps_csv.append(crps)
 
print("mean crps is %f"%np.mean(crps_csv))


def predict(x_te):
    model_num = len(models)
    for k,m in enumerate(models):
        if k==0:
            y_pred = m.predict(x_te,batch_size=1024)
        else:
            y_pred+=m.predict(x_te,batch_size=1024)
            
    y_pred = y_pred / model_num
    
    return y_pred
# Out:
# -----------
# -----------
# validation shape 2
# Epoch 1/100
# 20853/20853 [==============================] - 2s 82us/step - loss: 5.5853
#
# Epoch 00001: CRPS_score_val improved from inf to 0.08193, saving model to best_model.h5
# Epoch 2/100
# 20853/20853 [==============================] - 1s 57us/step - loss: 5.0793
#
# Epoch 00002: CRPS_score_val improved from 0.08193 to 0.07675, saving model to best_model.h5
# Epoch 3/100
# 20853/20853 [==============================] - 1s 59us/step - loss: 4.6179
#
# Epoch 00003: CRPS_score_val improved from 0.07675 to 0.05974, saving model to best_model.h5
# Epoch 4/100
# 20853/20853 [==============================] - 1s 59us/step - loss: 4.1528
#
# Epoch 00004: CRPS_score_val improved from 0.05974 to 0.03558, saving model to best_model.h5
# Epoch 5/100
# 20853/20853 [==============================] - 1s 61us/step - loss: 3.7224
#
# Epoch 00005: CRPS_score_val improved from 0.03558 to 0.02150, saving model to best_model.h5
# Epoch 6/100
# 20853/20853 [==============================] - 1s 58us/step - loss: 3.3758
#
# Epoch 00006: CRPS_score_val improved from 0.02150 to 0.01625, saving model to best_model.h5
# Epoch 7/100
# 20853/20853 [==============================] - 1s 60us/step - loss: 3.1412
#
# Epoch 00007: CRPS_score_val improved from 0.01625 to 0.01445, saving model to best_model.h5
# Epoch 8/100
# 20853/20853 [==============================] - 1s 60us/step - loss: 3.0023: 0s
#
# Epoch 00008: CRPS_score_val improved from 0.01445 to 0.01381, saving model to best_model.h5
# Epoch 9/100
# 20853/20853 [==============================] - 1s 59us/step - loss: 2.9293
#
# Epoch 00009: CRPS_score_val improved from 0.01381 to 0.01354, saving model to best_model.h5
# Epoch 10/100
# 20853/20853 [==============================] - 1s 58us/step - loss: 2.8784
#
# Epoch 00010: CRPS_score_val improved from 0.01354 to 0.01343, saving model to best_model.h5
# Epoch 11/100
# 20853/20853 [==============================] - 1s 58us/step - loss: 2.8445
#
# Epoch 00011: CRPS_score_val improved from 0.01343 to 0.01337, saving model to best_model.h5
# Epoch 12/100
# 20853/20853 [==============================] - 1s 57us/step - loss: 2.8210
#
# Epoch 00012: CRPS_score_val improved from 0.01337 to 0.01331, saving model to best_model.h5
# Epoch 13/100
# 20853/20853 [==============================] - 1s 57us/step - loss: 2.8070
#
# Epoch 00013: CRPS_score_val improved from 0.01331 to 0.01327, saving model to best_model.h5
# Epoch 14/100
# 20853/20853 [==============================] - 1s 57us/step - loss: 2.7851
#
# Epoch 00014: CRPS_score_val improved from 0.01327 to 0.01322, saving model to best_model.h5
# Epoch 15/100
# 20853/20853 [==============================] - 1s 58us/step - loss: 2.7769: 0s - loss
#
# Epoch 00015: CRPS_score_val improved from 0.01322 to 0.01319, saving model to best_model.h5
# Epoch 16/100
# 20853/20853 [==============================] - 1s 57us/step - loss: 2.7617
#
# Epoch 00016: CRPS_score_val improved from 0.01319 to 0.01315, saving model to best_model.h5
# Epoch 17/100
# 20853/20853 [==============================] - 1s 57us/step - loss: 2.7537
#
# Epoch 00017: CRPS_score_val improved from 0.01315 to 0.01311, saving model to best_model.h5
# Epoch 18/100
# 20853/20853 [==============================] - 1s 58us/step - loss: 2.7486
#
# Epoch 00018: CRPS_score_val improved from 0.01311 to 0.01308, saving model to best_model.h5
# Epoch 19/100
# 20853/20853 [==============================] - 1s 58us/step - loss: 2.7319
#
# Epoch 00019: CRPS_score_val improved from 0.01308 to 0.01306, saving model to best_model.h5
# Epoch 20/100
# 20853/20853 [==============================] - 1s 58us/step - loss: 2.7321
#
# Epoch 00020: CRPS_score_val improved from 0.01306 to 0.01303, saving model to best_model.h5
# Epoch 21/100
# 20853/20853 [==============================] - 1s 59us/step - loss: 2.7227
#
# Epoch 00021: CRPS_score_val improved from 0.01303 to 0.01302, saving model to best_model.h5
# Epoch 22/100
# 20853/20853 [==============================] - 1s 57us/step - loss: 2.7202
#
# Epoch 00022: CRPS_score_val improved from 0.01302 to 0.01300, saving model to best_model.h5
# Epoch 23/100
# 20853/20853 [==============================] - 1s 56us/step - loss: 2.7125
#
# Epoch 00023: CRPS_score_val improved from 0.01300 to 0.01298, saving model to best_model.h5
# Epoch 24/100
# 20853/20853 [==============================] - 1s 58us/step - loss: 2.7127
#
# Epoch 00024: CRPS_score_val improved from 0.01298 to 0.01296, saving model to best_model.h5
# Epoch 25/100
# 20853/20853 [==============================] - 1s 57us/step - loss: 2.7023
#
# Epoch 00025: CRPS_score_val did not improve from 0.01296
# Epoch 26/100
# 20853/20853 [==============================] - 1s 58us/step - loss: 2.6990
#
# Epoch 00026: CRPS_score_val did not improve from 0.01296
# Epoch 27/100
# 20853/20853 [==============================] - 1s 60us/step - loss: 2.6928
#
# Epoch 00027: CRPS_score_val improved from 0.01296 to 0.01295, saving model to best_model.h5
# Epoch 28/100
# 20853/20853 [==============================] - 1s 58us/step - loss: 2.6933: 0
#
# Epoch 00028: CRPS_score_val improved from 0.01295 to 0.01294, saving model to best_model.h5
# Epoch 29/100
# 20853/20853 [==============================] - 1s 58us/step - loss: 2.6913
#
# Epoch 00029: CRPS_score_val improved from 0.01294 to 0.01294, saving model to best_model.h5
# Epoch 30/100
# 20853/20853 [==============================] - 1s 59us/step - loss: 2.6885
#
# Epoch 00030: CRPS_score_val improved from 0.01294 to 0.01293, saving model to best_model.h5
# Epoch 31/100
# 20853/20853 [==============================] - 1s 58us/step - loss: 2.6842
#
# Epoch 00031: CRPS_score_val improved from 0.01293 to 0.01293, saving model to best_model.h5
# Epoch 32/100
# 20853/20853 [==============================] - 1s 59us/step - loss: 2.6825
#
# Epoch 00032: CRPS_score_val improved from 0.01293 to 0.01292, saving model to best_model.h5
# Epoch 33/100
# 20853/20853 [==============================] - 1s 59us/step - loss: 2.6723
#
# Epoch 00033: CRPS_score_val did not improve from 0.01292
# Epoch 34/100
# 20853/20853 [==============================] - 1s 58us/step - loss: 2.6688
#
# Epoch 00034: CRPS_score_val did not improve from 0.01292
# Epoch 35/100
# 20853/20853 [==============================] - 1s 59us/step - loss: 2.6678
#
# Epoch 00035: CRPS_score_val improved from 0.01292 to 0.01292, saving model to best_model.h5
# Epoch 36/100
# 20853/20853 [==============================] - 1s 57us/step - loss: 2.6611: 0s - loss:
#
# Epoch 00036: CRPS_score_val improved from 0.01292 to 0.01291, saving model to best_model.h5
# Epoch 37/100
# 20853/20853 [==============================] - 1s 59us/step - loss: 2.6630
#
# Epoch 00037: CRPS_score_val did not improve from 0.01291
# Epoch 38/100
# 20853/20853 [==============================] - 1s 57us/step - loss: 2.6580
#
# Epoch 00038: CRPS_score_val did not improve from 0.01291
# Epoch 39/100
# 20853/20853 [==============================] - 1s 58us/step - loss: 2.6611
#
# Epoch 00039: CRPS_score_val did not improve from 0.01291
# Epoch 40/100
# 20853/20853 [==============================] - 1s 58us/step - loss: 2.6611
#
# Epoch 00040: CRPS_score_val did not improve from 0.01291
# Epoch 41/100
# 20853/20853 [==============================] - 1s 58us/step - loss: 2.6500: 0s - l
#
# Epoch 00041: CRPS_score_val did not improve from 0.01291
# Epoch 42/100
# 20853/20853 [==============================] - 1s 57us/step - loss: 2.6525
#
# Epoch 00042: CRPS_score_val did not improve from 0.01291
# Epoch 43/100
# 20853/20853 [==============================] - 1s 58us/step - loss: 2.6484
#
# Epoch 00043: CRPS_score_val improved from 0.01291 to 0.01290, saving model to best_model.h5
# Epoch 44/100
# 20853/20853 [==============================] - 1s 64us/step - loss: 2.6422
#
# Epoch 00044: CRPS_score_val improved from 0.01290 to 0.01290, saving model to best_model.h5
# Epoch 45/100
# 20853/20853 [==============================] - 1s 59us/step - loss: 2.6426: 0s
#
# Epoch 00045: CRPS_score_val improved from 0.01290 to 0.01289, saving model to best_model.h5
# Epoch 46/100
# 20853/20853 [==============================] - 1s 59us/step - loss: 2.6354
#
# Epoch 00046: CRPS_score_val improved from 0.01289 to 0.01289, saving model to best_model.h5
# Epoch 47/100
# 20853/20853 [==============================] - 1s 60us/step - loss: 2.6315
# Epoch 00047: CRPS_score_val did not improve from 0.01289
# Epoch 48/100
# 20853/20853 [==============================] - 1s 59us/step - loss: 2.6287
#
# Epoch 00048: CRPS_score_val improved from 0.01289 to 0.01287, saving model to best_model.h5
# Epoch 49/100
# 20853/20853 [==============================] - 1s 59us/step - loss: 2.6264
#
# Epoch 00049: CRPS_score_val did not improve from 0.01287
# Epoch 50/100
# 20853/20853 [==============================] - 1s 61us/step - loss: 2.6206
#
# Epoch 00050: CRPS_score_val did not improve from 0.01287
# Epoch 51/100
# 20853/20853 [==============================] - 1s 61us/step - loss: 2.6238: 0s - los
#
# Epoch 00051: CRPS_score_val did not improve from 0.01287
# Epoch 52/100
# 20853/20853 [==============================] - 1s 59us/step - loss: 2.6230:
#
# Epoch 00052: CRPS_score_val did not improve from 0.01287
# Epoch 53/100
# 20853/20853 [==============================] - 1s 60us/step - loss: 2.6128
#
# Epoch 00053: CRPS_score_val did not improve from 0.01287
# Epoch 54/100
# 20853/20853 [==============================] - 1s 59us/step - loss: 2.6100
#
# Epoch 00054: CRPS_score_val did not improve from 0.01287
# Epoch 55/100
# 20853/20853 [==============================] - 1s 61us/step - loss: 2.6071
#
# Epoch 00055: CRPS_score_val did not improve from 0.01287
# Epoch 56/100
# 20853/20853 [==============================] - 1s 59us/step - loss: 2.6081
#
# Epoch 00056: CRPS_score_val did not improve from 0.01287
# Epoch 57/100
# 20853/20853 [==============================] - 1s 60us/step - loss: 2.6103
#
# Epoch 00057: CRPS_score_val did not improve from 0.01287
# Epoch 58/100
# 20853/20853 [==============================] - 1s 60us/step - loss: 2.5999
# Restoring model weights from the end of the best epoch
#
# Epoch 00058: CRPS_score_val did not improve from 0.01287
# Epoch 00058: early stopping
# the 1 fold crps is 0.012875
# -----------
# -----------
# validation shape 2
# Epoch 1/100
# 20854/20854 [==============================] - 2s 85us/step - loss: 5.5470
#
# Epoch 00001: CRPS_score_val improved from inf to 0.08237, saving model to best_model.h5
# Epoch 2/100
# 20854/20854 [==============================] - 1s 58us/step - loss: 5.0286
#
# Epoch 00002: CRPS_score_val improved from 0.08237 to 0.07616, saving model to best_model.h5
# Epoch 3/100
# 20854/20854 [==============================] - 1s 59us/step - loss: 4.5492
#
# Epoch 00003: CRPS_score_val improved from 0.07616 to 0.05727, saving model to best_model.h5
# Epoch 4/100
# 20854/20854 [==============================] - 1s 58us/step - loss: 4.1115
#
# Epoch 00004: CRPS_score_val improved from 0.05727 to 0.03526, saving model to best_model.h5
# Epoch 5/100
# 20854/20854 [==============================] - 1s 58us/step - loss: 3.6943
#
# Epoch 00005: CRPS_score_val improved from 0.03526 to 0.02165, saving model to best_model.h5
# Epoch 6/100
# 20854/20854 [==============================] - 1s 58us/step - loss: 3.3856
#
# Epoch 00006: CRPS_score_val improved from 0.02165 to 0.01686, saving model to best_model.h5
# Epoch 7/100
# 20854/20854 [==============================] - 1s 59us/step - loss: 3.1614
#
# Epoch 00007: CRPS_score_val improved from 0.01686 to 0.01466, saving model to best_model.h5
# Epoch 8/100
# 20854/20854 [==============================] - 1s 60us/step - loss: 3.0086
#
# Epoch 00008: CRPS_score_val improved from 0.01466 to 0.01381, saving model to best_model.h5
# Epoch 9/100
# 20854/20854 [==============================] - 1s 59us/step - loss: 2.9415
#
# Epoch 00009: CRPS_score_val improved from 0.01381 to 0.01354, saving model to best_model.h5
# Epoch 10/100
# 20854/20854 [==============================] - 1s 59us/step - loss: 2.8895
#
# Epoch 00010: CRPS_score_val improved from 0.01354 to 0.01338, saving model to best_model.h5
# Epoch 11/100
# 20854/20854 [==============================] - 1s 61us/step - loss: 2.8624
#
# Epoch 00011: CRPS_score_val improved from 0.01338 to 0.01328, saving model to best_model.h5
# Epoch 12/100
# 20854/20854 [==============================] - 1s 58us/step - loss: 2.8234
#
# Epoch 00012: CRPS_score_val improved from 0.01328 to 0.01324, saving model to best_model.h5
# Epoch 13/100
# 20854/20854 [==============================] - 1s 59us/step - loss: 2.8195
#
# Epoch 00013: CRPS_score_val improved from 0.01324 to 0.01318, saving model to best_model.h5
# Epoch 14/100
# 20854/20854 [==============================] - 1s 58us/step - loss: 2.7956:
#
# Epoch 00014: CRPS_score_val improved from 0.01318 to 0.01315, saving model to best_model.h5
# Epoch 15/100
# 20854/20854 [==============================] - 1s 58us/step - loss: 2.7830
#
# Epoch 00015: CRPS_score_val improved from 0.01315 to 0.01311, saving model to best_model.h5
# Epoch 16/100
# 20854/20854 [==============================] - 1s 58us/step - loss: 2.7720: 0s - loss: 2.7
#
# Epoch 00016: CRPS_score_val improved from 0.01311 to 0.01306, saving model to best_model.h5
# Epoch 17/100
# 20854/20854 [==============================] - 1s 60us/step - loss: 2.7648
#
# Epoch 00017: CRPS_score_val improved from 0.01306 to 0.01303, saving model to best_model.h5
# Epoch 18/100
# 20854/20854 [==============================] - 1s 59us/step - loss: 2.7475
#
# Epoch 00018: CRPS_score_val improved from 0.01303 to 0.01300, saving model to best_model.h5
# Epoch 19/100
# 20854/20854 [==============================] - 1s 61us/step - loss: 2.7480
#
# Epoch 00019: CRPS_score_val improved from 0.01300 to 0.01297, saving model to best_model.h5
# Epoch 20/100
# 20854/20854 [==============================] - 1s 61us/step - loss: 2.7379
#
# Epoch 00020: CRPS_score_val improved from 0.01297 to 0.01295, saving model to best_model.h5
# Epoch 21/100
# 20854/20854 [==============================] - 1s 59us/step - loss: 2.7360
#
# Epoch 00021: CRPS_score_val improved from 0.01295 to 0.01294, saving model to best_model.h5
# Epoch 22/100
# 20854/20854 [==============================] - 1s 61us/step - loss: 2.7216
#
# Epoch 00022: CRPS_score_val improved from 0.01294 to 0.01292, saving model to best_model.h5
# Epoch 23/100
# 20854/20854 [==============================] - 1s 60us/step - loss: 2.7168
#
# Epoch 00023: CRPS_score_val improved from 0.01292 to 0.01289, saving model to best_model.h5
# Epoch 24/100
# 20854/20854 [==============================] - 1s 61us/step - loss: 2.7184
#
# Epoch 00024: CRPS_score_val improved from 0.01289 to 0.01288, saving model to best_model.h5
# Epoch 25/100
# 20854/20854 [==============================] - 1s 59us/step - loss: 2.7127
#
# Epoch 00025: CRPS_score_val improved from 0.01288 to 0.01286, saving model to best_model.h5
# Epoch 26/100
# 20854/20854 [==============================] - 1s 59us/step - loss: 2.7045: 0s
#
# Epoch 00026: CRPS_score_val improved from 0.01286 to 0.01285, saving model to best_model.h5
# Epoch 27/100
# 20854/20854 [==============================] - 1s 59us/step - loss: 2.7023
#
# Epoch 00027: CRPS_score_val improved from 0.01285 to 0.01285, saving model to best_model.h5
# Epoch 28/100
# 20854/20854 [==============================] - 1s 59us/step - loss: 2.6978
#
# Epoch 00028: CRPS_score_val improved from 0.01285 to 0.01284, saving model to best_model.h5
# Epoch 29/100
# 20854/20854 [==============================] - 1s 60us/step - loss: 2.6909
#
# Epoch 00029: CRPS_score_val improved from 0.01284 to 0.01283, saving model to best_model.h5
# Epoch 30/100
# 20854/20854 [==============================] - 1s 59us/step - loss: 2.6912
#
# Epoch 00030: CRPS_score_val improved from 0.01283 to 0.01281, saving model to best_model.h5
# Epoch 31/100
# 20854/20854 [==============================] - 1s 61us/step - loss: 2.6920
#
# Epoch 00031: CRPS_score_val improved from 0.01281 to 0.01281, saving model to best_model.h5
# Epoch 32/100
# 20854/20854 [==============================] - 1s 59us/step - loss: 2.6851
#
# Epoch 00032: CRPS_score_val improved from 0.01281 to 0.01281, saving model to best_model.h5
# Epoch 33/100
# 20854/20854 [==============================] - 1s 59us/step - loss: 2.6812
#
# Epoch 00033: CRPS_score_val improved from 0.01281 to 0.01280, saving model to best_model.h5
# Epoch 34/100
# 20854/20854 [==============================] - 1s 58us/step - loss: 2.6797: 0s - loss - ETA: 0s - loss: 2.6
#
# Epoch 00034: CRPS_score_val improved from 0.01280 to 0.01279, saving model to best_model.h5
# Epoch 35/100
# 20854/20854 [==============================] - 1s 58us/step - loss: 2.6725
# Epoch 00035: CRPS_score_val improved from 0.01279 to 0.01278, saving model to best_model.h5
# Epoch 36/100
# 20854/20854 [==============================] - 1s 57us/step - loss: 2.6715: 0s - lo
#
# Epoch 00036: CRPS_score_val did not improve from 0.01278
# Epoch 37/100
# 20854/20854 [==============================] - 1s 58us/step - loss: 2.6701
#
# Epoch 00037: CRPS_score_val did not improve from 0.01278
# Epoch 38/100
# 20854/20854 [==============================] - 1s 57us/step - loss: 2.6654
#
# Epoch 00038: CRPS_score_val did not improve from 0.01278
# Epoch 39/100
# 20854/20854 [==============================] - 1s 57us/step - loss: 2.6629
#
# Epoch 00039: CRPS_score_val improved from 0.01278 to 0.01277, saving model to best_model.h5
# Epoch 40/100
# 20854/20854 [==============================] - 1s 58us/step - loss: 2.6606
#
# Epoch 00040: CRPS_score_val improved from 0.01277 to 0.01276, saving model to best_model.h5
# Epoch 41/100
# 20854/20854 [==============================] - 1s 58us/step - loss: 2.6597
#
# Epoch 00041: CRPS_score_val did not improve from 0.01276
# Epoch 42/100
# 20854/20854 [==============================] - 1s 58us/step - loss: 2.6558
#
# Epoch 00042: CRPS_score_val improved from 0.01276 to 0.01276, saving model to best_model.h5
# Epoch 43/100
# 20854/20854 [==============================] - 1s 57us/step - loss: 2.6556
#
# Epoch 00043: CRPS_score_val did not improve from 0.01276
# Epoch 44/100
# 20854/20854 [==============================] - 1s 57us/step - loss: 2.6509: 0s - loss
#
# Epoch 00044: CRPS_score_val did not improve from 0.01276
# Epoch 45/100
# 20854/20854 [==============================] - 1s 58us/step - loss: 2.6455
#
# Epoch 00045: CRPS_score_val improved from 0.01276 to 0.01275, saving model to best_model.h5
# Epoch 46/100
# 20854/20854 [==============================] - 1s 58us/step - loss: 2.6444
#
# Epoch 00046: CRPS_score_val improved from 0.01275 to 0.01274, saving model to best_model.h5
# Epoch 47/100
# 20854/20854 [==============================] - 1s 58us/step - loss: 2.6422
#
# Epoch 00047: CRPS_score_val improved from 0.01274 to 0.01274, saving model to best_model.h5
# Epoch 48/100
# 20854/20854 [==============================] - 1s 57us/step - loss: 2.6373
#
# Epoch 00048: CRPS_score_val improved from 0.01274 to 0.01273, saving model to best_model.h5
# Epoch 49/100
# 20854/20854 [==============================] - 1s 57us/step - loss: 2.6369
#
# Epoch 00049: CRPS_score_val did not improve from 0.01273
# Epoch 50/100
# 20854/20854 [==============================] - 1s 57us/step - loss: 2.6314
#
# Epoch 00050: CRPS_score_val did not improve from 0.01273
# Epoch 51/100
# 20854/20854 [==============================] - 1s 58us/step - loss: 2.6327
#
# Epoch 00051: CRPS_score_val did not improve from 0.01273
# Epoch 52/100
# 20854/20854 [==============================] - 1s 59us/step - loss: 2.6238
#
# Epoch 00052: CRPS_score_val improved from 0.01273 to 0.01272, saving model to best_model.h5
# Epoch 53/100
# 20854/20854 [==============================] - 1s 57us/step - loss: 2.6240
#
# Epoch 00053: CRPS_score_val did not improve from 0.01272
# Epoch 54/100
# 20854/20854 [==============================] - 1s 58us/step - loss: 2.6210
#
# Epoch 00054: CRPS_score_val did not improve from 0.01272
# Epoch 55/100
# 20854/20854 [==============================] - 1s 57us/step - loss: 2.6176: 0s -
#
# Epoch 00055: CRPS_score_val improved from 0.01272 to 0.01272, saving model to best_model.h5
# Epoch 56/100
# 20854/20854 [==============================] - 1s 57us/step - loss: 2.6163
#
# Epoch 00056: CRPS_score_val did not improve from 0.01272
# Epoch 57/100
# 20854/20854 [==============================] - 1s 58us/step - loss: 2.6085:
#
# Epoch 00057: CRPS_score_val did not improve from 0.01272
# Epoch 58/100
# 20854/20854 [==============================] - 1s 58us/step - loss: 2.6088
#
# Epoch 00058: CRPS_score_val improved from 0.01272 to 0.01271, saving model to best_model.h5
# Epoch 59/100
# 20854/20854 [==============================] - 1s 59us/step - loss: 2.6029
#
# Epoch 00059: CRPS_score_val did not improve from 0.01271
# Epoch 60/100
# 20854/20854 [==============================] - 1s 57us/step - loss: 2.6045
#
# Epoch 00060: CRPS_score_val improved from 0.01271 to 0.01270, saving model to best_model.h5
# Epoch 61/100
# 20854/20854 [==============================] - 1s 57us/step - loss: 2.6046
#
# Epoch 00061: CRPS_score_val did not improve from 0.01270
# Epoch 62/100
# 20854/20854 [==============================] - 1s 57us/step - loss: 2.5945
#
# Epoch 00062: CRPS_score_val improved from 0.01270 to 0.01269, saving model to best_model.h5
# Epoch 63/100
# 20854/20854 [==============================] - 1s 59us/step - loss: 2.5949
#
# Epoch 00063: CRPS_score_val did not improve from 0.01269
# Epoch 64/100
# 20854/20854 [==============================] - 1s 58us/step - loss: 2.5925: 0s
#
# Epoch 00064: CRPS_score_val did not improve from 0.01269
# Epoch 65/100
# 20854/20854 [==============================] - 1s 59us/step - loss: 2.5909
#
# Epoch 00065: CRPS_score_val improved from 0.01269 to 0.01269, saving model to best_model.h5
# Epoch 66/100
# 20854/20854 [==============================] - 1s 60us/step - loss: 2.5890
#
# Epoch 00066: CRPS_score_val did not improve from 0.01269
# Epoch 67/100
# 20854/20854 [==============================] - 1s 62us/step - loss: 2.5775
#
# Epoch 00067: CRPS_score_val did not improve from 0.01269
# Epoch 68/100
# 20854/20854 [==============================] - 1s 59us/step - loss: 2.5818
#
# Epoch 00068: CRPS_score_val did not improve from 0.01269
# Epoch 69/100
# 20854/20854 [==============================] - 1s 60us/step - loss: 2.5761
#
# Epoch 00069: CRPS_score_val did not improve from 0.01269
# Epoch 70/100
# 20854/20854 [==============================] - 1s 59us/step - loss: 2.5694
#
# Epoch 00070: CRPS_score_val did not improve from 0.01269
# Epoch 71/100
# 20854/20854 [==============================] - 1s 59us/step - loss: 2.5716
#
# Epoch 00071: CRPS_score_val did not improve from 0.01269
# Epoch 72/100
# 20854/20854 [==============================] - 1s 61us/step - loss: 2.5646
#
# Epoch 00072: CRPS_score_val improved from 0.01269 to 0.01269, saving model to best_model.h5
# Epoch 73/100
# 20854/20854 [==============================] - 1s 60us/step - loss: 2.5749
#
# Epoch 00073: CRPS_score_val improved from 0.01269 to 0.01267, saving model to best_model.h5
# Epoch 74/100
# 20854/20854 [==============================] - 1s 61us/step - loss: 2.5687
#
# Epoch 00074: CRPS_score_val did not improve from 0.01267
# Epoch 75/100
# 20854/20854 [==============================] - 1s 62us/step - loss: 2.5614: 0s
#
# Epoch 00075: CRPS_score_val did not improve from 0.01267
# Epoch 76/100
# 20854/20854 [==============================] - 1s 62us/step - loss: 2.5558
#
# Epoch 00076: CRPS_score_val did not improve from 0.01267
# Epoch 77/100
# 20854/20854 [==============================] - 1s 60us/step - loss: 2.5580
#
# Epoch 00077: CRPS_score_val did not improve from 0.01267
# Epoch 78/100
# 20854/20854 [==============================] - 1s 58us/step - loss: 2.5518
#
# Epoch 00078: CRPS_score_val improved from 0.01267 to 0.01266, saving model to best_model.h5
# Epoch 79/100
# 20854/20854 [==============================] - 1s 57us/step - loss: 2.5506
#
# Epoch 00079: CRPS_score_val did not improve from 0.01266
# Epoch 80/100
# 20854/20854 [==============================] - 1s 59us/step - loss: 2.5423
#
# Epoch 00080: CRPS_score_val did not improve from 0.01266
# Epoch 81/100
# 20854/20854 [==============================] - 1s 60us/step - loss: 2.5453: 0
#
# Epoch 00081: CRPS_score_val did not improve from 0.01266
# Epoch 82/100
# 20854/20854 [==============================] - 1s 61us/step - loss: 2.5363
#
# Epoch 00082: CRPS_score_val did not improve from 0.01266
# Epoch 83/100
# 20854/20854 [==============================] - 1s 58us/step - loss: 2.5331
#
# Epoch 00083: CRPS_score_val did not improve from 0.01266
# Epoch 84/100
# 20854/20854 [==============================] - 1s 63us/step - loss: 2.5324
#
# Epoch 00084: CRPS_score_val did not improve from 0.01266
# Epoch 85/100
# 20854/20854 [==============================] - 1s 59us/step - loss: 2.5312
#
# Epoch 00085: CRPS_score_val did not improve from 0.01266
# Epoch 86/100
# 20854/20854 [==============================] - 1s 59us/step - loss: 2.5225
#
# Epoch 00086: CRPS_score_val did not improve from 0.01266
# Epoch 87/100
# 20854/20854 [==============================] - 1s 59us/step - loss: 2.5187
#
# Epoch 00087: CRPS_score_val did not improve from 0.01266
# Epoch 88/100
# 20854/20854 [==============================] - 1s 62us/step - loss: 2.5157
# Restoring model weights from the end of the best epoch
#
# Epoch 00088: CRPS_score_val did not improve from 0.01266
# Epoch 00088: early stopping
# the 2 fold crps is 0.012661
# -----------
# -----------
# validation shape 2
# Epoch 1/100
# 20854/20854 [==============================] - 2s 83us/step - loss: 5.5473
#
# Epoch 00001: CRPS_score_val improved from inf to 0.08190, saving model to best_model.h5
# Epoch 2/100
# 20854/20854 [==============================] - 1s 62us/step - loss: 5.0434
#
# Epoch 00002: CRPS_score_val improved from 0.08190 to 0.07546, saving model to best_model.h5
# Epoch 3/100
# 20854/20854 [==============================] - 1s 65us/step - loss: 4.5759
#
# Epoch 00003: CRPS_score_val improved from 0.07546 to 0.05609, saving model to best_model.h5
# Epoch 4/100
# 20854/20854 [==============================] - 1s 62us/step - loss: 4.1115
#
# Epoch 00004: CRPS_score_val improved from 0.05609 to 0.03453, saving model to best_model.h5
# Epoch 5/100
# 20854/20854 [==============================] - 1s 59us/step - loss: 3.7207: 0s
#
# Epoch 00005: CRPS_score_val improved from 0.03453 to 0.02232, saving model to best_model.h5
# Epoch 6/100
# 20854/20854 [==============================] - 1s 60us/step - loss: 3.3967
#
# Epoch 00006: CRPS_score_val improved from 0.02232 to 0.01686, saving model to best_model.h5
# Epoch 7/100
# 20854/20854 [==============================] - 1s 61us/step - loss: 3.1547
#
# Epoch 00007: CRPS_score_val improved from 0.01686 to 0.01449, saving model to best_model.h5
# Epoch 8/100
# 20854/20854 [==============================] - 1s 64us/step - loss: 3.0109
#
# Epoch 00008: CRPS_score_val improved from 0.01449 to 0.01371, saving model to best_model.h5
# Epoch 9/100
# 20854/20854 [==============================] - 1s 60us/step - loss: 2.9313
#
# Epoch 00009: CRPS_score_val improved from 0.01371 to 0.01347, saving model to best_model.h5
# Epoch 10/100
# 20854/20854 [==============================] - 1s 60us/step - loss: 2.8839
#
# Epoch 00010: CRPS_score_val improved from 0.01347 to 0.01328, saving model to best_model.h5
# Epoch 11/100
# 20854/20854 [==============================] - 1s 58us/step - loss: 2.8496
#
# Epoch 00011: CRPS_score_val improved from 0.01328 to 0.01323, saving model to best_model.h5
# Epoch 12/100
# 20854/20854 [==============================] - 1s 58us/step - loss: 2.8278: 0s
#
# Epoch 00012: CRPS_score_val improved from 0.01323 to 0.01317, saving model to best_model.h5
# Epoch 13/100
# 20854/20854 [==============================] - 1s 60us/step - loss: 2.7997
#
# Epoch 00013: CRPS_score_val improved from 0.01317 to 0.01311, saving model to best_model.h5
# Epoch 14/100
# 20854/20854 [==============================] - 1s 60us/step - loss: 2.7865
#
# Epoch 00014: CRPS_score_val improved from 0.01311 to 0.01308, saving model to best_model.h5
# Epoch 15/100
# 20854/20854 [==============================] - 1s 59us/step - loss: 2.7761
#
# Epoch 00015: CRPS_score_val improved from 0.01308 to 0.01305, saving model to best_model.h5
# Epoch 16/100
# 20854/20854 [==============================] - 1s 58us/step - loss: 2.7611
#
# Epoch 00016: CRPS_score_val improved from 0.01305 to 0.01298, saving model to best_model.h5
# Epoch 17/100
# 20854/20854 [==============================] - 1s 56us/step - loss: 2.7501
#
# Epoch 00017: CRPS_score_val improved from 0.01298 to 0.01294, saving model to best_model.h5
# Epoch 18/100
# 20854/20854 [==============================] - 1s 57us/step - loss: 2.7428
#
# Epoch 00018: CRPS_score_val improved from 0.01294 to 0.01293, saving model to best_model.h5
# Epoch 19/100
# 20854/20854 [==============================] - 1s 58us/step - loss: 2.7376: 0s - loss: 2.7
#
# Epoch 00019: CRPS_score_val improved from 0.01293 to 0.01290, saving model to best_model.h5
# Epoch 20/100
# 20854/20854 [==============================] - 1s 60us/step - loss: 2.7244
#
# Epoch 00020: CRPS_score_val improved from 0.01290 to 0.01290, saving model to best_model.h5
# Epoch 21/100
# 20854/20854 [==============================] - 1s 61us/step - loss: 2.7236
#
# Epoch 00021: CRPS_score_val improved from 0.01290 to 0.01286, saving model to best_model.h5
# Epoch 22/100
# 20854/20854 [==============================] - 1s 61us/step - loss: 2.7185
#
# Epoch 00022: CRPS_score_val improved from 0.01286 to 0.01285, saving model to best_model.h5
# Epoch 23/100
# 20854/20854 [==============================] - 1s 57us/step - loss: 2.7082
#
# Epoch 00023: CRPS_score_val improved from 0.01285 to 0.01284, saving model to best_model.h5
# Epoch 24/100
# 20854/20854 [==============================] - 1s 63us/step - loss: 2.7092
#
# Epoch 00024: CRPS_score_val improved from 0.01284 to 0.01282, saving model to best_model.h5
# Epoch 25/100
# 20854/20854 [==============================] - 1s 61us/step - loss: 2.7022
#
# Epoch 00025: CRPS_score_val did not improve from 0.01282
# Epoch 26/100
# 20854/20854 [==============================] - 1s 60us/step - loss: 2.7012
#
# Epoch 00026: CRPS_score_val improved from 0.01282 to 0.01282, saving model to best_model.h5
# Epoch 27/100
# 20854/20854 [==============================] - 1s 59us/step - loss: 2.6940
#
# Epoch 00027: CRPS_score_val improved from 0.01282 to 0.01280, saving model to best_model.h5
# Epoch 28/100
# 20854/20854 [==============================] - 1s 58us/step - loss: 2.6934
#
# Epoch 00028: CRPS_score_val improved from 0.01280 to 0.01279, saving model to best_model.h5
# Epoch 29/100
# 20854/20854 [==============================] - 1s 58us/step - loss: 2.6868:
#
# Epoch 00029: CRPS_score_val improved from 0.01279 to 0.01279, saving model to best_model.h5
# Epoch 30/100
# 20854/20854 [==============================] - 1s 57us/step - loss: 2.6830
#
# Epoch 00030: CRPS_score_val improved from 0.01279 to 0.01278, saving model to best_model.h5
# Epoch 31/100
# 20854/20854 [==============================] - 1s 58us/step - loss: 2.6816
#
# Epoch 00031: CRPS_score_val improved from 0.01278 to 0.01276, saving model to best_model.h5
# Epoch 32/100
# 20854/20854 [==============================] - 1s 56us/step - loss: 2.6765
#
# Epoch 00032: CRPS_score_val did not improve from 0.01276
# Epoch 33/100
# 20854/20854 [==============================] - 1s 60us/step - loss: 2.6735: 0s - loss: 2.
#
# Epoch 00033: CRPS_score_val did not improve from 0.01276
# Epoch 34/100
# 20854/20854 [==============================] - 1s 63us/step - loss: 2.6695
#
# Epoch 00034: CRPS_score_val did not improve from 0.01276
# Epoch 35/100
# 20854/20854 [==============================] - 1s 63us/step - loss: 2.6683
#
# Epoch 00035: CRPS_score_val did not improve from 0.01276
# Epoch 36/100
# 20854/20854 [==============================] - 1s 59us/step - loss: 2.6661
#
# Epoch 00036: CRPS_score_val did not improve from 0.01276
# Epoch 37/100
# 20854/20854 [==============================] - 1s 57us/step - loss: 2.6629
#
# Epoch 00037: CRPS_score_val improved from 0.01276 to 0.01275, saving model to best_model.h5
# Epoch 38/100
# 20854/20854 [==============================] - 1s 58us/step - loss: 2.6631
#
# Epoch 00038: CRPS_score_val did not improve from 0.01275
# Epoch 39/100
# 20854/20854 [==============================] - 1s 58us/step - loss: 2.6580
#
# Epoch 00039: CRPS_score_val did not improve from 0.01275
# Epoch 40/100
# 20854/20854 [==============================] - 1s 58us/step - loss: 2.6508
#
# Epoch 00040: CRPS_score_val improved from 0.01275 to 0.01274, saving model to best_model.h5
# Epoch 41/100
# 20854/20854 [==============================] - 1s 61us/step - loss: 2.6517
#
# Epoch 00041: CRPS_score_val did not improve from 0.01274
# Epoch 42/100
# 20854/20854 [==============================] - 1s 60us/step - loss: 2.6456
#
# Epoch 00042: CRPS_score_val did not improve from 0.01274
# Epoch 43/100
# 20854/20854 [==============================] - 1s 60us/step - loss: 2.6427
#
# Epoch 00043: CRPS_score_val improved from 0.01274 to 0.01273, saving model to best_model.h5
# Epoch 44/100
# 20854/20854 [==============================] - 1s 61us/step - loss: 2.6433
#
# Epoch 00044: CRPS_score_val did not improve from 0.01273
# Epoch 45/100
# 20854/20854 [==============================] - 1s 60us/step - loss: 2.6380
#
# Epoch 00045: CRPS_score_val did not improve from 0.01273
# Epoch 46/100
# 20854/20854 [==============================] - 1s 60us/step - loss: 2.6360:
#
# Epoch 00046: CRPS_score_val did not improve from 0.01273
# Epoch 47/100
# 20854/20854 [==============================] - 1s 60us/step - loss: 2.6380
#
# Epoch 00047: CRPS_score_val did not improve from 0.01273
# Epoch 48/100
# 20854/20854 [==============================] - 1s 58us/step - loss: 2.6339
#
# Epoch 00048: CRPS_score_val improved from 0.01273 to 0.01272, saving model to best_model.h5
# Epoch 49/100
# 20854/20854 [==============================] - 1s 57us/step - loss: 2.6290
#
# Epoch 00049: CRPS_score_val did not improve from 0.01272
# Epoch 50/100
# 20854/20854 [==============================] - 1s 62us/step - loss: 2.6286
#
# Epoch 00050: CRPS_score_val did not improve from 0.01272
# Epoch 51/100
# 20854/20854 [==============================] - 1s 61us/step - loss: 2.6223
#
# Epoch 00051: CRPS_score_val did not improve from 0.01272
# Epoch 52/100
# 20854/20854 [==============================] - 1s 60us/step - loss: 2.6202
#
# Epoch 00052: CRPS_score_val did not improve from 0.01272
# Epoch 53/100
# 20854/20854 [==============================] - 1s 64us/step - loss: 2.6178
#
# Epoch 00053: CRPS_score_val did not improve from 0.01272
# Epoch 54/100
# 20854/20854 [==============================] - 1s 62us/step - loss: 2.6166
#
# Epoch 00054: CRPS_score_val did not improve from 0.01272
# Epoch 55/100
# 20854/20854 [==============================] - 1s 60us/step - loss: 2.6090
#
# Epoch 00055: CRPS_score_val did not improve from 0.01272
# Epoch 56/100
# 20854/20854 [==============================] - 1s 61us/step - loss: 2.6121: 0s - loss: 2
#
# Epoch 00056: CRPS_score_val did not improve from 0.01272
# Epoch 57/100
# 20854/20854 [==============================] - 1s 60us/step - loss: 2.6036
#
# Epoch 00057: CRPS_score_val did not improve from 0.01272
# Epoch 58/100
# 20854/20854 [==============================] - 1s 61us/step - loss: 2.6028
# Restoring model weights from the end of the best epoch
#
# Epoch 00058: CRPS_score_val did not improve from 0.01272
# Epoch 00058: early stopping
# the 3 fold crps is 0.012715
# -----------
# -----------
# validation shape 2
# Epoch 1/100
# 20854/20854 [==============================] - 2s 87us/step - loss: 5.5665
#
# Epoch 00001: CRPS_score_val improved from inf to 0.08202, saving model to best_model.h5
# Epoch 2/100
# 20854/20854 [==============================] - 1s 63us/step - loss: 5.0103
#
# Epoch 00002: CRPS_score_val improved from 0.08202 to 0.07525, saving model to best_model.h5
# Epoch 3/100
# 20854/20854 [==============================] - 1s 61us/step - loss: 4.5507
#
# Epoch 00003: CRPS_score_val improved from 0.07525 to 0.05548, saving model to best_model.h5
# Epoch 4/100
# 20854/20854 [==============================] - 1s 61us/step - loss: 4.0945
#
# Epoch 00004: CRPS_score_val improved from 0.05548 to 0.03402, saving model to best_model.h5
# Epoch 5/100
# 20854/20854 [==============================] - 1s 61us/step - loss: 3.6942
#
# Epoch 00005: CRPS_score_val improved from 0.03402 to 0.02099, saving model to best_model.h5
# Epoch 6/100
# 20854/20854 [==============================] - 1s 62us/step - loss: 3.3694
#
# Epoch 00006: CRPS_score_val improved from 0.02099 to 0.01627, saving model to best_model.h5
# Epoch 7/100
# 20854/20854 [==============================] - 1s 62us/step - loss: 3.1420
#
# Epoch 00007: CRPS_score_val improved from 0.01627 to 0.01441, saving model to best_model.h5
# Epoch 8/100
# 20854/20854 [==============================] - 1s 61us/step - loss: 3.0040
#
# Epoch 00008: CRPS_score_val improved from 0.01441 to 0.01376, saving model to best_model.h5
# Epoch 9/100
# 20854/20854 [==============================] - 1s 61us/step - loss: 2.9225
#
# Epoch 00009: CRPS_score_val improved from 0.01376 to 0.01351, saving model to best_model.h5
# Epoch 10/100
# 20854/20854 [==============================] - 1s 61us/step - loss: 2.8742
#
# Epoch 00010: CRPS_score_val improved from 0.01351 to 0.01341, saving model to best_model.h5
# Epoch 11/100
# 20854/20854 [==============================] - 1s 60us/step - loss: 2.8437
#
# Epoch 00011: CRPS_score_val improved from 0.01341 to 0.01331, saving model to best_model.h5
# Epoch 12/100
# 20854/20854 [==============================] - 1s 61us/step - loss: 2.8154
#
# Epoch 00012: CRPS_score_val improved from 0.01331 to 0.01326, saving model to best_model.h5
# Epoch 13/100
# 20854/20854 [==============================] - 1s 62us/step - loss: 2.8013
#
# Epoch 00013: CRPS_score_val improved from 0.01326 to 0.01319, saving model to best_model.h5
# Epoch 14/100
# 20854/20854 [==============================] - 1s 60us/step - loss: 2.7825
#
# Epoch 00014: CRPS_score_val improved from 0.01319 to 0.01316, saving model to best_model.h5
# Epoch 15/100
# 20854/20854 [==============================] - 1s 61us/step - loss: 2.7697
#
# Epoch 00015: CRPS_score_val improved from 0.01316 to 0.01312, saving model to best_model.h5
# Epoch 16/100
# 20854/20854 [==============================] - 1s 61us/step - loss: 2.7667
#
# Epoch 00016: CRPS_score_val improved from 0.01312 to 0.01309, saving model to best_model.h5
# Epoch 17/100
# 20854/20854 [==============================] - 1s 63us/step - loss: 2.7476
#
# Epoch 00017: CRPS_score_val improved from 0.01309 to 0.01306, saving model to best_model.h5
# Epoch 18/100
# 20854/20854 [==============================] - 1s 62us/step - loss: 2.7439
#
# Epoch 00018: CRPS_score_val improved from 0.01306 to 0.01304, saving model to best_model.h5
# Epoch 19/100
# 20854/20854 [==============================] - 1s 61us/step - loss: 2.7322
#
# Epoch 00019: CRPS_score_val improved from 0.01304 to 0.01301, saving model to best_model.h5
# Epoch 20/100
# 20854/20854 [==============================] - 1s 62us/step - loss: 2.7264
#
# Epoch 00020: CRPS_score_val improved from 0.01301 to 0.01298, saving model to best_model.h5
# Epoch 21/100
# 20854/20854 [==============================] - 1s 62us/step - loss: 2.7225
#
# Epoch 00021: CRPS_score_val improved from 0.01298 to 0.01297, saving model to best_model.h5
# Epoch 22/100
# 20854/20854 [==============================] - 1s 60us/step - loss: 2.7179: 0s
#
# Epoch 00022: CRPS_score_val improved from 0.01297 to 0.01296, saving model to best_model.h5
# Epoch 23/100
# 20854/20854 [==============================] - 1s 60us/step - loss: 2.7106
#
# Epoch 00023: CRPS_score_val improved from 0.01296 to 0.01293, saving model to best_model.h5
# Epoch 24/100
# 20854/20854 [==============================] - 1s 60us/step - loss: 2.7074
#
# Epoch 00024: CRPS_score_val did not improve from 0.01293
# Epoch 25/100
# 20854/20854 [==============================] - 1s 62us/step - loss: 2.7057
#
# Epoch 00025: CRPS_score_val improved from 0.01293 to 0.01291, saving model to best_model.h5
# Epoch 26/100
# 20854/20854 [==============================] - 1s 60us/step - loss: 2.6963: 0s - los
#
# Epoch 00026: CRPS_score_val improved from 0.01291 to 0.01290, saving model to best_model.h5
# Epoch 27/100
# 20854/20854 [==============================] - 1s 60us/step - loss: 2.6913
#
# Epoch 00027: CRPS_score_val did not improve from 0.01290
# Epoch 28/100
# 20854/20854 [==============================] - 1s 65us/step - loss: 2.6901
#
# Epoch 00028: CRPS_score_val improved from 0.01290 to 0.01289, saving model to best_model.h5
# Epoch 29/100
# 20854/20854 [==============================] - 1s 63us/step - loss: 2.6881
#
# Epoch 00029: CRPS_score_val improved from 0.01289 to 0.01288, saving model to best_model.h5
# Epoch 30/100
# 20854/20854 [==============================] - 1s 62us/step - loss: 2.6847
#
# Epoch 00030: CRPS_score_val did not improve from 0.01288
# Epoch 31/100
# 20854/20854 [==============================] - 1s 63us/step - loss: 2.6843
#
# Epoch 00031: CRPS_score_val improved from 0.01288 to 0.01286, saving model to best_model.h5
# Epoch 32/100
# 20854/20854 [==============================] - 1s 66us/step - loss: 2.6803
#
# Epoch 00032: CRPS_score_val did not improve from 0.01286
# Epoch 33/100
# 20854/20854 [==============================] - 1s 60us/step - loss: 2.6762
#
# Epoch 00033: CRPS_score_val improved from 0.01286 to 0.01284, saving model to best_model.h5
# Epoch 34/100
# 20854/20854 [==============================] - 1s 60us/step - loss: 2.6681
#
# Epoch 00034: CRPS_score_val did not improve from 0.01284
# Epoch 35/100
# 20854/20854 [==============================] - 1s 60us/step - loss: 2.6660
# Epoch 00035: CRPS_score_val did not improve from 0.01284
# Epoch 36/100
# 20854/20854 [==============================] - 1s 60us/step - loss: 2.6643
#
# Epoch 00036: CRPS_score_val did not improve from 0.01284
# Epoch 37/100
# 20854/20854 [==============================] - 1s 60us/step - loss: 2.6682
#
# Epoch 00037: CRPS_score_val improved from 0.01284 to 0.01284, saving model to best_model.h5
# Epoch 38/100
# 20854/20854 [==============================] - 1s 61us/step - loss: 2.6624
#
# Epoch 00038: CRPS_score_val did not improve from 0.01284
# Epoch 39/100
# 20854/20854 [==============================] - 1s 61us/step - loss: 2.6597
#
# Epoch 00039: CRPS_score_val improved from 0.01284 to 0.01283, saving model to best_model.h5
# Epoch 40/100
# 20854/20854 [==============================] - 1s 68us/step - loss: 2.6535
#
# Epoch 00040: CRPS_score_val did not improve from 0.01283
# Epoch 41/100
# 20854/20854 [==============================] - 1s 62us/step - loss: 2.6577: 0s - loss:
#
# Epoch 00041: CRPS_score_val did not improve from 0.01283
# Epoch 42/100
# 20854/20854 [==============================] - 1s 61us/step - loss: 2.6508
#
# Epoch 00042: CRPS_score_val did not improve from 0.01283
# Epoch 43/100
# 20854/20854 [==============================] - 1s 59us/step - loss: 2.6501
#
# Epoch 00043: CRPS_score_val improved from 0.01283 to 0.01282, saving model to best_model.h5
# Epoch 44/100
# 20854/20854 [==============================] - 1s 59us/step - loss: 2.6399
#
# Epoch 00044: CRPS_score_val did not improve from 0.01282
# Epoch 45/100
# 20854/20854 [==============================] - 1s 59us/step - loss: 2.6409
#
# Epoch 00045: CRPS_score_val did not improve from 0.01282
# Epoch 46/100
# 20854/20854 [==============================] - 1s 59us/step - loss: 2.6424
#
# Epoch 00046: CRPS_score_val improved from 0.01282 to 0.01282, saving model to best_model.h5
# Epoch 47/100
# 20854/20854 [==============================] - 1s 59us/step - loss: 2.6365
#
# Epoch 00047: CRPS_score_val did not improve from 0.01282
# Epoch 48/100
# 20854/20854 [==============================] - 1s 60us/step - loss: 2.6320: 0s
#
# Epoch 00048: CRPS_score_val improved from 0.01282 to 0.01280, saving model to best_model.h5
# Epoch 49/100
# 20854/20854 [==============================] - 1s 59us/step - loss: 2.6336
#
# Epoch 00049: CRPS_score_val did not improve from 0.01280
# Epoch 50/100
# 20854/20854 [==============================] - 1s 57us/step - loss: 2.6287
#
# Epoch 00050: CRPS_score_val improved from 0.01280 to 0.01280, saving model to best_model.h5
# Epoch 51/100
# 20854/20854 [==============================] - 1s 59us/step - loss: 2.6233
#
# Epoch 00051: CRPS_score_val did not improve from 0.01280
# Epoch 52/100
# 20854/20854 [==============================] - 1s 59us/step - loss: 2.6210
#
# Epoch 00052: CRPS_score_val did not improve from 0.01280
# Epoch 53/100
# 20854/20854 [==============================] - 1s 59us/step - loss: 2.6245: 0s
#
# Epoch 00053: CRPS_score_val did not improve from 0.01280
# Epoch 54/100
# 20854/20854 [==============================] - 1s 60us/step - loss: 2.6171
#
# Epoch 00054: CRPS_score_val did not improve from 0.01280
# Epoch 55/100
# 20854/20854 [==============================] - 1s 61us/step - loss: 2.6213
#
# Epoch 00055: CRPS_score_val improved from 0.01280 to 0.01280, saving model to best_model.h5
# Epoch 56/100
# 20854/20854 [==============================] - 1s 62us/step - loss: 2.6116
#
# Epoch 00056: CRPS_score_val did not improve from 0.01280
# Epoch 57/100
# 20854/20854 [==============================] - 1s 62us/step - loss: 2.6077
#
# Epoch 00057: CRPS_score_val improved from 0.01280 to 0.01278, saving model to best_model.h5
# Epoch 58/100
# 20854/20854 [==============================] - 1s 61us/step - loss: 2.6067
#
# Epoch 00058: CRPS_score_val did not improve from 0.01278
# Epoch 59/100
# 20854/20854 [==============================] - 1s 60us/step - loss: 2.6015
#
# Epoch 00059: CRPS_score_val did not improve from 0.01278
# Epoch 60/100
# 20854/20854 [==============================] - 1s 60us/step - loss: 2.5981
#
# Epoch 00060: CRPS_score_val did not improve from 0.01278
# Epoch 61/100
# 20854/20854 [==============================] - 1s 61us/step - loss: 2.5992
#
# Epoch 00061: CRPS_score_val did not improve from 0.01278
# Epoch 62/100
# 20854/20854 [==============================] - 1s 60us/step - loss: 2.5958
#
# Epoch 00062: CRPS_score_val did not improve from 0.01278
# Epoch 63/100
# 20854/20854 [==============================] - 1s 60us/step - loss: 2.5975
#
# Epoch 00063: CRPS_score_val did not improve from 0.01278
# Epoch 64/100
# 20854/20854 [==============================] - 1s 60us/step - loss: 2.5853
#
# Epoch 00064: CRPS_score_val did not improve from 0.01278
# Epoch 65/100
# 20854/20854 [==============================] - 1s 61us/step - loss: 2.5878
#
# Epoch 00065: CRPS_score_val did not improve from 0.01278
# Epoch 66/100
# 20854/20854 [==============================] - 1s 62us/step - loss: 2.5799
#
# Epoch 00066: CRPS_score_val did not improve from 0.01278
# Epoch 67/100
# 20854/20854 [==============================] - 1s 60us/step - loss: 2.5788
# Restoring model weights from the end of the best epoch
#
# Epoch 00067: CRPS_score_val did not improve from 0.01278
# Epoch 00067: early stopping
# the 4 fold crps is 0.012785
# -----------
# -----------
# validation shape 2
# Epoch 1/100
# 20854/20854 [==============================] - 2s 85us/step - loss: 5.5672
#
# Epoch 00001: CRPS_score_val improved from inf to 0.08185, saving model to best_model.h5
# Epoch 2/100
# 20854/20854 [==============================] - 1s 63us/step - loss: 5.0222
#
# Epoch 00002: CRPS_score_val improved from 0.08185 to 0.07562, saving model to best_model.h5
# Epoch 3/100
# 20854/20854 [==============================] - 1s 66us/step - loss: 4.5487
#
# Epoch 00003: CRPS_score_val improved from 0.07562 to 0.05664, saving model to best_model.h5
# Epoch 4/100
# 20854/20854 [==============================] - 1s 64us/step - loss: 4.0976
#
# Epoch 00004: CRPS_score_val improved from 0.05664 to 0.03502, saving model to best_model.h5
# Epoch 5/100
# 20854/20854 [==============================] - 1s 65us/step - loss: 3.6977
#
# Epoch 00005: CRPS_score_val improved from 0.03502 to 0.02225, saving model to best_model.h5
# Epoch 6/100
# 20854/20854 [==============================] - 1s 65us/step - loss: 3.3626
#
# Epoch 00006: CRPS_score_val improved from 0.02225 to 0.01688, saving model to best_model.h5
# Epoch 7/100
# 20854/20854 [==============================] - 1s 64us/step - loss: 3.1372
#
# Epoch 00007: CRPS_score_val improved from 0.01688 to 0.01490, saving model to best_model.h5
# Epoch 8/100
# 20854/20854 [==============================] - 1s 62us/step - loss: 3.0044
#
# Epoch 00008: CRPS_score_val improved from 0.01490 to 0.01392, saving model to best_model.h5
# Epoch 9/100
# 20854/20854 [==============================] - 1s 62us/step - loss: 2.9337
#
# Epoch 00009: CRPS_score_val improved from 0.01392 to 0.01367, saving model to best_model.h5
# Epoch 10/100
# 20854/20854 [==============================] - 1s 61us/step - loss: 2.8832
#
# Epoch 00010: CRPS_score_val improved from 0.01367 to 0.01358, saving model to best_model.h5
# Epoch 11/100
# 20854/20854 [==============================] - 1s 66us/step - loss: 2.8412
#
# Epoch 00011: CRPS_score_val improved from 0.01358 to 0.01343, saving model to best_model.h5
# Epoch 12/100
# ...
# Epoch 33/100
# 20854/20854 [==============================] - 1s 54us/step - loss: 2.6716
#
# Epoch 00033: CRPS_score_val did not improve from 0.01258
# Epoch 34/100
# 20854/20854 [==============================] - 1s 54us/step - loss: 2.6713
#
# Epoch 00034: CRPS_score_val improved from 0.01258 to 0.01256, saving model to best_model.h5
# Epoch 35/100
# 20854/20854 [==============================] - 1s 55us/step - loss: 2.6646
#
# Epoch 00035: CRPS_score_val improved from 0.01256 to 0.01256, saving model to best_model.h5
# Epoch 36/100
# 20854/20854 [==============================] - 1s 54us/step - loss: 2.6608
#
# Epoch 00036: CRPS_score_val did not improve from 0.01256
# Epoch 37/100
# 20854/20854 [==============================] - 1s 55us/step - loss: 2.6590
#
# Epoch 00037: CRPS_score_val did not improve from 0.01256
# Epoch 38/100
# 20854/20854 [==============================] - 1s 54us/step - loss: 2.6583
#
# Epoch 00038: CRPS_score_val did not improve from 0.01256
# Epoch 39/100
# 20854/20854 [==============================] - 1s 54us/step - loss: 2.6551
#
# Epoch 00039: CRPS_score_val did not improve from 0.01256
# Epoch 40/100
# 20854/20854 [==============================] - 1s 54us/step - loss: 2.6487
#
# Epoch 00040: CRPS_score_val did not improve from 0.01256
# Epoch 41/100
# 20854/20854 [==============================] - 1s 55us/step - loss: 2.6485
#
# Epoch 00041: CRPS_score_val did not improve from 0.01256
# Epoch 42/100
# 20854/20854 [==============================] - 1s 55us/step - loss: 2.6489
#
# Epoch 00042: CRPS_score_val did not improve from 0.01256
# Epoch 43/100
# 20854/20854 [==============================] - 1s 55us/step - loss: 2.6441
#
# Epoch 00043: CRPS_score_val improved from 0.01256 to 0.01256, saving model to best_model.h5
# Epoch 44/100
# 20854/20854 [==============================] - 1s 55us/step - loss: 2.6407
#
# Epoch 00044: CRPS_score_val did not improve from 0.01256
# Epoch 45/100
# 20854/20854 [==============================] - 1s 54us/step - loss: 2.6388
#
# Epoch 00045: CRPS_score_val did not improve from 0.01256
# Epoch 46/100
# 20854/20854 [==============================] - 1s 55us/step - loss: 2.6339
#
# Epoch 00046: CRPS_score_val did not improve from 0.01256
# Epoch 47/100
# 20854/20854 [==============================] - 1s 55us/step - loss: 2.6283
#
# Epoch 00047: CRPS_score_val did not improve from 0.01256
# Epoch 48/100
# 20854/20854 [==============================] - 1s 55us/step - loss: 2.6281
#
# Epoch 00048: CRPS_score_val improved from 0.01256 to 0.01255, saving model to best_model.h5
# Epoch 49/100
# 20854/20854 [==============================] - 1s 55us/step - loss: 2.6274
#
# Epoch 00049: CRPS_score_val did not improve from 0.01255
# Epoch 50/100
# 20854/20854 [==============================] - 1s 54us/step - loss: 2.6255
#
# Epoch 00050: CRPS_score_val did not improve from 0.01255
# Epoch 51/100
# 20854/20854 [==============================] - 1s 55us/step - loss: 2.6234
#
# Epoch 00051: CRPS_score_val did not improve from 0.01255
# Epoch 52/100
# 20854/20854 [==============================] - 1s 55us/step - loss: 2.6152
#
# Epoch 00052: CRPS_score_val did not improve from 0.01255
# Epoch 53/100
# 20854/20854 [==============================] - 1s 55us/step - loss: 2.6169
#
# Epoch 00053: CRPS_score_val did not improve from 0.01255
# Epoch 54/100
# 20854/20854 [==============================] - 1s 55us/step - loss: 2.6179
#
# Epoch 00054: CRPS_score_val did not improve from 0.01255
# Epoch 55/100
# 20854/20854 [==============================] - 1s 54us/step - loss: 2.6095
#
# Epoch 00055: CRPS_score_val improved from 0.01255 to 0.01254, saving model to best_model.h5
# Epoch 56/100
# 20854/20854 [==============================] - 1s 56us/step - loss: 2.6082
#
# Epoch 00056: CRPS_score_val did not improve from 0.01254
# Epoch 57/100
# 20854/20854 [==============================] - 1s 54us/step - loss: 2.6073
#
# Epoch 00057: CRPS_score_val improved from 0.01254 to 0.01253, saving model to best_model.h5
# Epoch 58/100
# 20854/20854 [==============================] - 1s 55us/step - loss: 2.6054
#
# Epoch 00058: CRPS_score_val did not improve from 0.01253
# Epoch 59/100
# 20854/20854 [==============================] - 1s 56us/step - loss: 2.5985
#
# Epoch 00059: CRPS_score_val did not improve from 0.01253
# Epoch 60/100
# 20854/20854 [==============================] - 1s 57us/step - loss: 2.5976
#
# Epoch 00060: CRPS_score_val did not improve from 0.01253
# Epoch 61/100
# 20854/20854 [==============================] - 1s 56us/step - loss: 2.5904
#
# Epoch 00061: CRPS_score_val did not improve from 0.01253
# Epoch 62/100
# 20854/20854 [==============================] - 1s 58us/step - loss: 2.5882
#
# Epoch 00062: CRPS_score_val did not improve from 0.01253
# Epoch 63/100
# 20854/20854 [==============================] - 1s 59us/step - loss: 2.5905
#
# Epoch 00063: CRPS_score_val did not improve from 0.01253
# Epoch 64/100
# 20854/20854 [==============================] - 1s 57us/step - loss: 2.5828: 0s - l
#
# Epoch 00064: CRPS_score_val did not improve from 0.01253
# Epoch 65/100
# 20854/20854 [==============================] - 1s 56us/step - loss: 2.5835
#
# Epoch 00065: CRPS_score_val did not improve from 0.01253
# Epoch 66/100
# 20854/20854 [==============================] - 1s 57us/step - loss: 2.5755
#
# Epoch 00066: CRPS_score_val did not improve from 0.01253
# Epoch 67/100
# 20854/20854 [==============================] - 1s 57us/step - loss: 2.5752
# Restoring model weights from the end of the best epoch
#
# Epoch 00067: CRPS_score_val did not improve from 0.01253
# Epoch 00067: early stopping
# the 2 fold crps is 0.012527
# -----------
# -----------
# validation shape 2
# ---------------------------------------------------------------------------
# InvalidArgumentError                      Traceback (most recent call last)
# c:\users\0000011306852\appdata\local\programs\python\python36\lib\site-packages\tensorflow_core\python\framework\ops.py in get_attr(self, name)
#    2382       with c_api_util.tf_buffer() as buf:
# -> 2383         c_api.TF_OperationGetAttrValueProto(self._c_op, name, buf)
#    2384         data = c_api.TF_GetBuffer(buf)
#
# InvalidArgumentError: Operation 'dropout_37/cond' has no attr named '_XlaCompile'.
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# c:\users\0000011306852\appdata\local\programs\python\python36\lib\site-packages\tensorflow_core\python\ops\gradients_util.py in _MaybeCompile(scope, op, func, grad_fn)
#     344     try:
# --> 345       xla_compile = op.get_attr("_XlaCompile")
#     346       xla_separate_compiled_gradients = op.get_attr(
#
# c:\users\0000011306852\appdata\local\programs\python\python36\lib\site-packages\tensorflow_core\python\framework\ops.py in get_attr(self, name)
#    2386       # Convert to ValueError for backwards compatibility.
# -> 2387       raise ValueError(str(e))
#    2388     x = attr_value_pb2.AttrValue()
#
# ValueError: Operation 'dropout_37/cond' has no attr named '_XlaCompile'.
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-11-00aec1a0c285> in <module>
#      16         tr_x,tr_y = X[tr_inds],y[tr_inds]
#      17         val_x,val_y = X[val_inds],y[val_inds]
# ---> 18         model,crps = get_model(tr_x,tr_y,val_x,val_y)
#      19         models.append(model)
#      20         print("the %d fold crps is %f"%((k_fold+1),crps))
#
# <ipython-input-10-dfa7820fa62f> in get_model(x_tr, y_tr, x_val, y_val)
#      33
#      34
# ---> 35     model.fit(x_tr, y_tr,callbacks=[CRPSCallback(validation = (x_val,y_val)),es,mc], epochs=100, batch_size=bsz,verbose=1)
#      36     model.load_weights("best_model.h5")
#      37
#
# c:\users\0000011306852\appdata\local\programs\python\python36\lib\site-packages\keras\engine\training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_freq, max_queue_size, workers, use_multiprocessing, **kwargs)
#    1211         else:
#    1212             fit_inputs = x + y + sample_weights
# -> 1213         self._make_train_function()
#    1214         fit_function = self.train_function
#    1215
#
# c:\users\0000011306852\appdata\local\programs\python\python36\lib\site-packages\keras\engine\training.py in _make_train_function(self)
#     314                     training_updates = self.optimizer.get_updates(
#     315                         params=self._collected_trainable_weights,
# --> 316                         loss=self.total_loss)
#     317                 updates = self.updates + training_updates
#     318
#
# c:\users\0000011306852\appdata\local\programs\python\python36\lib\site-packages\keras\legacy\interfaces.py in wrapper(*args, **kwargs)
#      89                 warnings.warn('Update your `' + object_name + '` call to the ' +
#      90                               'Keras 2 API: ' + signature, stacklevel=2)
# ---> 91             return func(*args, **kwargs)
#      92         wrapper._original_function = func
#      93         return wrapper
#
# c:\users\0000011306852\appdata\local\programs\python\python36\lib\site-packages\keras\backend\tensorflow_backend.py in symbolic_fn_wrapper(*args, **kwargs)
#      73         if _SYMBOLIC_SCOPE.value:
#      74             with get_graph().as_default():
# ---> 75                 return func(*args, **kwargs)
#      76         else:
#      77             return func(*args, **kwargs)
#
# c:\users\0000011306852\appdata\local\programs\python\python36\lib\site-packages\keras\optimizers.py in get_updates(self, loss, params)
#     502     @K.symbolic
#     503     def get_updates(self, loss, params):
# --> 504         grads = self.get_gradients(loss, params)
#     505         self.updates = [K.update_add(self.iterations, 1)]
#     506
#
# c:\users\0000011306852\appdata\local\programs\python\python36\lib\site-packages\keras\optimizers.py in get_gradients(self, loss, params)
#      89
#      90     def get_gradients(self, loss, params):
# ---> 91         grads = K.gradients(loss, params)
#      92         if any(x is None for x in grads):
#      93             raise ValueError('An operation has `None` for gradient. '
#
# c:\users\0000011306852\appdata\local\programs\python\python36\lib\site-packages\keras\backend\tensorflow_backend.py in symbolic_fn_wrapper(*args, **kwargs)
#      73         if _SYMBOLIC_SCOPE.value:
#      74             with get_graph().as_default():
# ---> 75                 return func(*args, **kwargs)
#      76         else:
#      77             return func(*args, **kwargs)
#
# c:\users\0000011306852\appdata\local\programs\python\python36\lib\site-packages\keras\backend\tensorflow_backend.py in gradients(loss, variables)
#    3023     if _is_tf_1():
#    3024         return tf.gradients(loss, variables, colocate_gradients_with_ops=True)
# -> 3025     return tf.gradients(loss, variables)
#    3026
#    3027
#
# c:\users\0000011306852\appdata\local\programs\python\python36\lib\site-packages\tensorflow_core\python\ops\gradients_impl.py in gradients_v2(ys, xs, grad_ys, name, gate_gradients, aggregation_method, stop_gradients, unconnected_gradients)
#     272         ys, xs, grad_ys, name, True, gate_gradients,
#     273         aggregation_method, stop_gradients,
# --> 274         unconnected_gradients)
#     275   # pylint: enable=protected-access
#     276
#
# c:\users\0000011306852\appdata\local\programs\python\python36\lib\site-packages\tensorflow_core\python\ops\gradients_util.py in _GradientsHelper(ys, xs, grad_ys, name, colocate_gradients_with_ops, gate_gradients, aggregation_method, stop_gradients, unconnected_gradients, src_graph)
#     677                 # functions.
#     678                 in_grads = _MaybeCompile(grad_scope, op, func_call,
# --> 679                                          lambda: grad_fn(op, *out_grads))
#     680               else:
#     681                 # For function call ops, we add a 'SymbolicGradient'
#
# c:\users\0000011306852\appdata\local\programs\python\python36\lib\site-packages\tensorflow_core\python\ops\gradients_util.py in _MaybeCompile(scope, op, func, grad_fn)
#     348       xla_scope = op.get_attr("_XlaScope").decode()
#     349     except ValueError:
# --> 350       return grad_fn()  # Exit early
#     351
#     352   if not xla_compile:
#
# c:\users\0000011306852\appdata\local\programs\python\python36\lib\site-packages\tensorflow_core\python\ops\gradients_util.py in <lambda>()
#     677                 # functions.
#     678                 in_grads = _MaybeCompile(grad_scope, op, func_call,
# --> 679                                          lambda: grad_fn(op, *out_grads))
#     680               else:
#     681                 # For function call ops, we add a 'SymbolicGradient'
#
# c:\users\0000011306852\appdata\local\programs\python\python36\lib\site-packages\tensorflow_core\python\ops\cond_v2.py in _IfGrad(op, *grads)
#     108   # Get the if operator (this logic handles the case where op is a MockOp)
#     109   if_op = op.outputs[0].op
# --> 110   true_graph, false_graph = get_func_graphs(if_op)
#     111   # Note: op.graph != ops.get_default_graph() when we are computing the gradient
#     112   # of a nested cond.
#
# c:\users\0000011306852\appdata\local\programs\python\python36\lib\site-packages\tensorflow_core\python\ops\cond_v2.py in get_func_graphs(op)
#     330   if op.type in ["If", "StatelessIf"]:
#     331     return (_get_func_graph_for_branch(op.get_attr("then_branch")),
# --> 332             _get_func_graph_for_branch(op.get_attr("else_branch")))
#     333   elif op.type == "Case":
#     334     return [_get_func_graph_for_branch(branch_fn)
#
# c:\users\0000011306852\appdata\local\programs\python\python36\lib\site-packages\tensorflow_core\python\ops\cond_v2.py in _get_func_graph_for_branch(name_attr_list)
#     320     with op.graph.as_default():
#     321       func_graph = function_def_to_graph.function_def_to_graph(
# --> 322           fdef, input_shapes)
#     323     for external_t, internal_t in zip(inputs, func_graph.inputs):
#     324       custom_gradient.copy_handle_data(external_t, internal_t)
#
# c:\users\0000011306852\appdata\local\programs\python\python36\lib\site-packages\tensorflow_core\python\framework\function_def_to_graph.py in function_def_to_graph(fdef, input_shapes, copy_functions)
#      63   with func_graph.as_default():
#      64     # Add all function nodes to the graph.
# ---> 65     importer.import_graph_def_for_function(graph_def, name="")
#      66
#      67     # Initialize fields specific to FuncGraph.
#
# c:\users\0000011306852\appdata\local\programs\python\python36\lib\site-packages\tensorflow_core\python\framework\importer.py in import_graph_def_for_function(graph_def, name)
#     410   """Like import_graph_def but does not validate colocation constraints."""
#     411   return _import_graph_def_internal(
# --> 412       graph_def, validate_colocation_constraints=False, name=name)
#     413
#     414
#
# c:\users\0000011306852\appdata\local\programs\python\python36\lib\site-packages\tensorflow_core\python\framework\importer.py in _import_graph_def_internal(graph_def, input_map, return_elements, validate_colocation_constraints, name, op_dict, producer_op_list)
#     518
#     519   if graph_def.library and graph_def.library.function:
# --> 520     functions = function.from_library(graph_def.library)
#     521     for f in functions:
#     522       f.add_to_graph(graph)
#
# c:\users\0000011306852\appdata\local\programs\python\python36\lib\site-packages\tensorflow_core\python\framework\function.py in from_library(lib)
#    1165     if func_to_grad[name]:
#    1166       assert grad
# -> 1167     defined_func = _from_definition(fdef, grad_func=grad)
#    1168     initialized[name] = defined_func
#    1169
#
# c:\users\0000011306852\appdata\local\programs\python\python36\lib\site-packages\tensorflow_core\python\framework\function.py in _from_definition(fdef, grad_func)
#    1100   # pylint: disable=protected-access
#    1101   serialized = fdef.SerializeToString()
# -> 1102   c_func = c_api.TF_FunctionImportFunctionDef(serialized)
#    1103   result._c_func = c_api_util.ScopedTFFunction(c_func)
#    1104   result._extra_inputs = []
#
# KeyboardInterrupt:

# %%
print("mean crps is %f"%np.mean(crps_csv))

# %%
# %%time
if  TRAIN_OFFLINE==False:
    from kaggle.competitions import nflrush
    env = nflrush.make_env()
    iter_test = env.iter_test()

    for (test_df, sample_prediction_df) in iter_test:
        basetable = create_features(test_df, deploy=True)
        basetable.drop(['GameId','PlayId'], axis=1, inplace=True)
        scaled_basetable = scaler.transform(basetable)

        y_pred = predict(scaled_basetable)
        y_pred = np.clip(np.cumsum(y_pred, axis=1), 0, 1).tolist()[0]

        preds_df = pd.DataFrame(data=[y_pred], columns=sample_prediction_df.columns)
        env.predict(preds_df)

    env.write_submission_file()
